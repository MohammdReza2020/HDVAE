# %%
############### Comparison Step ##################

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
ls
# Out:
# gdrive/  sample_data/

# %%
cd gdrive/MyDrive/Dataset
# Out:
# /content/gdrive/MyDrive/Dataset

# %%
# hdvae
import os
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms
from torchvision.utils import save_image
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm # for a progress bar

# For Disentanglement Metrics
from sklearn.feature_selection import mutual_info_regression
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.preprocessing import KBinsDiscretizer # for MIG discretization

# torch.autograd.set_detect_anomaly(True) # <--- ADD THIS LINE HERE

# If you are running on Colab and this solved the issue for you:
# os.environ['CUDA_LAUNCH_BLOCKING'] = '0' # Reverted to asynchronous for faster execution
# If you want to keep debugging with synchronous errors uncomment the line below:
# os.environ['CUDA_LAUNCH_BLOCKING'] = '1'

# --- DspritesDataset Class ---
class DspritesDataset(torch.utils.data.Dataset):
    def __init__(self, root_dir, transform=None):
        self.root_dir = root_dir
        self.transform = transform
        self.data_path = os.path.join(root_dir, 'dsprites_ndarray_co1sh3sc6or40x32y32_64x64.npz')

        if not os.path.exists(self.data_path):
            raise FileNotFoundError(f"dSprites data not found at {self.data_path}. "
                                    f"Please download it from https://github.com/deepmind/dsprites-dataset "
                                    f"and place it in the '{root_dir}' directory.")

        try:
            with np.load(self.data_path, encoding='bytes', allow_pickle=True) as data:
                self.imgs = data['imgs']
                self.latents_values = data['latents_values']
                self.latents_classes = data['latents_classes']
            print(f"Successfully loaded dsprites_ndarray_co1sh3sc6or40x32y32_64x64.npz from {self.data_path}")
            print(f"Number of images loaded: {len(self.imgs)}")
        except Exception as e:
            raise RuntimeError(f"Error loading dsprites.npz file: {e}. Please check if the file is corrupted or incomplete.")

    def __len__(self):
        return len(self.imgs)

    def __getitem__(self, idx):
        image_np = self.imgs[idx]
        image = torch.from_numpy(image_np).float().unsqueeze(0)
        latents_value = torch.from_numpy(self.latents_values[idx]).float()
        latents_class = torch.from_numpy(self.latents_classes[idx]).long()

        if self.transform:
            image = self.transform(image)

        return image, latents_value, latents_class

# Device configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Hyper-parameters
image_size = 64 * 64
z1_dim = 64
z2_dim = 32
z3_dim = 16
num_epochs = 10
batch_size = 128
learning_rate = 1e-3


# dSprites dataset
dsprites_root_dir = './'
os.makedirs(dsprites_root_dir, exist_ok=True)

transform = None

full_dataset = DspritesDataset(root_dir=dsprites_root_dir, transform=transform)

train_size = int(0.8 * len(full_dataset))
test_size = len(full_dataset) - train_size
train_dataset, test_dataset = torch.utils.data.random_split(full_dataset, [train_size, test_size])

train_loader = torch.utils.data.DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True)
test_loader = torch.utils.data.DataLoader(dataset=test_dataset, batch_size=batch_size, shuffle=False)

test_loader_fixed_batch = torch.utils.data.DataLoader(dataset=test_dataset, batch_size=8, shuffle=False)
try:
    fixed_test_images, _, _ = next(iter(test_loader_fixed_batch))
    fixed_test_images = fixed_test_images.to(device)
except Exception as e:
    print(f"CRITICAL ERROR: Failed to load or move fixed test images to device: {e}")
    exit()
# Out:
# Successfully loaded dsprites_ndarray_co1sh3sc6or40x32y32_64x64.npz from ./dsprites_ndarray_co1sh3sc6or40x32y32_64x64.npz
# Number of images loaded: 737280

# %%
# HDVAE Model
class HDVAE(nn.Module):
    def __init__(self, image_size, z1_dim, z2_dim, z3_dim):
        super(HDVAE, self).__init__()
        self.image_size = image_size
        self.z1_dim = z1_dim
        self.z2_dim = z2_dim
        self.z3_dim = z3_dim

        self.encoder_x_to_z1 = nn.Sequential(
            nn.Linear(image_size, 512),
            nn.ReLU(),
            nn.Linear(512, 256),
            nn.ReLU(),
            nn.Linear(256, 128)
        )
        self.fc_mu1 = nn.Linear(128, z1_dim)
        self.fc_logvar1 = nn.Linear(128, z1_dim)

        self.encoder_z1_to_z2 = nn.Sequential(
            nn.Linear(z1_dim, 256),
            nn.ReLU(),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Linear(128, 64)
        )
        self.fc_mu2 = nn.Linear(64, z2_dim)
        self.fc_logvar2 = nn.Linear(64, z2_dim)

        self.encoder_z2_to_z3 = nn.Sequential(
            nn.Linear(z2_dim, 128),
            nn.ReLU(),
            nn.Linear(128, 64)
        )
        self.fc_mu3 = nn.Linear(64, z3_dim)
        self.fc_logvar3 = nn.Linear(64, z3_dim)

        self.decoder_z3_to_z2_params = nn.Sequential(
            nn.Linear(z3_dim, 64),
            nn.ReLU(),
            nn.Linear(64, 128)
        )
        self.fc_prior_mu2 = nn.Linear(128, z2_dim)
        self.fc_prior_logvar2 = nn.Linear(128, z2_dim)

        self.decoder_z2_to_z1_params = nn.Sequential(
            nn.Linear(z2_dim, 64),
            nn.ReLU(),
            nn.Linear(64, 128)
        )
        self.fc_prior_mu1 = nn.Linear(128, z1_dim)
        self.fc_prior_logvar1 = nn.Linear(128, z1_dim)

        self.decoder_z1_to_x = nn.Sequential(
            nn.Linear(z1_dim, 256),
            nn.ReLU(),
            nn.Linear(256, 512),
            nn.ReLU(),
            nn.Linear(512, image_size),
            nn.Sigmoid()
        )

    def reparameterize(self, mu, log_var):
        std = torch.exp(0.5 * log_var)
        eps = torch.randn_like(std)
        return mu + eps * std

    def encode(self, x):
        h1 = self.encoder_x_to_z1(x.view(-1, self.image_size))
        mu1, log_var1 = self.fc_mu1(h1), self.fc_logvar1(h1)
        z1 = self.reparameterize(mu1, log_var1)

        h2 = self.encoder_z1_to_z2(z1)
        mu2, log_var2 = self.fc_mu2(h2), self.fc_logvar2(h2)
        z2 = self.reparameterize(mu2, log_var2)

        h3 = self.encoder_z2_to_z3(z2)
        mu3, log_var3 = self.fc_mu3(h3), self.fc_logvar3(h3)
        z3 = self.reparameterize(mu3, log_var3)

        return (mu1, log_var1, z1), (mu2, log_var2, z2), (mu3, log_var3, z3)

    def decode(self, z1, z2, z3):
        x_reconst = self.decoder_z1_to_x(z1)

        h_prior_z1 = self.decoder_z2_to_z1_params(z2)
        mu_prior_1 = self.fc_prior_mu1(h_prior_z1)
        log_var_prior_1 = self.fc_prior_logvar1(h_prior_z1)

        h_prior_z2 = self.decoder_z3_to_z2_params(z3)
        mu_prior_2 = self.fc_prior_mu2(h_prior_z2)
        log_var_prior_2 = self.fc_prior_logvar2(h_prior_z2)

        return x_reconst, (mu_prior_1, log_var_prior_1), (mu_prior_2, log_var_prior_2)

    def forward(self, x):
        (mu1, log_var1, z1), (mu2, log_var2, z2), (mu3, log_var3, z3) = self.encode(x)
        x_reconst, (mu_prior_1, log_var_prior_1), (mu_prior_2, log_var_prior_2) = self.decode(z1, z2, z3)

        return x_reconst, mu1, log_var1, z1, mu2, log_var2, z2, mu3, log_var3, z3, \
               mu_prior_1, log_var_prior_1, mu_prior_2, log_var_prior_2

# Instantiate the model
print(f"Attempting to move model to device: {device}")

model = HDVAE(image_size, z1_dim, z2_dim, z3_dim).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# print(model)

# Loss Function
def loss_function_hdvae(recon_x, x, mu1, log_var1, mu2, log_var2, mu3, log_var3, mu_prior_1, log_var_prior_1, mu_prior_2, log_var_prior_2,
                        beta1=1.0, beta2=1.0, beta3=1.0):

    BCE = F.binary_cross_entropy(recon_x, x.view(-1, image_size), reduction='sum')

    KLD_z3 = -0.5 * torch.sum(1 + log_var3 - mu3.pow(2) - log_var3.exp())

    log_var_prior_2_clamped = torch.clamp(log_var_prior_2, min=-20.0, max=20.0)
    log_var2_clamped = torch.clamp(log_var2, min=-20.0, max=20.0)
    KLD_z2 = 0.5 * torch.sum(
        torch.exp(log_var2_clamped - log_var_prior_2_clamped) +
        ((mu_prior_2 - mu2)**2) * torch.exp(-log_var_prior_2_clamped) - 1 +
        (log_var_prior_2_clamped - log_var2_clamped)
    )

    log_var_prior_1_clamped = torch.clamp(log_var_prior_1, min=-20.0, max=20.0)
    log_var1_clamped = torch.clamp(log_var1, min=-20.0, max=20.0)
    KLD_z1 = 0.5 * torch.sum(
        torch.exp(log_var1_clamped - log_var_prior_1_clamped) +
        ((mu_prior_1 - mu1)**2) * torch.exp(-log_var_prior_1_clamped) - 1 +
        (log_var_prior_1_clamped - log_var1_clamped)
    )

    return BCE + beta1 * KLD_z1 + beta2 * KLD_z2 + beta3 * KLD_z3


hdvae_loss_history = []


print("Starting HDVAE training with 3 hierarchical layers on dSprites...")
for epoch in range(num_epochs):
    model.train()
    total_loss = 0
    for i, (images, _, _) in enumerate(train_loader):
        images = images.to(device)

        recon_images, mu1, log_var1, z1, mu2, log_var2, z2, mu3, log_var3, z3, \
               mu_prior_1, log_var_prior_1, mu_prior_2, log_var_prior_2 = model(images)


        ### MRH:
        ################ linear annealing for Beta  in loss function:
        num_annealing_epochs = num_epochs / 2
        beta_anneelling_factor = min(1.0, epoch / num_annealing_epochs)
        # --- REDUCED MAX BETA VALUES FOR STABILITY ---
        max_beta1 = 2 #0.75 #5   #4 > 3.3 #5 > 4 #3 => 2.4
        max_beta2 = 1 #0.5  #4   #3      #4      #2
        max_beta3 = 0.5 #0.25 #3   #1      #2      #1
        current_beta1 = beta_anneelling_factor * max_beta1
        current_beta2 = beta_anneelling_factor * max_beta2
        current_beta3 = beta_anneelling_factor * max_beta3
        ################

        loss = loss_function_hdvae(recon_images, images,
                                   mu1, log_var1,
                                   mu2, log_var2,
                                   mu3, log_var3,
                                   mu_prior_1, log_var_prior_1,
                                   mu_prior_2, log_var_prior_2, beta1=current_beta1, beta2=current_beta2, beta3=current_beta3)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        total_loss += loss.item()

        if (i+1) % 100 == 0:
            print(f"Epoch [{epoch+1}/{num_epochs}], Step [{i+1}/{len(train_loader)}], Loss: {loss.item():.4f}")

    avg_loss = total_loss / len(train_loader.dataset)

    print(f"Epoch [{epoch+1}/{num_epochs}] completed. Avg Loss: {avg_loss:.4f}")
    hdvae_loss_history.append(avg_loss)

print("Training complete!")


################################
model_HDVAE = model
# Out:
# Attempting to move model to device: cpu
# Starting HDVAE training with 3 hierarchical layers on dSprites...
# Epoch [1/10], Step [100/4608], Loss: 65657.0781
# Epoch [1/10], Step [200/4608], Loss: 15270.5195
# Epoch [1/10], Step [300/4608], Loss: 14910.9873
# Epoch [1/10], Step [400/4608], Loss: 14090.8887
# Epoch [1/10], Step [500/4608], Loss: 14008.3545
# Epoch [1/10], Step [600/4608], Loss: 12639.3828
# Epoch [1/10], Step [700/4608], Loss: 13316.7959
# Epoch [1/10], Step [800/4608], Loss: 12826.3154
# Epoch [1/10], Step [900/4608], Loss: 11925.5332
# Epoch [1/10], Step [1000/4608], Loss: 12561.8203
# Epoch [1/10], Step [1100/4608], Loss: 11609.7617
# Epoch [1/10], Step [1200/4608], Loss: 10589.3643
# Epoch [1/10], Step [1300/4608], Loss: 10871.7461
# Epoch [1/10], Step [1400/4608], Loss: 10477.5420
# Epoch [1/10], Step [1500/4608], Loss: 9938.7100
# Epoch [1/10], Step [1600/4608], Loss: 9838.7148
# Epoch [1/10], Step [1700/4608], Loss: 9418.3789
# Epoch [1/10], Step [1800/4608], Loss: 9440.9043
# Epoch [1/10], Step [1900/4608], Loss: 9183.0381
# Epoch [1/10], Step [2000/4608], Loss: 9161.0469
# Epoch [1/10], Step [2100/4608], Loss: 9754.7637
# Epoch [1/10], Step [2200/4608], Loss: 9444.9131
# Epoch [1/10], Step [2300/4608], Loss: 9067.1621
# Epoch [1/10], Step [2400/4608], Loss: 9678.9395
# Epoch [1/10], Step [2500/4608], Loss: 9147.0645
# Epoch [1/10], Step [2600/4608], Loss: 8320.9531
# Epoch [1/10], Step [2700/4608], Loss: 9315.9434
# Epoch [1/10], Step [2800/4608], Loss: 8877.7832
# Epoch [1/10], Step [2900/4608], Loss: 9053.1416
# Epoch [1/10], Step [3000/4608], Loss: 9194.3926
# Epoch [1/10], Step [3100/4608], Loss: 8332.8223
# Epoch [1/10], Step [3200/4608], Loss: 8752.3223
# Epoch [1/10], Step [3300/4608], Loss: 8678.9980
# Epoch [1/10], Step [3400/4608], Loss: 8074.2832
# Epoch [1/10], Step [3500/4608], Loss: 7849.3838
# Epoch [1/10], Step [3600/4608], Loss: 8116.1660
# Epoch [1/10], Step [3700/4608], Loss: 7651.7002
# Epoch [1/10], Step [3800/4608], Loss: 8716.7178
# Epoch [1/10], Step [3900/4608], Loss: 7414.8423
# Epoch [1/10], Step [4000/4608], Loss: 7388.8340
# Epoch [1/10], Step [4100/4608], Loss: 7500.2988
# Epoch [1/10], Step [4200/4608], Loss: 7897.2773
# Epoch [1/10], Step [4300/4608], Loss: 8213.8418
# Epoch [1/10], Step [4400/4608], Loss: 7332.8472
# Epoch [1/10], Step [4500/4608], Loss: 7291.5410
# Epoch [1/10], Step [4600/4608], Loss: 7396.1636
# Epoch [1/10] completed. Avg Loss: 94.0797
# Epoch [2/10], Step [100/4608], Loss: 13679.5029
# Epoch [2/10], Step [200/4608], Loss: 12328.3965
# Epoch [2/10], Step [300/4608], Loss: 11855.4404
# Epoch [2/10], Step [400/4608], Loss: 10170.5068
# Epoch [2/10], Step [500/4608], Loss: 10118.4531
# Epoch [2/10], Step [600/4608], Loss: 10088.5625
# Epoch [2/10], Step [700/4608], Loss: 9573.9229
# Epoch [2/10], Step [800/4608], Loss: 9985.6543
# Epoch [2/10], Step [900/4608], Loss: 10351.4004
# Epoch [2/10], Step [1000/4608], Loss: 10084.8516
# Epoch [2/10], Step [1100/4608], Loss: 9085.5625
# Epoch [2/10], Step [1200/4608], Loss: 9387.5430
# Epoch [2/10], Step [1300/4608], Loss: 9179.6436
# Epoch [2/10], Step [1400/4608], Loss: 8852.9297
# Epoch [2/10], Step [1500/4608], Loss: 9577.3213
# Epoch [2/10], Step [1600/4608], Loss: 9010.5283
# Epoch [2/10], Step [1700/4608], Loss: 9001.4062
# Epoch [2/10], Step [1800/4608], Loss: 8660.7100
# Epoch [2/10], Step [1900/4608], Loss: 8953.5576
# Epoch [2/10], Step [2000/4608], Loss: 9368.7578
# Epoch [2/10], Step [2100/4608], Loss: 8735.6152
# Epoch [2/10], Step [2200/4608], Loss: 8443.7559
# Epoch [2/10], Step [2300/4608], Loss: 8173.9409
# Epoch [2/10], Step [2400/4608], Loss: 8395.5137
# Epoch [2/10], Step [2500/4608], Loss: 7711.5347
# Epoch [2/10], Step [2600/4608], Loss: 8598.6025
# Epoch [2/10], Step [2700/4608], Loss: 8128.5024
# Epoch [2/10], Step [2800/4608], Loss: 8742.3506
# Epoch [2/10], Step [2900/4608], Loss: 8756.2207
# Epoch [2/10], Step [3000/4608], Loss: 8524.1650
# Epoch [2/10], Step [3100/4608], Loss: 8177.2178
# Epoch [2/10], Step [3200/4608], Loss: 7707.1245
# Epoch [2/10], Step [3300/4608], Loss: 8219.7295
# Epoch [2/10], Step [3400/4608], Loss: 7532.2041
# Epoch [2/10], Step [3500/4608], Loss: 7992.8638
# Epoch [2/10], Step [3600/4608], Loss: 8336.4473
# Epoch [2/10], Step [3700/4608], Loss: 8107.6294
# Epoch [2/10], Step [3800/4608], Loss: 7504.5176
# Epoch [2/10], Step [3900/4608], Loss: 7394.9224
# Epoch [2/10], Step [4000/4608], Loss: 7618.0571
# Epoch [2/10], Step [4100/4608], Loss: 7770.8086
# Epoch [2/10], Step [4200/4608], Loss: 7534.1479
# Epoch [2/10], Step [4300/4608], Loss: 7280.7822
# Epoch [2/10], Step [4400/4608], Loss: 8119.5283
# Epoch [2/10], Step [4500/4608], Loss: 7691.6313
# Epoch [2/10], Step [4600/4608], Loss: 7630.0010
# Epoch [2/10] completed. Avg Loss: 71.4888
# Epoch [3/10], Step [100/4608], Loss: 8911.4326
# Epoch [3/10], Step [200/4608], Loss: 8405.5342
# Epoch [3/10], Step [300/4608], Loss: 9041.5361
# Epoch [3/10], Step [400/4608], Loss: 8069.8516
# Epoch [3/10], Step [500/4608], Loss: 9496.5391
# Epoch [3/10], Step [600/4608], Loss: 8378.2266
# Epoch [3/10], Step [700/4608], Loss: 8348.8252
# Epoch [3/10], Step [800/4608], Loss: 8659.1650
# Epoch [3/10], Step [900/4608], Loss: 8084.8398
# Epoch [3/10], Step [1000/4608], Loss: 8535.1201
# Epoch [3/10], Step [1100/4608], Loss: 8585.4678
# Epoch [3/10], Step [1200/4608], Loss: 8320.4863
# Epoch [3/10], Step [1300/4608], Loss: 9127.6025
# Epoch [3/10], Step [1400/4608], Loss: 8166.9712
# Epoch [3/10], Step [1500/4608], Loss: 8175.4248
# Epoch [3/10], Step [1600/4608], Loss: 8397.2305
# Epoch [3/10], Step [1700/4608], Loss: 8038.9302
# Epoch [3/10], Step [1800/4608], Loss: 8334.5439
# Epoch [3/10], Step [1900/4608], Loss: 8093.4175
# Epoch [3/10], Step [2000/4608], Loss: 8059.7036
# Epoch [3/10], Step [2100/4608], Loss: 8034.6206
# Epoch [3/10], Step [2200/4608], Loss: 8202.2754
# Epoch [3/10], Step [2300/4608], Loss: 7586.9038
# Epoch [3/10], Step [2400/4608], Loss: 8158.5493
# Epoch [3/10], Step [2500/4608], Loss: 8390.2656
# Epoch [3/10], Step [2600/4608], Loss: 8395.4629
# Epoch [3/10], Step [2700/4608], Loss: 7595.2773
# Epoch [3/10], Step [2800/4608], Loss: 8341.8672
# Epoch [3/10], Step [2900/4608], Loss: 7591.0498
# Epoch [3/10], Step [3000/4608], Loss: 7651.4004
# Epoch [3/10], Step [3100/4608], Loss: 7707.3555
# Epoch [3/10], Step [3200/4608], Loss: 8004.1387
# Epoch [3/10], Step [3300/4608], Loss: 7999.4829
# Epoch [3/10], Step [3400/4608], Loss: 8130.2329
# Epoch [3/10], Step [3500/4608], Loss: 7803.1055
# Epoch [3/10], Step [3600/4608], Loss: 7620.1211
# Epoch [3/10], Step [3700/4608], Loss: 7537.1543
# Epoch [3/10], Step [3800/4608], Loss: 7369.0005
# Epoch [3/10], Step [3900/4608], Loss: 7859.8462
# Epoch [3/10], Step [4000/4608], Loss: 7795.6348
# Epoch [3/10], Step [4100/4608], Loss: 7537.7988
# Epoch [3/10], Step [4200/4608], Loss: 7600.0781
# Epoch [3/10], Step [4300/4608], Loss: 7761.9214
# Epoch [3/10], Step [4400/4608], Loss: 7809.3071
# Epoch [3/10], Step [4500/4608], Loss: 7847.0474
# Epoch [3/10], Step [4600/4608], Loss: 7549.2856
# Epoch [3/10] completed. Avg Loss: 63.9222
# Epoch [4/10], Step [100/4608], Loss: 8568.7959
# Epoch [4/10], Step [200/4608], Loss: 9055.2559
# Epoch [4/10], Step [300/4608], Loss: 8431.4004
# Epoch [4/10], Step [400/4608], Loss: 8151.6567
# Epoch [4/10], Step [500/4608], Loss: 8378.7930
# Epoch [4/10], Step [600/4608], Loss: 8661.5117
# Epoch [4/10], Step [700/4608], Loss: 8870.8320
# Epoch [4/10], Step [800/4608], Loss: 8532.6855
# Epoch [4/10], Step [900/4608], Loss: 8413.9492
# Epoch [4/10], Step [1000/4608], Loss: 8143.2280
# Epoch [4/10], Step [1100/4608], Loss: 8693.0420
# Epoch [4/10], Step [1200/4608], Loss: 8491.2275
# Epoch [4/10], Step [1300/4608], Loss: 8473.5361
# Epoch [4/10], Step [1400/4608], Loss: 8350.6475
# Epoch [4/10], Step [1500/4608], Loss: 8048.6499
# Epoch [4/10], Step [1600/4608], Loss: 8301.6016
# Epoch [4/10], Step [1700/4608], Loss: 7876.6836
# Epoch [4/10], Step [1800/4608], Loss: 8391.7100
# Epoch [4/10], Step [1900/4608], Loss: 7891.7231
# Epoch [4/10], Step [2000/4608], Loss: 8718.4873
# Epoch [4/10], Step [2100/4608], Loss: 7852.2285
# Epoch [4/10], Step [2200/4608], Loss: 8202.9258
# Epoch [4/10], Step [2300/4608], Loss: 7924.8652
# Epoch [4/10], Step [2400/4608], Loss: 8407.4062
# Epoch [4/10], Step [2500/4608], Loss: 8042.0874
# Epoch [4/10], Step [2600/4608], Loss: 8319.2979
# Epoch [4/10], Step [2700/4608], Loss: 8302.0312
# Epoch [4/10], Step [2800/4608], Loss: 8052.0371
# Epoch [4/10], Step [2900/4608], Loss: 8194.6133
# Epoch [4/10], Step [3000/4608], Loss: 7887.1006
# Epoch [4/10], Step [3100/4608], Loss: 8146.7705
# Epoch [4/10], Step [3200/4608], Loss: 7721.2012
# Epoch [4/10], Step [3300/4608], Loss: 8477.8623
# Epoch [4/10], Step [3400/4608], Loss: 8065.8721
# Epoch [4/10], Step [3500/4608], Loss: 7715.6606
# Epoch [4/10], Step [3600/4608], Loss: 7952.7778
# Epoch [4/10], Step [3700/4608], Loss: 8237.1953
# Epoch [4/10], Step [3800/4608], Loss: 7921.4575
# Epoch [4/10], Step [3900/4608], Loss: 8243.0459
# Epoch [4/10], Step [4000/4608], Loss: 8141.2588
# Epoch [4/10], Step [4100/4608], Loss: 7938.3213
# Epoch [4/10], Step [4200/4608], Loss: 7801.0942
# Epoch [4/10], Step [4300/4608], Loss: 8099.9072
# Epoch [4/10], Step [4400/4608], Loss: 8103.3252
# Epoch [4/10], Step [4500/4608], Loss: 8015.6489
# Epoch [4/10], Step [4600/4608], Loss: 7201.8887
# Epoch [4/10] completed. Avg Loss: 63.9937
# Epoch [5/10], Step [100/4608], Loss: 8716.5127
# Epoch [5/10], Step [200/4608], Loss: 8439.3906
# Epoch [5/10], Step [300/4608], Loss: 8351.7754
# Epoch [5/10], Step [400/4608], Loss: 8611.8672
# Epoch [5/10], Step [500/4608], Loss: 8687.0957
# Epoch [5/10], Step [600/4608], Loss: 8976.4629
# Epoch [5/10], Step [700/4608], Loss: 8923.8271
# Epoch [5/10], Step [800/4608], Loss: 8908.4248
# Epoch [5/10], Step [900/4608], Loss: 8593.9658
# Epoch [5/10], Step [1000/4608], Loss: 8582.2510
# Epoch [5/10], Step [1100/4608], Loss: 8569.4609
# Epoch [5/10], Step [1200/4608], Loss: 8628.9160
# Epoch [5/10], Step [1300/4608], Loss: 8388.6768
# Epoch [5/10], Step [1400/4608], Loss: 8154.4282
# Epoch [5/10], Step [1500/4608], Loss: 8567.2578
# Epoch [5/10], Step [1600/4608], Loss: 8564.7578
# Epoch [5/10], Step [1700/4608], Loss: 8394.3242
# Epoch [5/10], Step [1800/4608], Loss: 8627.2100
# Epoch [5/10], Step [1900/4608], Loss: 8545.0107
# Epoch [5/10], Step [2000/4608], Loss: 8688.2412
# Epoch [5/10], Step [2100/4608], Loss: 8118.5381
# Epoch [5/10], Step [2200/4608], Loss: 8504.2256
# Epoch [5/10], Step [2300/4608], Loss: 8305.7529
# Epoch [5/10], Step [2400/4608], Loss: 8031.1670
# Epoch [5/10], Step [2500/4608], Loss: 8087.1802
# Epoch [5/10], Step [2600/4608], Loss: 7908.7900
# Epoch [5/10], Step [2700/4608], Loss: 8355.2568
# Epoch [5/10], Step [2800/4608], Loss: 8141.1987
# Epoch [5/10], Step [2900/4608], Loss: 8801.3213
# Epoch [5/10], Step [3000/4608], Loss: 8167.7617
# Epoch [5/10], Step [3100/4608], Loss: 8235.7842
# Epoch [5/10], Step [3200/4608], Loss: 8339.1182
# Epoch [5/10], Step [3300/4608], Loss: 8686.2158
# Epoch [5/10], Step [3400/4608], Loss: 8312.7773
# Epoch [5/10], Step [3500/4608], Loss: 8277.0059
# Epoch [5/10], Step [3600/4608], Loss: 8289.7793
# Epoch [5/10], Step [3700/4608], Loss: 8372.1445
# Epoch [5/10], Step [3800/4608], Loss: 8487.8877
# Epoch [5/10], Step [3900/4608], Loss: 8853.5430
# Epoch [5/10], Step [4000/4608], Loss: 8551.3584
# Epoch [5/10], Step [4100/4608], Loss: 8478.3594
# Epoch [5/10], Step [4200/4608], Loss: 8506.1777
# Epoch [5/10], Step [4300/4608], Loss: 8612.7900
# Epoch [5/10], Step [4400/4608], Loss: 8288.0586
# Epoch [5/10], Step [4500/4608], Loss: 8090.6455
# Epoch [5/10], Step [4600/4608], Loss: 8227.8086
# Epoch [5/10] completed. Avg Loss: 65.6228
# Epoch [6/10], Step [100/4608], Loss: 8582.4141
# Epoch [6/10], Step [200/4608], Loss: 8754.1230
# Epoch [6/10], Step [300/4608], Loss: 9055.1064
# Epoch [6/10], Step [400/4608], Loss: 9119.6104
# Epoch [6/10], Step [500/4608], Loss: 8738.6182
# Epoch [6/10], Step [600/4608], Loss: 8708.3145
# Epoch [6/10], Step [700/4608], Loss: 8788.7051
# Epoch [6/10], Step [800/4608], Loss: 8211.1299
# Epoch [6/10], Step [900/4608], Loss: 8697.3525
# Epoch [6/10], Step [1000/4608], Loss: 8523.2266
# Epoch [6/10], Step [1100/4608], Loss: 8644.9756
# Epoch [6/10], Step [1200/4608], Loss: 8614.2051
# Epoch [6/10], Step [1300/4608], Loss: 9056.0596
# Epoch [6/10], Step [1400/4608], Loss: 8764.4268
# Epoch [6/10], Step [1500/4608], Loss: 8953.9844
# Epoch [6/10], Step [1600/4608], Loss: 8770.8496
# Epoch [6/10], Step [1700/4608], Loss: 8232.4209
# Epoch [6/10], Step [1800/4608], Loss: 8582.5625
# Epoch [6/10], Step [1900/4608], Loss: 8497.5781
# Epoch [6/10], Step [2000/4608], Loss: 8378.3428
# Epoch [6/10], Step [2100/4608], Loss: 9000.0879
# Epoch [6/10], Step [2200/4608], Loss: 9323.9785
# Epoch [6/10], Step [2300/4608], Loss: 8808.5752
# Epoch [6/10], Step [2400/4608], Loss: 8835.2012
# Epoch [6/10], Step [2500/4608], Loss: 8685.1123
# Epoch [6/10], Step [2600/4608], Loss: 8936.3018
# Epoch [6/10], Step [2700/4608], Loss: 8375.2441
# Epoch [6/10], Step [2800/4608], Loss: 9114.4346
# Epoch [6/10], Step [2900/4608], Loss: 8681.1680
# Epoch [6/10], Step [3000/4608], Loss: 8770.1514
# Epoch [6/10], Step [3100/4608], Loss: 8957.3418
# Epoch [6/10], Step [3200/4608], Loss: 8873.1523
# Epoch [6/10], Step [3300/4608], Loss: 9075.9180
# Epoch [6/10], Step [3400/4608], Loss: 8521.5215
# Epoch [6/10], Step [3500/4608], Loss: 8852.3037
# Epoch [6/10], Step [3600/4608], Loss: 8135.9561
# Epoch [6/10], Step [3700/4608], Loss: 9143.0557
# Epoch [6/10], Step [3800/4608], Loss: 8702.4023
# Epoch [6/10], Step [3900/4608], Loss: 8486.2324
# Epoch [6/10], Step [4000/4608], Loss: 8611.2402
# Epoch [6/10], Step [4100/4608], Loss: 8544.9668
# Epoch [6/10], Step [4200/4608], Loss: 8609.3574
# Epoch [6/10], Step [4300/4608], Loss: 8267.8320
# Epoch [6/10], Step [4400/4608], Loss: 8508.9072
# Epoch [6/10], Step [4500/4608], Loss: 8257.6982
# Epoch [6/10], Step [4600/4608], Loss: 8686.8594
# Epoch [6/10] completed. Avg Loss: 68.2975
# Epoch [7/10], Step [100/4608], Loss: 8573.2148
# Epoch [7/10], Step [200/4608], Loss: 8449.7148
# Epoch [7/10], Step [300/4608], Loss: 8412.6348
# Epoch [7/10], Step [400/4608], Loss: 8249.3721
# Epoch [7/10], Step [500/4608], Loss: 8879.8604
# Epoch [7/10], Step [600/4608], Loss: 8221.2266
# Epoch [7/10], Step [700/4608], Loss: 8462.6895
# Epoch [7/10], Step [800/4608], Loss: 8722.1387
# Epoch [7/10], Step [900/4608], Loss: 8478.5498
# Epoch [7/10], Step [1000/4608], Loss: 9064.5928
# Epoch [7/10], Step [1100/4608], Loss: 8431.9219
# Epoch [7/10], Step [1200/4608], Loss: 8427.8574
# Epoch [7/10], Step [1300/4608], Loss: 8568.9492
# Epoch [7/10], Step [1400/4608], Loss: 8916.9238
# Epoch [7/10], Step [1500/4608], Loss: 8865.3789
# Epoch [7/10], Step [1600/4608], Loss: 8173.2852
# Epoch [7/10], Step [1700/4608], Loss: 8565.6660
# Epoch [7/10], Step [1800/4608], Loss: 8196.8086
# Epoch [7/10], Step [1900/4608], Loss: 8456.9941
# Epoch [7/10], Step [2000/4608], Loss: 8410.9785
# Epoch [7/10], Step [2100/4608], Loss: 8297.2891
# Epoch [7/10], Step [2200/4608], Loss: 8180.7021
# Epoch [7/10], Step [2300/4608], Loss: 8162.5957
# Epoch [7/10], Step [2400/4608], Loss: 8578.2461
# Epoch [7/10], Step [2500/4608], Loss: 8491.1533
# Epoch [7/10], Step [2600/4608], Loss: 8898.0713
# Epoch [7/10], Step [2700/4608], Loss: 8786.8857
# Epoch [7/10], Step [2800/4608], Loss: 8560.6211
# Epoch [7/10], Step [2900/4608], Loss: 7816.6304
# Epoch [7/10], Step [3000/4608], Loss: 8028.4595
# Epoch [7/10], Step [3100/4608], Loss: 8641.6025
# Epoch [7/10], Step [3200/4608], Loss: 8426.0244
# Epoch [7/10], Step [3300/4608], Loss: 8476.9756
# Epoch [7/10], Step [3400/4608], Loss: 8486.8447
# Epoch [7/10], Step [3500/4608], Loss: 8228.0312
# Epoch [7/10], Step [3600/4608], Loss: 8610.3887
# Epoch [7/10], Step [3700/4608], Loss: 8581.5029
# Epoch [7/10], Step [3800/4608], Loss: 8253.2676
# Epoch [7/10], Step [3900/4608], Loss: 8374.9727
# Epoch [7/10], Step [4000/4608], Loss: 8401.0830
# Epoch [7/10], Step [4100/4608], Loss: 8466.1797
# Epoch [7/10], Step [4200/4608], Loss: 8846.6182
# Epoch [7/10], Step [4300/4608], Loss: 8477.6289
# Epoch [7/10], Step [4400/4608], Loss: 8422.6377
# Epoch [7/10], Step [4500/4608], Loss: 8570.7188
# Epoch [7/10], Step [4600/4608], Loss: 8498.9668
# Epoch [7/10] completed. Avg Loss: 66.1372
# Epoch [8/10], Step [100/4608], Loss: 8236.5928
# Epoch [8/10], Step [200/4608], Loss: 8261.8359
# Epoch [8/10], Step [300/4608], Loss: 8699.3203
# Epoch [8/10], Step [400/4608], Loss: 8454.4189
# Epoch [8/10], Step [500/4608], Loss: 7669.0498
# Epoch [8/10], Step [600/4608], Loss: 7775.2515
# Epoch [8/10], Step [700/4608], Loss: 8026.7993
# Epoch [8/10], Step [800/4608], Loss: 8125.8120
# Epoch [8/10], Step [900/4608], Loss: 8345.5420
# Epoch [8/10], Step [1000/4608], Loss: 8002.0005
# Epoch [8/10], Step [1100/4608], Loss: 8339.4863
# Epoch [8/10], Step [1200/4608], Loss: 8471.9043
# Epoch [8/10], Step [1300/4608], Loss: 8450.2412
# Epoch [8/10], Step [1400/4608], Loss: 7867.2236
# Epoch [8/10], Step [1500/4608], Loss: 8458.9199
# Epoch [8/10], Step [1600/4608], Loss: 8153.2793
# Epoch [8/10], Step [1700/4608], Loss: 8365.6201
# Epoch [8/10], Step [1800/4608], Loss: 8640.3457
# Epoch [8/10], Step [1900/4608], Loss: 8097.6934
# Epoch [8/10], Step [2000/4608], Loss: 7949.8203
# Epoch [8/10], Step [2100/4608], Loss: 8304.4355
# Epoch [8/10], Step [2200/4608], Loss: 8147.1748
# Epoch [8/10], Step [2300/4608], Loss: 7969.4165
# Epoch [8/10], Step [2400/4608], Loss: 8528.8594
# Epoch [8/10], Step [2500/4608], Loss: 7929.9375
# Epoch [8/10], Step [2600/4608], Loss: 7829.4189
# Epoch [8/10], Step [2700/4608], Loss: 8070.1270
# Epoch [8/10], Step [2800/4608], Loss: 8320.9238
# Epoch [8/10], Step [2900/4608], Loss: 8302.5615
# Epoch [8/10], Step [3000/4608], Loss: 8411.7588
# Epoch [8/10], Step [3100/4608], Loss: 8250.6719
# Epoch [8/10], Step [3200/4608], Loss: 7626.5210
# Epoch [8/10], Step [3300/4608], Loss: 7840.1182
# Epoch [8/10], Step [3400/4608], Loss: 8104.5933
# Epoch [8/10], Step [3500/4608], Loss: 8298.7471
# Epoch [8/10], Step [3600/4608], Loss: 8095.2256
# Epoch [8/10], Step [3700/4608], Loss: 7726.6636
# Epoch [8/10], Step [3800/4608], Loss: 8299.9814
# Epoch [8/10], Step [3900/4608], Loss: 8289.6484
# Epoch [8/10], Step [4000/4608], Loss: 8166.0894
# Epoch [8/10], Step [4100/4608], Loss: 8186.0498
# Epoch [8/10], Step [4200/4608], Loss: 8623.1895
# Epoch [8/10], Step [4300/4608], Loss: 8449.9531
# Epoch [8/10], Step [4400/4608], Loss: 8110.0757
# Epoch [8/10], Step [4500/4608], Loss: 8168.8037
# Epoch [8/10], Step [4600/4608], Loss: 8499.8633
# Epoch [8/10] completed. Avg Loss: 64.4653
# Epoch [9/10], Step [100/4608], Loss: 8164.4854
# Epoch [9/10], Step [200/4608], Loss: 8351.9375
# Epoch [9/10], Step [300/4608], Loss: 8419.2930
# Epoch [9/10], Step [400/4608], Loss: 8129.2866
# Epoch [9/10], Step [500/4608], Loss: 7892.4062
# Epoch [9/10], Step [600/4608], Loss: 8421.0225
# Epoch [9/10], Step [700/4608], Loss: 8100.2222
# Epoch [9/10], Step [800/4608], Loss: 8139.3652
# Epoch [9/10], Step [900/4608], Loss: 8203.3086
# Epoch [9/10], Step [1000/4608], Loss: 8236.1504
# Epoch [9/10], Step [1100/4608], Loss: 8063.1768
# Epoch [9/10], Step [1200/4608], Loss: 7981.8755
# Epoch [9/10], Step [1300/4608], Loss: 8246.4414
# Epoch [9/10], Step [1400/4608], Loss: 8107.3857
# Epoch [9/10], Step [1500/4608], Loss: 8362.4170
# Epoch [9/10], Step [1600/4608], Loss: 8239.3887
# Epoch [9/10], Step [1700/4608], Loss: 8182.1821
# Epoch [9/10], Step [1800/4608], Loss: 8051.7373
# Epoch [9/10], Step [1900/4608], Loss: 7998.2793
# Epoch [9/10], Step [2000/4608], Loss: 7920.5225
# Epoch [9/10], Step [2100/4608], Loss: 7877.3936
# Epoch [9/10], Step [2200/4608], Loss: 8301.9863
# Epoch [9/10], Step [2300/4608], Loss: 8010.9946
# Epoch [9/10], Step [2400/4608], Loss: 8465.5176
# Epoch [9/10], Step [2500/4608], Loss: 8818.2354
# Epoch [9/10], Step [2600/4608], Loss: 8110.7349
# Epoch [9/10], Step [2700/4608], Loss: 7794.6665
# Epoch [9/10], Step [2800/4608], Loss: 7912.5630
# Epoch [9/10], Step [2900/4608], Loss: 8142.7959
# Epoch [9/10], Step [3000/4608], Loss: 7857.0400
# Epoch [9/10], Step [3100/4608], Loss: 7776.4487
# Epoch [9/10], Step [3200/4608], Loss: 7785.8604
# Epoch [9/10], Step [3300/4608], Loss: 7792.7441
# Epoch [9/10], Step [3400/4608], Loss: 8063.4102
# Epoch [9/10], Step [3500/4608], Loss: 8347.9434
# Epoch [9/10], Step [3600/4608], Loss: 8113.6533
# Epoch [9/10], Step [3700/4608], Loss: 8629.8281
# Epoch [9/10], Step [3800/4608], Loss: 7958.5947
# Epoch [9/10], Step [3900/4608], Loss: 8205.6855
# Epoch [9/10], Step [4000/4608], Loss: 7989.4268
# Epoch [9/10], Step [4100/4608], Loss: 7847.3984
# Epoch [9/10], Step [4200/4608], Loss: 8250.9482
# Epoch [9/10], Step [4300/4608], Loss: 7808.9727
# Epoch [9/10], Step [4400/4608], Loss: 7978.1733
# Epoch [9/10], Step [4500/4608], Loss: 8197.2900
# Epoch [9/10], Step [4600/4608], Loss: 8170.8047
# Epoch [9/10] completed. Avg Loss: 63.1964
# Epoch [10/10], Step [100/4608], Loss: 7969.3408
# Epoch [10/10], Step [200/4608], Loss: 8320.8857
# Epoch [10/10], Step [300/4608], Loss: 7620.0786
# Epoch [10/10], Step [400/4608], Loss: 7409.8916
# Epoch [10/10], Step [500/4608], Loss: 8218.0244
# Epoch [10/10], Step [600/4608], Loss: 7826.9912
# Epoch [10/10], Step [700/4608], Loss: 7984.4478
# Epoch [10/10], Step [800/4608], Loss: 7979.4629
# Epoch [10/10], Step [900/4608], Loss: 8137.9995
# Epoch [10/10], Step [1000/4608], Loss: 7958.3896
# Epoch [10/10], Step [1100/4608], Loss: 7705.7607
# Epoch [10/10], Step [1200/4608], Loss: 7966.5073
# Epoch [10/10], Step [1300/4608], Loss: 7844.4014
# Epoch [10/10], Step [1400/4608], Loss: 8464.7441
# Epoch [10/10], Step [1500/4608], Loss: 7962.7104
# Epoch [10/10], Step [1600/4608], Loss: 7630.4551
# Epoch [10/10], Step [1700/4608], Loss: 7800.4512
# Epoch [10/10], Step [1800/4608], Loss: 8026.4414
# Epoch [10/10], Step [1900/4608], Loss: 7825.8506
# Epoch [10/10], Step [2000/4608], Loss: 7794.5322
# Epoch [10/10], Step [2100/4608], Loss: 8284.8809
# Epoch [10/10], Step [2200/4608], Loss: 8233.6279
# Epoch [10/10], Step [2300/4608], Loss: 7909.5664
# Epoch [10/10], Step [2400/4608], Loss: 7702.7378
# Epoch [10/10], Step [2500/4608], Loss: 7494.2485
# Epoch [10/10], Step [2600/4608], Loss: 7936.7207
# Epoch [10/10], Step [2700/4608], Loss: 8025.9990
# Epoch [10/10], Step [2800/4608], Loss: 7660.9741
# Epoch [10/10], Step [2900/4608], Loss: 8078.8906
# Epoch [10/10], Step [3000/4608], Loss: 7746.8643
# Epoch [10/10], Step [3100/4608], Loss: 7924.9346
# Epoch [10/10], Step [3200/4608], Loss: 8088.1030
# Epoch [10/10], Step [3300/4608], Loss: 7863.0103
# Epoch [10/10], Step [3400/4608], Loss: 7994.8340
# Epoch [10/10], Step [3500/4608], Loss: 8183.0630
# Epoch [10/10], Step [3600/4608], Loss: 8060.2295
# Epoch [10/10], Step [3700/4608], Loss: 8080.3071
# Epoch [10/10], Step [3800/4608], Loss: 7924.3076
# Epoch [10/10], Step [3900/4608], Loss: 8206.0645
# Epoch [10/10], Step [4000/4608], Loss: 7659.8096
# Epoch [10/10], Step [4100/4608], Loss: 7819.1323
# Epoch [10/10], Step [4200/4608], Loss: 7891.7500
# Epoch [10/10], Step [4300/4608], Loss: 7858.5283
# Epoch [10/10], Step [4400/4608], Loss: 7869.5806
# Epoch [10/10], Step [4500/4608], Loss: 7983.6958
# Epoch [10/10], Step [4600/4608], Loss: 7779.1133
# Epoch [10/10] completed. Avg Loss: 62.0974
# Training complete!

# %%
# --- Quantitative Metrics (Disentanglement) ---

# Updated collect_latent_factors_for_metrics function
# Assuming KBinsDiscretizer is imported if not already.
from sklearn.preprocessing import KBinsDiscretizer
import numpy as np # Ensure numpy is imported
import torch # Ensure torch is imported
from tqdm.auto import tqdm # Ensure tqdm is imported

def collect_latent_factors_for_metrics(model, data_loader, device, num_samples_to_collect=None):
    model.eval()
    all_mu1 = []
    all_latents_values = [] # This will store the continuous ground truth factors

    # dSprites factor names (excluding 'color')
    factor_names = ["color", "shape", "scale", "orientation", "posX", "posY"]
    active_factors_idx = [1, 2, 3, 4, 5] # Exclude color (index 0)

    print(f"Collecting latent representations and ground truth factors for metrics (up to {num_samples_to_collect if num_samples_to_collect else 'all'} samples)...")
    samples_collected = 0
    with torch.no_grad():
        # --- MODIFIED LINE HERE (same as before) ---
        # Assuming your DataLoader yields (image, latents_values, latents_classes)
        for batch_idx, (images, latents_values_batch, latents_classes_batch) in tqdm(enumerate(data_loader), desc="Collecting data for metrics"):
            images = images.to(device)
            # print('mrh= ',images.shape)
            # raise Exception(" MRH ")

            # Extract ground truth factors (continuous values)
            # For dSprites, latents_values_batch tensor structure is usually:
            # latents_values_batch[:, 0] = color (constant)
            # latents_values_batch[:, 1] = shape
            # latents_values_batch[:, 2] = scale
            # latents_values_batch[:, 3] = orientation
            # latents_values_batch[:, 4] = posX
            # latents_values_batch[:, 5] = posY
            # --- CORRECTED LINE BELOW ---
            ground_truth_factors = latents_values_batch.cpu().numpy() # Use the correct variable name

            # Encode the image to get latent means (mu1)
            (_, _, z1_mu), (_, _, z2_mu), (_, _, z3_mu) = model.encode(images)

            # print('z1_mu shape = ',z1_mu.shape)
            # raise Exception(" MRH ")

            all_mu1.append(z1_mu.cpu().numpy())
            all_latents_values.append(ground_truth_factors)

            samples_collected += images.size(0)
            if num_samples_to_collect is not None and samples_collected >= num_samples_to_collect:
                break # Stop collecting once enough samples are gathered

    mu1_for_metrics = np.concatenate(all_mu1, axis=0)
    latents_values_for_metrics = np.concatenate(all_latents_values, axis=0)

    # Ensure we only return up to num_samples_to_collect if specified
    if num_samples_to_collect is not None:
        mu1_for_metrics = mu1_for_metrics[:num_samples_to_collect]
        latents_values_for_metrics = latents_values_for_metrics[:num_samples_to_collect]
        print(f"Collected {mu1_for_metrics.shape[0]} samples for metrics.")

    return mu1_for_metrics, latents_values_for_metrics, factor_names, active_factors_idx
#######################################################
# Function to calculate MIG (Mutual Information Gap)
# Add this import at the top of your script alongside other imports
from joblib import Parallel, delayed

# --- Updated calculate_mig function ---
def calculate_mig(mus, latents_values, factor_names, active_factors_idx,
                  num_bins_for_mi=20): # Added num_bins_for_mi as an argument
    print("\nCalculating MIG (Mutual Information Gap) Score...")

    num_latents = mus.shape[1]
    num_active_factors = len(active_factors_idx)

    # Discretize continuous factors for MI calculation if they are continuous
    # And discretize the latent dimensions
    discretized_mus = np.zeros_like(mus, dtype=int)
    discretized_latents_values = np.zeros_like(latents_values, dtype=int)

    # Discretize latent dimensions (mus)
    print(f"Discretizing latent dimensions into {num_bins_for_mi} bins for MI calculation...")
    for i in tqdm(range(num_latents), desc="Discretizing Latents"):
        latent_data = mus[:, i].reshape(-1, 1)
        # Using KBinsDiscretizer with 'uniform' or 'quantile' can be robust
        discretizer = KBinsDiscretizer(n_bins=num_bins_for_mi, encode='ordinal', strategy='uniform') # 'uniform' or 'quantile'
        discretized_mus[:, i] = discretizer.fit_transform(latent_data).flatten().astype(int)

    # Discretize active ground truth factors
    print(f"Discretizing ground truth factors into {num_bins_for_mi} bins for MI calculation...")
    for j in tqdm(active_factors_idx, desc="Discretizing Factors"):
        factor_data = latents_values[:, j].reshape(-1, 1)
        discretizer = KBinsDiscretizer(n_bins=num_bins_for_mi, encode='ordinal', strategy='uniform') # 'uniform' or 'quantile'
        discretized_latents_values[:, j] = discretizer.fit_transform(factor_data).flatten().astype(int)

    # Calculate mutual information for all pairs (latent_dim, factor)
    mi_matrix = np.zeros((num_latents, num_active_factors))

    print("Calculating MI matrix (this can take a while)...")
    # --- Parallelize the MI calculation loop ---
    # n_jobs=-1 means use all available CPU cores
    # backend='threading' can be faster for numpy/scipy operations
    results = Parallel(n_jobs=-1, verbose=0, backend='threading')(
        delayed(mutual_info_score)(discretized_mus[:, i], discretized_latents_values[:, factor_idx_in_full])
        for i in range(num_latents)
        for factor_idx_in_full in active_factors_idx
    )

    # Populate mi_matrix from results
    k = 0
    for i in range(num_latents):
        for j_idx, factor_idx_in_full in enumerate(active_factors_idx):
            mi_matrix[i, j_idx] = results[k]
            k += 1


    # Calculate MIG score
    mig_scores = []
    for j in range(num_active_factors): # Iterate over ground truth factors
        # Get MI values for the current factor across all latent dimensions
        mi_values_for_factor = mi_matrix[:, j]
        # Sort them in descending order
        sorted_mi = np.sort(mi_values_for_factor)[::-1]

        # Calculate MIG: (MI_1st_most_informative - MI_2nd_most_informative) / MI_1st_most_informative
        if len(sorted_mi) >= 2 and sorted_mi[0] > 0: # Ensure there are at least two values and the max MI is not zero
            mig = (sorted_mi[0] - sorted_mi[1]) / sorted_mi[0]
            mig_scores.append(mig)
        else:
            mig_scores.append(0.0) # Cannot calculate MIG if less than 2 latent dimensions or max MI is zero

    avg_mig_score = np.mean(mig_scores) if mig_scores else 0.0

    report_lines = [
        "\nMIG Score:",
        "--------------------------------------------------",
        f"  Average MIG Score: {avg_mig_score:.4f}",
        "--------------------------------------------------"
    ]
    print("\n".join(report_lines))

    # --- Visualization ---
    fig, ax = plt.subplots(figsize=(num_active_factors * 0.8 + 2, num_latents * 0.5 + 2))
    cax = ax.imshow(mi_matrix, cmap='magma', aspect='auto') # 'magma' or 'viridis' are good for heatmaps
    fig.colorbar(cax, label='Mutual Information')

    ax.set_xticks(np.arange(num_active_factors))
    ax.set_yticks(np.arange(num_latents))

    # Map active_factors_idx back to their original names for labels
    active_factor_names_mapped = [factor_names[idx] for idx in active_factors_idx]
    ax.set_xticklabels(active_factor_names_mapped, rotation=45, ha="right")
    ax.set_yticklabels([f"z{i+1}" for i in range(num_latents)])

    ax.set_xlabel("Ground Truth Factor")
    ax.set_ylabel("Latent Dimension")
    ax.set_title("Mutual Information Heatmap (Latents vs. Factors)")
    fig.tight_layout()
    plt.savefig("mig_mi_heatmap.png")
    plt.close(fig)

    print("Mutual Information Heatmap saved to mig_mi_heatmap.png")

    return avg_mig_score, report_lines

##########################################################
# Function to calculate Linear Regression Disentanglement Score (Simplified Beta-VAE style)
def calculate_linear_disentanglement_score(mus, latents_values, factor_names, active_factors_idx):
    print("\nCalculating Linear Regression Disentanglement Score (R-squared)...")
    num_latents = mus.shape[1]
    num_factors = latents_values.shape[1]

    r2_matrix = np.zeros((num_latents, num_factors))
    p_values_matrix = np.zeros((num_latents, num_factors)) # Not used directly in score, but informative

    results_str = ["\nLinear Regression R-squared Scores:"]
    results_str.append("--------------------------------------------------")
    results_str.append(f"{'Latent Dim':<12} | {' '.join([f'{f:<10}' for f in [factor_names[idx] for idx in active_factors_idx]])}")
    results_str.append("-" * (12 + 3 + len(active_factors_idx) * 11))

    for i in tqdm(range(num_latents), desc="Fitting linear regressors"):
        row_r2_values = []
        for j in active_factors_idx: # Iterate only over active factors
            regressor = LinearRegression()
            regressor.fit(mus[:, i:i+1], latents_values[:, j]) # Predict factor from single latent dim
            r2 = r2_score(latents_values[:, j], regressor.predict(mus[:, i:i+1]))
            r2_matrix[i, j] = r2 if not np.isnan(r2) else 0.0 # Handle NaN if regression fails (e.g., constant latent dim)
            row_r2_values.append(f'{r2_matrix[i, j]:<10.4f}')
        results_str.append(f"{f'Latent {i}':<12} | {' '.join(row_r2_values)}")

    # Calculate disentanglement score:
    # For each ground truth factor, find the latent dimension that explains it best (highest R2).
    # The score is often defined as the average of the maximum R2 for each factor.
    # Alternatively, for *disentanglement*, you look for high R2 for one factor, low for others.
    # A common beta-VAE style score is: for each factor, find the latent dimension with max R2,
    # then average these max R2s.
    factor_disentanglement_scores = []
    disentanglement_summary = ["\nDisentanglement Summary (Per Ground Truth Factor):"]
    disentanglement_summary.append("--------------------------------------------------")

    for j in active_factors_idx:
        max_r2_for_factor = -1.0
        best_latent_dim = -1
        for i in range(num_latents):
            if r2_matrix[i, j] > max_r2_for_factor:
                max_r2_for_factor = r2_matrix[i, j]
                best_latent_dim = i
        factor_disentanglement_scores.append(max_r2_for_factor)
        disentanglement_summary.append(f"  {factor_names[j]}: Best explained by Latent {best_latent_dim} (R2: {max_r2_for_factor:.4f})")

    avg_disentanglement_score = np.mean(factor_disentanglement_scores) if factor_disentanglement_scores else 0.0
    disentanglement_summary.append("--------------------------------------------------")
    disentanglement_summary.append(f"Average Disentanglement Score (Max R2 per factor): {avg_disentanglement_score:.4f}")

    print("\n".join(results_str))
    print("\n".join(disentanglement_summary))

    # Optional: Save R2 matrix to a file
    np.save(os.path.join('./metrics_hdvae', 'linear_r2_matrix.npy'), r2_matrix)
    print(f"Saved R2 matrix to {os.path.join('./metrics_hdvae', 'linear_r2_matrix.npy')}")

    # Optional: Save and plot R2 matrix as a heatmap
    plt.figure(figsize=(10, 8))
    plt.imshow(r2_matrix[:, active_factors_idx].T, cmap='magma', aspect='auto', vmin=0, vmax=1) # Transposed
    plt.colorbar(label='R-squared Score')
    plt.xlabel('Latent Dimensions (z1)')
    plt.ylabel('Ground Truth Factors')
    plt.title('R-squared (R2) between Latent Dimensions and Ground Truth Factors')
    plt.xticks(np.arange(num_latents), labels=[f'z{i}' for i in range(num_latents)], rotation=90)
    plt.yticks(np.arange(len(active_factors_idx)), labels=[factor_names[i] for i in active_factors_idx])
    plt.tight_layout()
    plt.savefig(os.path.join('./metrics_hdvae', 'linear_r2_heatmap.png'))
    plt.show()
    print(f"Saved R2 heatmap to {os.path.join('./metrics_hdvae', 'linear_r2_heatmap.png')}")

    return avg_disentanglement_score, results_str, disentanglement_summary
########################
# Updated calculate_dci function
from sklearn.ensemble import RandomForestClassifier # For informativeness, disentanglement, completeness
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, mutual_info_score, f1_score
from sklearn.preprocessing import KBinsDiscretizer # Ensure this is imported for discretization

def calculate_dci(mus, latents_values, factor_names, active_factors_idx,
                  test_size=0.2, random_state=42):
    print("\nCalculating DCI (Disentanglement, Completeness, Informativeness) Score...")

    # We'll use the provided mus and latents_values.
    # Note: For dSprites' continuous factors, we need to adapt the classification approach.
    # A common approach is to discretize the factors or use a regressor.
    # For a general DCI implementation that aims for "classification accuracy" like behavior,
    # we can discretize the factors. However, the original DCI paper often uses
    # regressors or assumes discrete factors.
    # Let's adapt for continuous factors by treating them as regression tasks
    # and using RandomForestRegressor, then assessing "informativeness" as R2.
    # For disentanglement/completeness, we'll still use a classifier,
    # meaning we'll discretize the ground truth factors.

    # Discretize continuous ground truth factors for DCI classification component
    # This is a critical step for dSprites as its factors are continuous.
    # You can adjust num_bins as needed. Higher bins means more granular factors.
    num_bins_for_factors = 10 # For shape, scale, orientation, posX, posY
    discretized_latents_values = np.zeros_like(latents_values, dtype=int)
    factor_discretizers = {}

    print(f"Discretizing ground truth factors into {num_bins_for_factors} bins for DCI...")
    for j in active_factors_idx:
        factor_data = latents_values[:, j].reshape(-1, 1)
        # Use KBinsDiscretizer to discretize each continuous factor
        # 'quantile' strategy works well for non-uniform distributions
        discretizer = KBinsDiscretizer(n_bins=num_bins_for_factors, encode='ordinal', strategy='quantile')
        discretized_latents_values[:, j] = discretizer.fit_transform(factor_data).flatten().astype(int)
        factor_discretizers[j] = discretizer # Store if needed for inverse transform or checking bins

    # Filter to only active factors for X and y for classification
    mus_active = mus
    discretized_latents_active = discretized_latents_values[:, active_factors_idx]

    num_latents = mus_active.shape[1]
    num_active_factors = len(active_factors_idx)

    # Initialize results
    informativeness_scores = []
    disentanglement_scores = np.zeros((num_active_factors, num_latents))
    completeness_scores = np.zeros((num_active_factors, num_latents))

    # Split data into training and test sets for the classifiers
    X_train, X_test, y_train_factors, y_test_factors = train_test_split(
        mus_active, discretized_latents_active, test_size=test_size, random_state=random_state
    )

    print("Training RandomForestClassifiers for each ground truth factor...")
    # 1. Informativeness, Disentanglement, Completeness Calculation
    # For each ground truth factor, train a classifier to predict it from the latent representation
    # and assess how much each latent dimension contributes.
    for i in tqdm(range(num_active_factors), desc="DCI per factor"):
        factor_idx_in_full = active_factors_idx[i]
        y_train_factor = y_train_factors[:, i]
        y_test_factor = y_test_factors[:, i]

        # Classifier for the i-th ground truth factor
        # Adjust max_depth, n_estimators as needed. Lower max_depth for simpler models.
        # Ensure we have enough samples per class if some bins are sparse
        min_samples_leaf = 5 # Avoid overfitting by requiring more samples per leaf
        if len(np.unique(y_train_factor)) > 1: # Ensure there's more than one class
            classifier = RandomForestClassifier(n_estimators=100, random_state=random_state,
                                                min_samples_leaf=min_samples_leaf)
            classifier.fit(X_train, y_train_factor)

            # Informativeness (Accuracy on test set)
            y_pred = classifier.predict(X_test)
            informativeness = accuracy_score(y_test_factor, y_pred)
            informativeness_scores.append(informativeness)

            # Feature importance for disentanglement and completeness
            # Normalized feature importances from the RandomForestClassifier
            importance_scores = classifier.feature_importances_

            # Disentanglement: for each ground truth factor, how concentrated is its
            # importance on a single latent dimension?
            # Higher importance for one dimension, lower for others.
            if np.sum(importance_scores) > 0:
                disentanglement_scores[i, :] = importance_scores / np.sum(importance_scores)
            else:
                disentanglement_scores[i, :] = 0

            # Completeness: (Calculated from importance scores of the same classifier)
            # This is handled in the final calculation, but it's about how many latent
            # dimensions are important for a single factor.
        else: # Factor has only one unique value in training, cannot train classifier
            informativeness_scores.append(0)
            disentanglement_scores[i, :] = 0


    # DCI Score Calculations
    # ---------------------

    # Informativeness: Average informativeness (accuracy) across all factors
    mean_informativeness = np.mean(informativeness_scores)

    # Disentanglement: For each ground truth factor f,
    # find its importance distribution over latent dimensions.
    # The score is 1 - (sum of entropies of these distributions).
    # If all importance is concentrated on one latent dimension (low entropy), score is high.
    disentanglement = 0.0
    for i in range(num_active_factors): # For each ground truth factor
        if np.sum(disentanglement_scores[i, :]) > 0:
            # Normalize to sum to 1 to treat as probability distribution for entropy
            p_i = disentanglement_scores[i, :] / np.sum(disentanglement_scores[i, :])
            # Use negative sum(p*log(p)) for entropy. Add small epsilon for log(0)
            entropy_i = -np.sum(p_i * np.log(p_i + 1e-10))
            # Max possible entropy is log(num_latents) for uniform distribution
            max_entropy = np.log(num_latents + 1e-10) # Add epsilon to avoid log(0) if num_latents is 0
            if max_entropy > 0:
                disentanglement += (1 - entropy_i / max_entropy)
            else:
                disentanglement += 1.0 # If only one latent dim, it's perfectly disentangled by default
    mean_disentanglement = disentanglement / num_active_factors if num_active_factors > 0 else 0.0


    # Completeness: For each latent dimension z,
    # find its importance distribution over ground truth factors.
    # The score is 1 - (sum of entropies of these distributions).
    # If a latent dimension is important for only one factor (low entropy), score is high.
    completeness = 0.0
    # Transpose disentanglement_scores to get (latent_dim, factor_idx)
    # This is effectively the importance of latent_dim for factor_idx
    completeness_importance_matrix = disentanglement_scores.T # (num_latents, num_active_factors)

    for j in range(num_latents): # For each latent dimension
        if np.sum(completeness_importance_matrix[j, :]) > 0:
            # Normalize to sum to 1 to treat as probability distribution for entropy
            p_j = completeness_importance_matrix[j, :] / np.sum(completeness_importance_matrix[j, :])
            entropy_j = -np.sum(p_j * np.log(p_j + 1e-10))
            max_entropy = np.log(num_active_factors + 1e-10) # Max possible entropy for uniform distribution over factors
            if max_entropy > 0:
                completeness += (1 - entropy_j / max_entropy)
            else:
                completeness += 1.0 # If only one active factor, it's perfectly complete by default
    mean_completeness = completeness / num_latents if num_latents > 0 else 0.0


    results_str = [
        "\nDCI Scores:",
        "--------------------------------------------------",
        f"  Informativeness: {mean_informativeness:.4f}",
        f"  Disentanglement: {mean_disentanglement:.4f}",
        f"  Completeness:    {mean_completeness:.4f}",
        "--------------------------------------------------"
    ]
    print("\n".join(results_str))

    return mean_informativeness, mean_disentanglement, mean_completeness, results_str



##########

# %%
# HDVAE
# --- Run Metrics After Training ---
print("\n" + "="*50)
print("Starting Quantitative Metrics Evaluation")
print("="*50 + "\n")

# Define the number of samples for metrics calculation to speed it up.
# For dSprites, 10,000 to 20,000 samples is usually sufficient.
# Set to None to use all available samples in the test_dataset.
NUM_SAMPLES_FOR_METRICS = 20000

# Collect data for metrics (using test_loader, but now limited by NUM_SAMPLES_FOR_METRICS)
# It's good to keep batch_size for the data_loader relatively high (e.g., 256)
# to make efficient use of the GPU during the forward pass.
metrics_data_loader = torch.utils.data.DataLoader(dataset=test_dataset, batch_size=256, shuffle=False)


######################################
# model=model_HDVAE

mu1_for_metrics, latents_values_for_metrics, factor_names, active_factors_idx = \
    collect_latent_factors_for_metrics(model, metrics_data_loader, device,
                                       num_samples_to_collect=NUM_SAMPLES_FOR_METRICS)

# Calculate and print MIG
mig_avg_score, mig_report = calculate_mig(mu1_for_metrics, latents_values_for_metrics, factor_names, active_factors_idx)

# Calculate and print Linear Regression Disentanglement Score
linear_disentanglement_avg_score, linear_r2_report, linear_disentanglement_summary = \
    calculate_linear_disentanglement_score(mu1_for_metrics, latents_values_for_metrics, factor_names, active_factors_idx)

# Calculate and print DCI
dci_informativeness, dci_disentanglement, dci_completeness, dci_report = \
    calculate_dci(mu1_for_metrics, latents_values_for_metrics, factor_names, active_factors_idx)

print("\n" + "="*50)
print("Quantitative Metrics Evaluation Complete")
print("="*50 + "\n")
# Out:
# ==================================================
# Starting Quantitative Metrics Evaluation
# ==================================================
#
# Collecting latent representations and ground truth factors for metrics (up to 20000 samples)...
# Collecting data for metrics: 0it [00:00, ?it/s]
# Collected 20000 samples for metrics.
#
# Calculating MIG (Mutual Information Gap) Score...
# Discretizing latent dimensions into 20 bins for MI calculation...
# Discretizing Latents:   0%|          | 0/64 [00:00<?, ?it/s]
# Discretizing ground truth factors into 20 bins for MI calculation...
# Discretizing Factors:   0%|          | 0/5 [00:00<?, ?it/s]
# Calculating MI matrix (this can take a while)...
#
# MIG Score:
# --------------------------------------------------
#   Average MIG Score: 0.3964
# --------------------------------------------------
# Mutual Information Heatmap saved to mig_mi_heatmap.png
#
# Calculating Linear Regression Disentanglement Score (R-squared)...
# Fitting linear regressors:   0%|          | 0/64 [00:00<?, ?it/s]
# Linear Regression R-squared Scores:
# --------------------------------------------------
# Latent Dim   | shape      scale      orientation posX       posY
# ----------------------------------------------------------------------
# Latent 0     | 0.0012     0.0044     0.0000     0.0000     0.0050
# Latent 1     | 0.0008     0.0069     0.0016     0.3477     0.0020
# Latent 2     | 0.0000     0.0001     0.0002     0.0026     0.0001
# Latent 3     | 0.0015     0.0028     0.0048     0.0925     0.1291
# Latent 4     | 0.0010     0.0027     0.0004     0.0538     0.1781
# Latent 5     | 0.0003     0.0017     0.0000     0.0000     0.0005
# Latent 6     | 0.0025     0.0062     0.0001     0.0697     0.5766
# Latent 7     | 0.0011     0.0098     0.0001     0.0239     0.0178
# Latent 8     | 0.0001     0.0000     0.0000     0.0000     0.0053
# Latent 9     | 0.0000     0.0000     0.0001     0.0000     0.0005
# Latent 10    | 0.0003     0.0046     0.0000     0.0022     0.0004
# Latent 11    | 0.0009     0.0037     0.0000     0.0033     0.0005
# Latent 12    | 0.0001     0.0003     0.0000     0.0023     0.0003
# Latent 13    | 0.0002     0.0012     0.0000     0.0058     0.0006
# Latent 14    | 0.0007     0.0047     0.0000     0.0034     0.0000
# Latent 15    | 0.0002     0.0001     0.0000     0.0002     0.0024
# Latent 16    | 0.0002     0.0035     0.0000     0.0043     0.0004
# Latent 17    | 0.0003     0.0021     0.0000     0.0007     0.0007
# Latent 18    | 0.0000     0.0003     0.0000     0.0009     0.0009
# Latent 19    | 0.0002     0.0005     0.0000     0.0006     0.0000
# Latent 20    | 0.0009     0.0004     0.0002     0.1586     0.2755
# Latent 21    | 0.0000     0.0000     0.0002     0.0002     0.0012
# Latent 22    | 0.0000     0.0003     0.0002     0.0002     0.0014
# Latent 23    | 0.0001     0.0001     0.0000     0.0060     0.0023
# Latent 24    | 0.0000     0.0004     0.0002     0.0017     0.0001
# Latent 25    | 0.0004     0.0034     0.0000     0.0397     0.1417
# Latent 26    | 0.0002     0.0000     0.0000     0.0024     0.0027
# Latent 27    | 0.0028     0.0128     0.0004     0.4323     0.0662
# Latent 28    | 0.0000     0.0004     0.0000     0.0048     0.0000
# Latent 29    | 0.0003     0.0022     0.0000     0.0004     0.0001
# Latent 30    | 0.0000     0.0003     0.0001     0.0020     0.0033
# Latent 31    | 0.0000     0.0006     0.0000     0.0015     0.0000
# Latent 32    | 0.0004     0.0018     0.0000     0.0002     0.0000
# Latent 33    | 0.0001     0.0001     0.0000     0.0014     0.0001
# Latent 34    | 0.0000     0.0000     0.0000     0.0000     0.0009
# Latent 35    | 0.0000     0.0001     0.0001     0.0013     0.0041
# Latent 36    | 0.0000     0.0004     0.0000     0.0437     0.1256
# Latent 37    | 0.0947     0.4783     0.0005     0.1286     0.0087
# Latent 38    | 0.0000     0.0001     0.0000     0.0000     0.0001
# Latent 39    | 0.0000     0.0001     0.0000     0.0025     0.0000
# Latent 40    | 0.0000     0.0006     0.0003     0.0011     0.0025
# Latent 41    | 0.0001     0.0014     0.0002     0.0000     0.0002
# Latent 42    | 0.0001     0.0001     0.0000     0.0032     0.0003
# Latent 43    | 0.0004     0.0004     0.0001     0.0000     0.0020
# Latent 44    | 0.0000     0.0005     0.0000     0.0005     0.0013
# Latent 45    | 0.0099     0.0355     0.0015     0.0023     0.0941
# Latent 46    | 0.0000     0.0000     0.0000     0.0002     0.0002
# Latent 47    | 0.0000     0.0002     0.0000     0.0004     0.0019
# Latent 48    | 0.0009     0.0063     0.0000     0.0006     0.0024
# Latent 49    | 0.0000     0.0003     0.0000     0.0002     0.0010
# Latent 50    | 0.0002     0.0008     0.0001     0.0011     0.0019
# Latent 51    | 0.0002     0.0012     0.0000     0.0000     0.0006
# Latent 52    | 0.0000     0.0001     0.0000     0.0011     0.0002
# Latent 53    | 0.0000     0.0002     0.0000     0.0013     0.0005
# Latent 54    | 0.0003     0.0000     0.0001     0.0555     0.1436
# Latent 55    | 0.0080     0.0296     0.0008     0.1810     0.0213
# Latent 56    | 0.0001     0.0019     0.0000     0.0012     0.0004
# Latent 57    | 0.0001     0.0004     0.0000     0.0001     0.0000
# Latent 58    | 0.0000     0.0001     0.0000     0.0025     0.0011
# Latent 59    | 0.0003     0.0019     0.0000     0.0001     0.0000
# Latent 60    | 0.0003     0.0001     0.0000     0.1561     0.3155
# Latent 61    | 0.0003     0.0053     0.0001     0.0000     0.0021
# Latent 62    | 0.0002     0.0008     0.0001     0.0021     0.0013
# Latent 63    | 0.0028     0.0074     0.0001     0.2761     0.1890
#
# Disentanglement Summary (Per Ground Truth Factor):
# --------------------------------------------------
#   shape: Best explained by Latent 37 (R2: 0.0947)
#   scale: Best explained by Latent 37 (R2: 0.4783)
#   orientation: Best explained by Latent 3 (R2: 0.0048)
#   posX: Best explained by Latent 27 (R2: 0.4323)
#   posY: Best explained by Latent 6 (R2: 0.5766)
# --------------------------------------------------
# Average Disentanglement Score (Max R2 per factor): 0.3173
# Saved R2 matrix to ./metrics_hdvae/linear_r2_matrix.npy
# Saved R2 heatmap to ./metrics_hdvae/linear_r2_heatmap.png
#
# Calculating DCI (Disentanglement, Completeness, Informativeness) Score...
# Discretizing ground truth factors into 10 bins for DCI...
# Training RandomForestClassifiers for each ground truth factor...
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_discretization.py:306: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 0 are removed. Consider decreasing the number of bins.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_discretization.py:306: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 0 are removed. Consider decreasing the number of bins.
#   warnings.warn(
# DCI per factor:   0%|          | 0/5 [00:00<?, ?it/s]
# DCI Scores:
# --------------------------------------------------
#   Informativeness: 0.6248
#   Disentanglement: 0.1106
#   Completeness:    0.0321
# --------------------------------------------------
#
# ==================================================
# Quantitative Metrics Evaluation Complete
# ==================================================

# %%
all_model_results = []
model_name = "HDVAE"
model_results = {
    "Model": model_name,
    "MIG Score": mig_avg_score,
    "DCI Informativeness": dci_informativeness,
    "DCI Disentanglement": dci_disentanglement,
    "DCI Completeness": dci_completeness,
    "Average R2 Disentanglement": linear_disentanglement_avg_score,
}
all_model_results.append(model_results)
print(f"Finished evaluating {model_name}.")
# Out:
# Finished evaluating HDVAE.

# %%
#
# V4: Beta-VAE for comparison
class BetaVAE(nn.Module):
    def __init__(self, image_size, z_dim):
        super(BetaVAE, self).__init__()
        self.image_size = image_size
        self.z_dim = z_dim

        # Encoder (identical to Vanilla VAE and HDVAE's encoder_x_to_z1 part)
        self.encoder = nn.Sequential(
            nn.Linear(image_size, 512),
            nn.ReLU(),
            nn.Linear(512, 256),
            nn.ReLU(),
            nn.Linear(256, 128)
        )
        self.fc_mu = nn.Linear(128, z_dim)
        self.fc_logvar = nn.Linear(128, z_dim)

        # Decoder (identical to Vanilla VAE and HDVAE's decoder_z1_to_x part)
        self.decoder = nn.Sequential(
            nn.Linear(z_dim, 256),
            nn.ReLU(),
            nn.Linear(256, 512),
            nn.ReLU(),
            nn.Linear(512, image_size),
            nn.Sigmoid()
        )

    def reparameterize(self, mu, log_var):
        std = torch.exp(0.5 * log_var)
        eps = torch.randn_like(std)
        return mu + eps * std

    def forward(self, x):
        # Encode
        h = self.encoder(x.view(-1, self.image_size))
        # print('mrh x= ',x.shape)
        # print('mrh x= ',x.view(-1, self.image_size).shape)
        # print('mrh= ',h.shape)
        # raise Exception(" MRH ")
        mu = self.fc_mu(h)
        log_var = self.fc_logvar(h)
        z = self.reparameterize(mu, log_var)

        # Decode
        recon_x = self.decoder(z)
        return recon_x, mu, log_var


# --- Loss Function for Vanilla VAE ---
def loss_function_beta_vae(recon_x, x, mu, log_var, beta): # beta is now a required argument
    BCE = F.binary_cross_entropy(recon_x, x.view(-1, image_size), reduction='sum')
    KLD = -0.5 * torch.sum(1 + log_var - mu.pow(2) - log_var.exp())
    return BCE + beta * KLD



beta_vae_z_dim = z1_dim # Still 64

# Choose a beta value. Common values are 4 or 8 to encourage disentanglement.
# Let's start with 4.0. You can experiment with this.
beta_vae_beta_value = 4.0

beta_vae_model_ = BetaVAE(image_size, beta_vae_z_dim).to(device)
beta_vae_optimizer = torch.optim.Adam(beta_vae_model_.parameters(), lr=learning_rate)

#print("\n--- Beta-VAE Model ---")
#print(beta_vae_model)

# --- Training Loop for Beta-VAE ---
print(f"\nStarting Beta-VAE training with beta = {beta_vae_beta_value}...")
for epoch in range(num_epochs): # Using the same num_epochs as HDVAE for direct comparison
    beta_vae_model_.train()
    total_loss = 0
    for i, (images, _,_) in enumerate(train_loader):
        images = images.to(device)

        recon_images, mu, log_var = beta_vae_model_(images)

        # Here we pass the fixed beta_vae_beta_value
        loss = loss_function_beta_vae(recon_images, images, mu, log_var, beta=beta_vae_beta_value)

        beta_vae_optimizer.zero_grad()
        loss.backward()
        beta_vae_optimizer.step()

        total_loss += loss.item()

        if (i+1) % 100 == 0:
            print(f"Beta-VAE - Epoch [{epoch+1}/{num_epochs}], Step [{i+1}/{len(train_loader)}], Loss: {loss.item():.4f}")

    avg_loss = total_loss / len(train_loader.dataset)
    print(f"Beta-VAE - Epoch [{epoch+1}/{num_epochs}]")

print("Training complete!")
# Out:
# Starting Beta-VAE training with beta = 4.0...
# Beta-VAE - Epoch [1/10], Step [100/4608], Loss: 66301.2891
# Beta-VAE - Epoch [1/10], Step [200/4608], Loss: 39506.2031
# Beta-VAE - Epoch [1/10], Step [300/4608], Loss: 33446.8750
# Beta-VAE - Epoch [1/10], Step [400/4608], Loss: 30578.1133
# Beta-VAE - Epoch [1/10], Step [500/4608], Loss: 28591.1582
# Beta-VAE - Epoch [1/10], Step [600/4608], Loss: 26160.8105
# Beta-VAE - Epoch [1/10], Step [700/4608], Loss: 24217.6914
# Beta-VAE - Epoch [1/10], Step [800/4608], Loss: 24568.0508
# Beta-VAE - Epoch [1/10], Step [900/4608], Loss: 22395.0918
# Beta-VAE - Epoch [1/10], Step [1000/4608], Loss: 21718.8027
# Beta-VAE - Epoch [1/10], Step [1100/4608], Loss: 21948.6328
# Beta-VAE - Epoch [1/10], Step [1200/4608], Loss: 21241.5273
# Beta-VAE - Epoch [1/10], Step [1300/4608], Loss: 20758.7129
# Beta-VAE - Epoch [1/10], Step [1400/4608], Loss: 20892.3477
# Beta-VAE - Epoch [1/10], Step [1500/4608], Loss: 20392.0469
# Beta-VAE - Epoch [1/10], Step [1600/4608], Loss: 21199.5840
# Beta-VAE - Epoch [1/10], Step [1700/4608], Loss: 19556.7734
# Beta-VAE - Epoch [1/10], Step [1800/4608], Loss: 19897.2246
# Beta-VAE - Epoch [1/10], Step [1900/4608], Loss: 20680.4629
# Beta-VAE - Epoch [1/10], Step [2000/4608], Loss: 20354.6387
# Beta-VAE - Epoch [1/10], Step [2100/4608], Loss: 19186.1953
# Beta-VAE - Epoch [1/10], Step [2200/4608], Loss: 20357.6035
# Beta-VAE - Epoch [1/10], Step [2300/4608], Loss: 18992.5938
# Beta-VAE - Epoch [1/10], Step [2400/4608], Loss: 19206.7891
# Beta-VAE - Epoch [1/10], Step [2500/4608], Loss: 20037.2617
# Beta-VAE - Epoch [1/10], Step [2600/4608], Loss: 19974.9082
# Beta-VAE - Epoch [1/10], Step [2700/4608], Loss: 19232.2676
# Beta-VAE - Epoch [1/10], Step [2800/4608], Loss: 19187.4492
# Beta-VAE - Epoch [1/10], Step [2900/4608], Loss: 18947.5996
# Beta-VAE - Epoch [1/10], Step [3000/4608], Loss: 19409.4062
# Beta-VAE - Epoch [1/10], Step [3100/4608], Loss: 18257.0918
# Beta-VAE - Epoch [1/10], Step [3200/4608], Loss: 18524.4980
# Beta-VAE - Epoch [1/10], Step [3300/4608], Loss: 19466.1836
# Beta-VAE - Epoch [1/10], Step [3400/4608], Loss: 18802.8184
# Beta-VAE - Epoch [1/10], Step [3500/4608], Loss: 19088.6992
# Beta-VAE - Epoch [1/10], Step [3600/4608], Loss: 18947.0781
# Beta-VAE - Epoch [1/10], Step [3700/4608], Loss: 18323.3730
# Beta-VAE - Epoch [1/10], Step [3800/4608], Loss: 19707.7695
# Beta-VAE - Epoch [1/10], Step [3900/4608], Loss: 18079.8809
# Beta-VAE - Epoch [1/10], Step [4000/4608], Loss: 18715.8320
# Beta-VAE - Epoch [1/10], Step [4100/4608], Loss: 19141.6758
# Beta-VAE - Epoch [1/10], Step [4200/4608], Loss: 18873.3516
# Beta-VAE - Epoch [1/10], Step [4300/4608], Loss: 18705.0156
# Beta-VAE - Epoch [1/10], Step [4400/4608], Loss: 19309.7148
# Beta-VAE - Epoch [1/10], Step [4500/4608], Loss: 18582.5508
# Beta-VAE - Epoch [1/10], Step [4600/4608], Loss: 18026.3203
# Beta-VAE - Epoch [1/10]
# Beta-VAE - Epoch [2/10], Step [100/4608], Loss: 19601.5801
# Beta-VAE - Epoch [2/10], Step [200/4608], Loss: 17852.0957
# Beta-VAE - Epoch [2/10], Step [300/4608], Loss: 17472.4375
# Beta-VAE - Epoch [2/10], Step [400/4608], Loss: 18653.3789
# Beta-VAE - Epoch [2/10], Step [500/4608], Loss: 18292.1387
# Beta-VAE - Epoch [2/10], Step [600/4608], Loss: 19287.9414
# Beta-VAE - Epoch [2/10], Step [700/4608], Loss: 19288.1543
# Beta-VAE - Epoch [2/10], Step [800/4608], Loss: 18213.0723
# Beta-VAE - Epoch [2/10], Step [900/4608], Loss: 18358.8438
# Beta-VAE - Epoch [2/10], Step [1000/4608], Loss: 18529.9883
# Beta-VAE - Epoch [2/10], Step [1100/4608], Loss: 19021.9785
# Beta-VAE - Epoch [2/10], Step [1200/4608], Loss: 17985.3418
# Beta-VAE - Epoch [2/10], Step [1300/4608], Loss: 17728.1680
# Beta-VAE - Epoch [2/10], Step [1400/4608], Loss: 18462.1289
# Beta-VAE - Epoch [2/10], Step [1500/4608], Loss: 18181.1953
# Beta-VAE - Epoch [2/10], Step [1600/4608], Loss: 18739.2617
# Beta-VAE - Epoch [2/10], Step [1700/4608], Loss: 18848.8828
# Beta-VAE - Epoch [2/10], Step [1800/4608], Loss: 17678.2812
# Beta-VAE - Epoch [2/10], Step [1900/4608], Loss: 18064.6094
# Beta-VAE - Epoch [2/10], Step [2000/4608], Loss: 19055.2070
# Beta-VAE - Epoch [2/10], Step [2100/4608], Loss: 18118.3711
# Beta-VAE - Epoch [2/10], Step [2200/4608], Loss: 19475.7109
# Beta-VAE - Epoch [2/10], Step [2300/4608], Loss: 18161.0410
# Beta-VAE - Epoch [2/10], Step [2400/4608], Loss: 18756.2793
# Beta-VAE - Epoch [2/10], Step [2500/4608], Loss: 17923.2070
# Beta-VAE - Epoch [2/10], Step [2600/4608], Loss: 18031.2578
# Beta-VAE - Epoch [2/10], Step [2700/4608], Loss: 18359.3555
# Beta-VAE - Epoch [2/10], Step [2800/4608], Loss: 18052.7891
# Beta-VAE - Epoch [2/10], Step [2900/4608], Loss: 17706.5195
# Beta-VAE - Epoch [2/10], Step [3000/4608], Loss: 17848.7188
# Beta-VAE - Epoch [2/10], Step [3100/4608], Loss: 18449.5137
# Beta-VAE - Epoch [2/10], Step [3200/4608], Loss: 17856.9785
# Beta-VAE - Epoch [2/10], Step [3300/4608], Loss: 17511.8281
# Beta-VAE - Epoch [2/10], Step [3400/4608], Loss: 17584.2812
# Beta-VAE - Epoch [2/10], Step [3500/4608], Loss: 18335.6016
# Beta-VAE - Epoch [2/10], Step [3600/4608], Loss: 17723.8750
# Beta-VAE - Epoch [2/10], Step [3700/4608], Loss: 17869.5723
# Beta-VAE - Epoch [2/10], Step [3800/4608], Loss: 18284.5449
# Beta-VAE - Epoch [2/10], Step [3900/4608], Loss: 17654.1387
# Beta-VAE - Epoch [2/10], Step [4000/4608], Loss: 17629.1953
# Beta-VAE - Epoch [2/10], Step [4100/4608], Loss: 17848.4824
# Beta-VAE - Epoch [2/10], Step [4200/4608], Loss: 17320.0117
# Beta-VAE - Epoch [2/10], Step [4300/4608], Loss: 17502.1406
# Beta-VAE - Epoch [2/10], Step [4400/4608], Loss: 17698.8438
# Beta-VAE - Epoch [2/10], Step [4500/4608], Loss: 17396.9805
# Beta-VAE - Epoch [2/10], Step [4600/4608], Loss: 17649.2734
# Beta-VAE - Epoch [2/10]
# Beta-VAE - Epoch [3/10], Step [100/4608], Loss: 17528.5176
# Beta-VAE - Epoch [3/10], Step [200/4608], Loss: 17573.7617
# Beta-VAE - Epoch [3/10], Step [300/4608], Loss: 17953.3867
# Beta-VAE - Epoch [3/10], Step [400/4608], Loss: 17118.9941
# Beta-VAE - Epoch [3/10], Step [500/4608], Loss: 17369.8281
# Beta-VAE - Epoch [3/10], Step [600/4608], Loss: 16841.5410
# Beta-VAE - Epoch [3/10], Step [700/4608], Loss: 16406.9961
# Beta-VAE - Epoch [3/10], Step [800/4608], Loss: 17272.5879
# Beta-VAE - Epoch [3/10], Step [900/4608], Loss: 16718.6777
# Beta-VAE - Epoch [3/10], Step [1000/4608], Loss: 17388.2070
# Beta-VAE - Epoch [3/10], Step [1100/4608], Loss: 17565.5312
# Beta-VAE - Epoch [3/10], Step [1200/4608], Loss: 17716.1523
# Beta-VAE - Epoch [3/10], Step [1300/4608], Loss: 17635.3711
# Beta-VAE - Epoch [3/10], Step [1400/4608], Loss: 17488.1055
# Beta-VAE - Epoch [3/10], Step [1500/4608], Loss: 17610.2852
# Beta-VAE - Epoch [3/10], Step [1600/4608], Loss: 17201.5703
# Beta-VAE - Epoch [3/10], Step [1700/4608], Loss: 17272.6836
# Beta-VAE - Epoch [3/10], Step [1800/4608], Loss: 17424.6562
# Beta-VAE - Epoch [3/10], Step [1900/4608], Loss: 17069.6855
# Beta-VAE - Epoch [3/10], Step [2000/4608], Loss: 16993.1875
# Beta-VAE - Epoch [3/10], Step [2100/4608], Loss: 16652.8281
# Beta-VAE - Epoch [3/10], Step [2200/4608], Loss: 17449.9609
# Beta-VAE - Epoch [3/10], Step [2300/4608], Loss: 17307.8086
# Beta-VAE - Epoch [3/10], Step [2400/4608], Loss: 17844.0527
# Beta-VAE - Epoch [3/10], Step [2500/4608], Loss: 17243.0273
# Beta-VAE - Epoch [3/10], Step [2600/4608], Loss: 16101.8848
# Beta-VAE - Epoch [3/10], Step [2700/4608], Loss: 16953.7422
# Beta-VAE - Epoch [3/10], Step [2800/4608], Loss: 17175.3516
# Beta-VAE - Epoch [3/10], Step [2900/4608], Loss: 17806.5156
# Beta-VAE - Epoch [3/10], Step [3000/4608], Loss: 16687.9160
# Beta-VAE - Epoch [3/10], Step [3100/4608], Loss: 17644.5059
# Beta-VAE - Epoch [3/10], Step [3200/4608], Loss: 16133.5459
# Beta-VAE - Epoch [3/10], Step [3300/4608], Loss: 17142.4805
# Beta-VAE - Epoch [3/10], Step [3400/4608], Loss: 16988.1289
# Beta-VAE - Epoch [3/10], Step [3500/4608], Loss: 16819.2559
# Beta-VAE - Epoch [3/10], Step [3600/4608], Loss: 17630.9727
# Beta-VAE - Epoch [3/10], Step [3700/4608], Loss: 15987.9121
# Beta-VAE - Epoch [3/10], Step [3800/4608], Loss: 16962.7031
# Beta-VAE - Epoch [3/10], Step [3900/4608], Loss: 17295.7402
# Beta-VAE - Epoch [3/10], Step [4000/4608], Loss: 16473.1094
# Beta-VAE - Epoch [3/10], Step [4100/4608], Loss: 16884.7754
# Beta-VAE - Epoch [3/10], Step [4200/4608], Loss: 16855.8359
# Beta-VAE - Epoch [3/10], Step [4300/4608], Loss: 17052.7656
# Beta-VAE - Epoch [3/10], Step [4400/4608], Loss: 18228.1504
# Beta-VAE - Epoch [3/10], Step [4500/4608], Loss: 16538.0469
# Beta-VAE - Epoch [3/10], Step [4600/4608], Loss: 16315.3828
# Beta-VAE - Epoch [3/10]
# Beta-VAE - Epoch [4/10], Step [100/4608], Loss: 16632.1562
# Beta-VAE - Epoch [4/10], Step [200/4608], Loss: 17639.4023
# Beta-VAE - Epoch [4/10], Step [300/4608], Loss: 16196.9551
# Beta-VAE - Epoch [4/10], Step [400/4608], Loss: 17224.4023
# Beta-VAE - Epoch [4/10], Step [500/4608], Loss: 16833.1465
# Beta-VAE - Epoch [4/10], Step [600/4608], Loss: 17177.7285
# Beta-VAE - Epoch [4/10], Step [700/4608], Loss: 17031.0234
# Beta-VAE - Epoch [4/10], Step [800/4608], Loss: 16566.6641
# Beta-VAE - Epoch [4/10], Step [900/4608], Loss: 16904.3574
# Beta-VAE - Epoch [4/10], Step [1000/4608], Loss: 16793.9961
# Beta-VAE - Epoch [4/10], Step [1100/4608], Loss: 16978.5801
# Beta-VAE - Epoch [4/10], Step [1200/4608], Loss: 16210.0752
# Beta-VAE - Epoch [4/10], Step [1300/4608], Loss: 16398.2715
# Beta-VAE - Epoch [4/10], Step [1400/4608], Loss: 16321.9199
# Beta-VAE - Epoch [4/10], Step [1500/4608], Loss: 16030.1826
# Beta-VAE - Epoch [4/10], Step [1600/4608], Loss: 17018.2148
# Beta-VAE - Epoch [4/10], Step [1700/4608], Loss: 17361.4980
# Beta-VAE - Epoch [4/10], Step [1800/4608], Loss: 16505.6738
# Beta-VAE - Epoch [4/10], Step [1900/4608], Loss: 16323.8867
# Beta-VAE - Epoch [4/10], Step [2000/4608], Loss: 17081.1289
# Beta-VAE - Epoch [4/10], Step [2100/4608], Loss: 16811.7246
# Beta-VAE - Epoch [4/10], Step [2200/4608], Loss: 17224.8945
# Beta-VAE - Epoch [4/10], Step [2300/4608], Loss: 16846.5586
# Beta-VAE - Epoch [4/10], Step [2400/4608], Loss: 16673.6367
# Beta-VAE - Epoch [4/10], Step [2500/4608], Loss: 16616.3945
# Beta-VAE - Epoch [4/10], Step [2600/4608], Loss: 16540.9141
# Beta-VAE - Epoch [4/10], Step [2700/4608], Loss: 16982.0117
# Beta-VAE - Epoch [4/10], Step [2800/4608], Loss: 16356.8906
# Beta-VAE - Epoch [4/10], Step [2900/4608], Loss: 16285.1846
# Beta-VAE - Epoch [4/10], Step [3000/4608], Loss: 16660.7188
# Beta-VAE - Epoch [4/10], Step [3100/4608], Loss: 15857.1328
# Beta-VAE - Epoch [4/10], Step [3200/4608], Loss: 16817.9766
# Beta-VAE - Epoch [4/10], Step [3300/4608], Loss: 17465.1816
# Beta-VAE - Epoch [4/10], Step [3400/4608], Loss: 16885.7500
# Beta-VAE - Epoch [4/10], Step [3500/4608], Loss: 17055.0918
# Beta-VAE - Epoch [4/10], Step [3600/4608], Loss: 16560.4688
# Beta-VAE - Epoch [4/10], Step [3700/4608], Loss: 16071.2012
# Beta-VAE - Epoch [4/10], Step [3800/4608], Loss: 16604.7852
# Beta-VAE - Epoch [4/10], Step [3900/4608], Loss: 16077.2871
# Beta-VAE - Epoch [4/10], Step [4000/4608], Loss: 16889.6641
# Beta-VAE - Epoch [4/10], Step [4100/4608], Loss: 16538.9922
# Beta-VAE - Epoch [4/10], Step [4200/4608], Loss: 16793.2324
# Beta-VAE - Epoch [4/10], Step [4300/4608], Loss: 16723.3027
# Beta-VAE - Epoch [4/10], Step [4400/4608], Loss: 16623.5508
# Beta-VAE - Epoch [4/10], Step [4500/4608], Loss: 16651.8672
# Beta-VAE - Epoch [4/10], Step [4600/4608], Loss: 15288.5293
# Beta-VAE - Epoch [4/10]
# Beta-VAE - Epoch [5/10], Step [100/4608], Loss: 16655.3086
# Beta-VAE - Epoch [5/10], Step [200/4608], Loss: 16151.8281
# Beta-VAE - Epoch [5/10], Step [300/4608], Loss: 16823.3262
# Beta-VAE - Epoch [5/10], Step [400/4608], Loss: 16897.9648
# Beta-VAE - Epoch [5/10], Step [500/4608], Loss: 16089.2988
# Beta-VAE - Epoch [5/10], Step [600/4608], Loss: 16572.1055
# Beta-VAE - Epoch [5/10], Step [700/4608], Loss: 17299.1074
# Beta-VAE - Epoch [5/10], Step [800/4608], Loss: 16827.0117
# Beta-VAE - Epoch [5/10], Step [900/4608], Loss: 15972.4639
# Beta-VAE - Epoch [5/10], Step [1000/4608], Loss: 16628.9570
# Beta-VAE - Epoch [5/10], Step [1100/4608], Loss: 15887.8887
# Beta-VAE - Epoch [5/10], Step [1200/4608], Loss: 16608.7383
# Beta-VAE - Epoch [5/10], Step [1300/4608], Loss: 16204.3477
# Beta-VAE - Epoch [5/10], Step [1400/4608], Loss: 16627.7305
# Beta-VAE - Epoch [5/10], Step [1500/4608], Loss: 16596.6328
# Beta-VAE - Epoch [5/10], Step [1600/4608], Loss: 17063.4219
# Beta-VAE - Epoch [5/10], Step [1700/4608], Loss: 16070.0029
# Beta-VAE - Epoch [5/10], Step [1800/4608], Loss: 16208.6963
# Beta-VAE - Epoch [5/10], Step [1900/4608], Loss: 16457.2109
# Beta-VAE - Epoch [5/10], Step [2000/4608], Loss: 17483.2852
# Beta-VAE - Epoch [5/10], Step [2100/4608], Loss: 15784.3887
# Beta-VAE - Epoch [5/10], Step [2200/4608], Loss: 16930.3008
# Beta-VAE - Epoch [5/10], Step [2300/4608], Loss: 16396.3613
# Beta-VAE - Epoch [5/10], Step [2400/4608], Loss: 17180.4922
# Beta-VAE - Epoch [5/10], Step [2500/4608], Loss: 17043.4453
# Beta-VAE - Epoch [5/10], Step [2600/4608], Loss: 16208.2207
# Beta-VAE - Epoch [5/10], Step [2700/4608], Loss: 17181.0488
# Beta-VAE - Epoch [5/10], Step [2800/4608], Loss: 16272.7656
# Beta-VAE - Epoch [5/10], Step [2900/4608], Loss: 16640.1777
# Beta-VAE - Epoch [5/10], Step [3000/4608], Loss: 16195.7305
# Beta-VAE - Epoch [5/10], Step [3100/4608], Loss: 16765.9219
# Beta-VAE - Epoch [5/10], Step [3200/4608], Loss: 16026.1104
# Beta-VAE - Epoch [5/10], Step [3300/4608], Loss: 16078.2617
# Beta-VAE - Epoch [5/10], Step [3400/4608], Loss: 16728.6523
# Beta-VAE - Epoch [5/10], Step [3500/4608], Loss: 15824.5879
# Beta-VAE - Epoch [5/10], Step [3600/4608], Loss: 16233.6270
# Beta-VAE - Epoch [5/10], Step [3700/4608], Loss: 16049.4893
# Beta-VAE - Epoch [5/10], Step [3800/4608], Loss: 15776.3691
# Beta-VAE - Epoch [5/10], Step [3900/4608], Loss: 16390.2090
# Beta-VAE - Epoch [5/10], Step [4000/4608], Loss: 16805.3125
# Beta-VAE - Epoch [5/10], Step [4100/4608], Loss: 16360.1807
# Beta-VAE - Epoch [5/10], Step [4200/4608], Loss: 15935.8506
# Beta-VAE - Epoch [5/10], Step [4300/4608], Loss: 16316.1816
# Beta-VAE - Epoch [5/10], Step [4400/4608], Loss: 16921.4883
# Beta-VAE - Epoch [5/10], Step [4500/4608], Loss: 16074.6758
# Beta-VAE - Epoch [5/10], Step [4600/4608], Loss: 16523.2578
# Beta-VAE - Epoch [5/10]
# Beta-VAE - Epoch [6/10], Step [100/4608], Loss: 15820.5547
# Beta-VAE - Epoch [6/10], Step [200/4608], Loss: 16057.9355
# Beta-VAE - Epoch [6/10], Step [300/4608], Loss: 15379.2246
# Beta-VAE - Epoch [6/10], Step [400/4608], Loss: 16992.6016
# Beta-VAE - Epoch [6/10], Step [500/4608], Loss: 16499.8711
# Beta-VAE - Epoch [6/10], Step [600/4608], Loss: 16713.8066
# Beta-VAE - Epoch [6/10], Step [700/4608], Loss: 15718.8604
# Beta-VAE - Epoch [6/10], Step [800/4608], Loss: 15946.2432
# Beta-VAE - Epoch [6/10], Step [900/4608], Loss: 17530.5430
# Beta-VAE - Epoch [6/10], Step [1000/4608], Loss: 16436.1562
# Beta-VAE - Epoch [6/10], Step [1100/4608], Loss: 16225.7510
# Beta-VAE - Epoch [6/10], Step [1200/4608], Loss: 16382.6621
# Beta-VAE - Epoch [6/10], Step [1300/4608], Loss: 16082.2695
# Beta-VAE - Epoch [6/10], Step [1400/4608], Loss: 16449.9492
# Beta-VAE - Epoch [6/10], Step [1500/4608], Loss: 16234.7012
# Beta-VAE - Epoch [6/10], Step [1600/4608], Loss: 16084.5605
# Beta-VAE - Epoch [6/10], Step [1700/4608], Loss: 16170.1709
# Beta-VAE - Epoch [6/10], Step [1800/4608], Loss: 17189.3594
# Beta-VAE - Epoch [6/10], Step [1900/4608], Loss: 16637.1680
# Beta-VAE - Epoch [6/10], Step [2000/4608], Loss: 16804.8672
# Beta-VAE - Epoch [6/10], Step [2100/4608], Loss: 15838.7803
# Beta-VAE - Epoch [6/10], Step [2200/4608], Loss: 16314.4863
# Beta-VAE - Epoch [6/10], Step [2300/4608], Loss: 16229.3281
# Beta-VAE - Epoch [6/10], Step [2400/4608], Loss: 16531.1797
# Beta-VAE - Epoch [6/10], Step [2500/4608], Loss: 16597.9824
# Beta-VAE - Epoch [6/10], Step [2600/4608], Loss: 16367.8525
# Beta-VAE - Epoch [6/10], Step [2700/4608], Loss: 16328.0146
# Beta-VAE - Epoch [6/10], Step [2800/4608], Loss: 16882.1211
# Beta-VAE - Epoch [6/10], Step [2900/4608], Loss: 16337.3232
# Beta-VAE - Epoch [6/10], Step [3000/4608], Loss: 16179.6406
# Beta-VAE - Epoch [6/10], Step [3100/4608], Loss: 16257.2363
# Beta-VAE - Epoch [6/10], Step [3200/4608], Loss: 15869.4424
# Beta-VAE - Epoch [6/10], Step [3300/4608], Loss: 16658.2070
# Beta-VAE - Epoch [6/10], Step [3400/4608], Loss: 16273.3203
# Beta-VAE - Epoch [6/10], Step [3500/4608], Loss: 16026.0352
# Beta-VAE - Epoch [6/10], Step [3600/4608], Loss: 16593.0352
# Beta-VAE - Epoch [6/10], Step [3700/4608], Loss: 15773.2607
# Beta-VAE - Epoch [6/10], Step [3800/4608], Loss: 16653.5039
# Beta-VAE - Epoch [6/10], Step [3900/4608], Loss: 16466.5137
# Beta-VAE - Epoch [6/10], Step [4000/4608], Loss: 15616.8691
# Beta-VAE - Epoch [6/10], Step [4100/4608], Loss: 16433.1973
# Beta-VAE - Epoch [6/10], Step [4200/4608], Loss: 15960.0273
# Beta-VAE - Epoch [6/10], Step [4300/4608], Loss: 16617.4414
# Beta-VAE - Epoch [6/10], Step [4400/4608], Loss: 16529.9277
# Beta-VAE - Epoch [6/10], Step [4500/4608], Loss: 15829.5371
# Beta-VAE - Epoch [6/10], Step [4600/4608], Loss: 15940.0820
# Beta-VAE - Epoch [6/10]
# Beta-VAE - Epoch [7/10], Step [100/4608], Loss: 15859.4707
# Beta-VAE - Epoch [7/10], Step [200/4608], Loss: 15906.8047
# Beta-VAE - Epoch [7/10], Step [300/4608], Loss: 15288.0723
# Beta-VAE - Epoch [7/10], Step [400/4608], Loss: 15475.1143
# Beta-VAE - Epoch [7/10], Step [500/4608], Loss: 15813.6787
# Beta-VAE - Epoch [7/10], Step [600/4608], Loss: 16155.2852
# Beta-VAE - Epoch [7/10], Step [700/4608], Loss: 16110.7461
# Beta-VAE - Epoch [7/10], Step [800/4608], Loss: 15888.2031
# Beta-VAE - Epoch [7/10], Step [900/4608], Loss: 16225.9395
# Beta-VAE - Epoch [7/10], Step [1000/4608], Loss: 16228.1211
# Beta-VAE - Epoch [7/10], Step [1100/4608], Loss: 15970.4580
# Beta-VAE - Epoch [7/10], Step [1200/4608], Loss: 15486.0342
# Beta-VAE - Epoch [7/10], Step [1300/4608], Loss: 16155.5098
# Beta-VAE - Epoch [7/10], Step [1400/4608], Loss: 15863.2471
# Beta-VAE - Epoch [7/10], Step [1500/4608], Loss: 16191.3223
# Beta-VAE - Epoch [7/10], Step [1600/4608], Loss: 15645.2188
# Beta-VAE - Epoch [7/10], Step [1700/4608], Loss: 15654.8643
# Beta-VAE - Epoch [7/10], Step [1800/4608], Loss: 15873.8096
# Beta-VAE - Epoch [7/10], Step [1900/4608], Loss: 16220.1367
# Beta-VAE - Epoch [7/10], Step [2000/4608], Loss: 15790.3682
# Beta-VAE - Epoch [7/10], Step [2100/4608], Loss: 16181.3145
# Beta-VAE - Epoch [7/10], Step [2200/4608], Loss: 16232.2900
# Beta-VAE - Epoch [7/10], Step [2300/4608], Loss: 15652.9648
# Beta-VAE - Epoch [7/10], Step [2400/4608], Loss: 16485.2461
# Beta-VAE - Epoch [7/10], Step [2500/4608], Loss: 15645.1650
# Beta-VAE - Epoch [7/10], Step [2600/4608], Loss: 15750.2051
# Beta-VAE - Epoch [7/10], Step [2700/4608], Loss: 15274.0488
# Beta-VAE - Epoch [7/10], Step [2800/4608], Loss: 16438.1914
# Beta-VAE - Epoch [7/10], Step [2900/4608], Loss: 15797.8828
# Beta-VAE - Epoch [7/10], Step [3000/4608], Loss: 16252.2676
# Beta-VAE - Epoch [7/10], Step [3100/4608], Loss: 15271.2334
# Beta-VAE - Epoch [7/10], Step [3200/4608], Loss: 15697.8955
# Beta-VAE - Epoch [7/10], Step [3300/4608], Loss: 16091.5107
# Beta-VAE - Epoch [7/10], Step [3400/4608], Loss: 16160.4805
# Beta-VAE - Epoch [7/10], Step [3500/4608], Loss: 15164.3359
# Beta-VAE - Epoch [7/10], Step [3600/4608], Loss: 17156.5391
# Beta-VAE - Epoch [7/10], Step [3700/4608], Loss: 16009.4463
# Beta-VAE - Epoch [7/10], Step [3800/4608], Loss: 15264.5469
# Beta-VAE - Epoch [7/10], Step [3900/4608], Loss: 16077.7754
# Beta-VAE - Epoch [7/10], Step [4000/4608], Loss: 15500.5322
# Beta-VAE - Epoch [7/10], Step [4100/4608], Loss: 16133.7031
# Beta-VAE - Epoch [7/10], Step [4200/4608], Loss: 15405.6494
# Beta-VAE - Epoch [7/10], Step [4300/4608], Loss: 16194.3203
# Beta-VAE - Epoch [7/10], Step [4400/4608], Loss: 15562.8848
# Beta-VAE - Epoch [7/10], Step [4500/4608], Loss: 15476.5391
# Beta-VAE - Epoch [7/10], Step [4600/4608], Loss: 16211.5527
# Beta-VAE - Epoch [7/10]
# Beta-VAE - Epoch [8/10], Step [100/4608], Loss: 16137.5010
# Beta-VAE - Epoch [8/10], Step [200/4608], Loss: 16178.7500
# Beta-VAE - Epoch [8/10], Step [300/4608], Loss: 15660.0010
# Beta-VAE - Epoch [8/10], Step [400/4608], Loss: 16599.6543
# Beta-VAE - Epoch [8/10], Step [500/4608], Loss: 15579.8359
# Beta-VAE - Epoch [8/10], Step [600/4608], Loss: 16078.1211
# Beta-VAE - Epoch [8/10], Step [700/4608], Loss: 16609.5078
# Beta-VAE - Epoch [8/10], Step [800/4608], Loss: 16600.7012
# Beta-VAE - Epoch [8/10], Step [900/4608], Loss: 15911.0234
# Beta-VAE - Epoch [8/10], Step [1000/4608], Loss: 16977.4297
# Beta-VAE - Epoch [8/10], Step [1100/4608], Loss: 16240.3311
# Beta-VAE - Epoch [8/10], Step [1200/4608], Loss: 16167.2402
# Beta-VAE - Epoch [8/10], Step [1300/4608], Loss: 16658.2148
# Beta-VAE - Epoch [8/10], Step [1400/4608], Loss: 15134.1191
# Beta-VAE - Epoch [8/10], Step [1500/4608], Loss: 15353.8438
# Beta-VAE - Epoch [8/10], Step [1600/4608], Loss: 15546.4912
# Beta-VAE - Epoch [8/10], Step [1700/4608], Loss: 16488.1406
# Beta-VAE - Epoch [8/10], Step [1800/4608], Loss: 15400.8467
# Beta-VAE - Epoch [8/10], Step [1900/4608], Loss: 15302.6758
# Beta-VAE - Epoch [8/10], Step [2000/4608], Loss: 15863.3750
# Beta-VAE - Epoch [8/10], Step [2100/4608], Loss: 16200.7441
# Beta-VAE - Epoch [8/10], Step [2200/4608], Loss: 15769.8125
# Beta-VAE - Epoch [8/10], Step [2300/4608], Loss: 15437.1328
# Beta-VAE - Epoch [8/10], Step [2400/4608], Loss: 16238.8896
# Beta-VAE - Epoch [8/10], Step [2500/4608], Loss: 15744.5566
# Beta-VAE - Epoch [8/10], Step [2600/4608], Loss: 15138.6562
# Beta-VAE - Epoch [8/10], Step [2700/4608], Loss: 15543.1182
# Beta-VAE - Epoch [8/10], Step [2800/4608], Loss: 15667.2402
# Beta-VAE - Epoch [8/10], Step [2900/4608], Loss: 15704.7832
# Beta-VAE - Epoch [8/10], Step [3000/4608], Loss: 16301.0029
# Beta-VAE - Epoch [8/10], Step [3100/4608], Loss: 15898.6250
# Beta-VAE - Epoch [8/10], Step [3200/4608], Loss: 15858.3848
# Beta-VAE - Epoch [8/10], Step [3300/4608], Loss: 15685.4551
# Beta-VAE - Epoch [8/10], Step [3400/4608], Loss: 15012.1680
# Beta-VAE - Epoch [8/10], Step [3500/4608], Loss: 16022.7363
# Beta-VAE - Epoch [8/10], Step [3600/4608], Loss: 15552.0801
# Beta-VAE - Epoch [8/10], Step [3700/4608], Loss: 15763.4531
# Beta-VAE - Epoch [8/10], Step [3800/4608], Loss: 15698.0225
# Beta-VAE - Epoch [8/10], Step [3900/4608], Loss: 15675.7930
# Beta-VAE - Epoch [8/10], Step [4000/4608], Loss: 16215.8086
# Beta-VAE - Epoch [8/10], Step [4100/4608], Loss: 15733.4375
# Beta-VAE - Epoch [8/10], Step [4200/4608], Loss: 15855.8516
# Beta-VAE - Epoch [8/10], Step [4300/4608], Loss: 16339.3682
# Beta-VAE - Epoch [8/10], Step [4400/4608], Loss: 15855.8594
# Beta-VAE - Epoch [8/10], Step [4500/4608], Loss: 15876.1201
# Beta-VAE - Epoch [8/10], Step [4600/4608], Loss: 15679.7676
# Beta-VAE - Epoch [8/10]
# Beta-VAE - Epoch [9/10], Step [100/4608], Loss: 16105.3359
# Beta-VAE - Epoch [9/10], Step [200/4608], Loss: 15428.3184
# Beta-VAE - Epoch [9/10], Step [300/4608], Loss: 15389.2520
# Beta-VAE - Epoch [9/10], Step [400/4608], Loss: 16958.2520
# Beta-VAE - Epoch [9/10], Step [500/4608], Loss: 15189.5078
# Beta-VAE - Epoch [9/10], Step [600/4608], Loss: 15808.4746
# Beta-VAE - Epoch [9/10], Step [700/4608], Loss: 15435.0625
# Beta-VAE - Epoch [9/10], Step [800/4608], Loss: 15271.8848
# Beta-VAE - Epoch [9/10], Step [900/4608], Loss: 15511.9121
# Beta-VAE - Epoch [9/10], Step [1000/4608], Loss: 15339.9463
# Beta-VAE - Epoch [9/10], Step [1100/4608], Loss: 15673.6934
# Beta-VAE - Epoch [9/10], Step [1200/4608], Loss: 15525.2227
# Beta-VAE - Epoch [9/10], Step [1300/4608], Loss: 16117.8086
# Beta-VAE - Epoch [9/10], Step [1400/4608], Loss: 15838.4648
# Beta-VAE - Epoch [9/10], Step [1500/4608], Loss: 15088.3369
# Beta-VAE - Epoch [9/10], Step [1600/4608], Loss: 15443.4014
# Beta-VAE - Epoch [9/10], Step [1700/4608], Loss: 16543.7324
# Beta-VAE - Epoch [9/10], Step [1800/4608], Loss: 15775.0000
# Beta-VAE - Epoch [9/10], Step [1900/4608], Loss: 15355.7031
# Beta-VAE - Epoch [9/10], Step [2000/4608], Loss: 15373.3818
# Beta-VAE - Epoch [9/10], Step [2100/4608], Loss: 15964.5635
# Beta-VAE - Epoch [9/10], Step [2200/4608], Loss: 15947.5947
# Beta-VAE - Epoch [9/10], Step [2300/4608], Loss: 15797.7314
# Beta-VAE - Epoch [9/10], Step [2400/4608], Loss: 15374.0107
# Beta-VAE - Epoch [9/10], Step [2500/4608], Loss: 16193.3525
# Beta-VAE - Epoch [9/10], Step [2600/4608], Loss: 15378.0527
# Beta-VAE - Epoch [9/10], Step [2700/4608], Loss: 15413.1562
# Beta-VAE - Epoch [9/10], Step [2800/4608], Loss: 15745.2529
# Beta-VAE - Epoch [9/10], Step [2900/4608], Loss: 16262.1270
# Beta-VAE - Epoch [9/10], Step [3000/4608], Loss: 15413.4326
# Beta-VAE - Epoch [9/10], Step [3100/4608], Loss: 15534.4326
# Beta-VAE - Epoch [9/10], Step [3200/4608], Loss: 15550.2363
# Beta-VAE - Epoch [9/10], Step [3300/4608], Loss: 15881.1172
# Beta-VAE - Epoch [9/10], Step [3400/4608], Loss: 16329.2227
# Beta-VAE - Epoch [9/10], Step [3500/4608], Loss: 15609.9160
# Beta-VAE - Epoch [9/10], Step [3600/4608], Loss: 15796.3164
# Beta-VAE - Epoch [9/10], Step [3700/4608], Loss: 15482.2705
# Beta-VAE - Epoch [9/10], Step [3800/4608], Loss: 16050.4805
# Beta-VAE - Epoch [9/10], Step [3900/4608], Loss: 15188.8086
# Beta-VAE - Epoch [9/10], Step [4000/4608], Loss: 15126.2549
# Beta-VAE - Epoch [9/10], Step [4100/4608], Loss: 15420.9688
# Beta-VAE - Epoch [9/10], Step [4200/4608], Loss: 14734.4551
# Beta-VAE - Epoch [9/10], Step [4300/4608], Loss: 15704.8125
# Beta-VAE - Epoch [9/10], Step [4400/4608], Loss: 15599.4922
# Beta-VAE - Epoch [9/10], Step [4500/4608], Loss: 15864.8965
# Beta-VAE - Epoch [9/10], Step [4600/4608], Loss: 15203.6992
# Beta-VAE - Epoch [9/10]
# Beta-VAE - Epoch [10/10], Step [100/4608], Loss: 15823.6367
# Beta-VAE - Epoch [10/10], Step [200/4608], Loss: 16277.6289
# Beta-VAE - Epoch [10/10], Step [300/4608], Loss: 15589.5645
# Beta-VAE - Epoch [10/10], Step [400/4608], Loss: 15341.2402
# Beta-VAE - Epoch [10/10], Step [500/4608], Loss: 15183.7031
# Beta-VAE - Epoch [10/10], Step [600/4608], Loss: 15390.1973
# Beta-VAE - Epoch [10/10], Step [700/4608], Loss: 15590.0879
# Beta-VAE - Epoch [10/10], Step [800/4608], Loss: 16041.4180
# Beta-VAE - Epoch [10/10], Step [900/4608], Loss: 15427.3193
# Beta-VAE - Epoch [10/10], Step [1000/4608], Loss: 16491.4492
# Beta-VAE - Epoch [10/10], Step [1100/4608], Loss: 15427.9873
# Beta-VAE - Epoch [10/10], Step [1200/4608], Loss: 15619.3340
# Beta-VAE - Epoch [10/10], Step [1300/4608], Loss: 15656.8076
# Beta-VAE - Epoch [10/10], Step [1400/4608], Loss: 15195.1670
# Beta-VAE - Epoch [10/10], Step [1500/4608], Loss: 15596.7617
# Beta-VAE - Epoch [10/10], Step [1600/4608], Loss: 16132.7520
# Beta-VAE - Epoch [10/10], Step [1700/4608], Loss: 15195.4756
# Beta-VAE - Epoch [10/10], Step [1800/4608], Loss: 16022.2363
# Beta-VAE - Epoch [10/10], Step [1900/4608], Loss: 15358.9512
# Beta-VAE - Epoch [10/10], Step [2000/4608], Loss: 15178.1855
# Beta-VAE - Epoch [10/10], Step [2100/4608], Loss: 15442.5723
# Beta-VAE - Epoch [10/10], Step [2200/4608], Loss: 15504.3750
# Beta-VAE - Epoch [10/10], Step [2300/4608], Loss: 15646.0449
# Beta-VAE - Epoch [10/10], Step [2400/4608], Loss: 15653.3770
# Beta-VAE - Epoch [10/10], Step [2500/4608], Loss: 15649.2910
# Beta-VAE - Epoch [10/10], Step [2600/4608], Loss: 14945.0527
# Beta-VAE - Epoch [10/10], Step [2700/4608], Loss: 15363.6367
# Beta-VAE - Epoch [10/10], Step [2800/4608], Loss: 15129.4980
# Beta-VAE - Epoch [10/10], Step [2900/4608], Loss: 15854.3691
# Beta-VAE - Epoch [10/10], Step [3000/4608], Loss: 15681.2148
# Beta-VAE - Epoch [10/10], Step [3100/4608], Loss: 15206.9082
# Beta-VAE - Epoch [10/10], Step [3200/4608], Loss: 15035.4766
# Beta-VAE - Epoch [10/10], Step [3300/4608], Loss: 15718.8662
# Beta-VAE - Epoch [10/10], Step [3400/4608], Loss: 16110.9082
# Beta-VAE - Epoch [10/10], Step [3500/4608], Loss: 15999.6836
# Beta-VAE - Epoch [10/10], Step [3600/4608], Loss: 15558.6641
# Beta-VAE - Epoch [10/10], Step [3700/4608], Loss: 15762.8623
# Beta-VAE - Epoch [10/10], Step [3800/4608], Loss: 15020.9629
# Beta-VAE - Epoch [10/10], Step [3900/4608], Loss: 15237.0176
# Beta-VAE - Epoch [10/10], Step [4000/4608], Loss: 16233.2266
# Beta-VAE - Epoch [10/10], Step [4100/4608], Loss: 15863.1621
# Beta-VAE - Epoch [10/10], Step [4200/4608], Loss: 15650.5586
# Beta-VAE - Epoch [10/10], Step [4300/4608], Loss: 15494.4951
# Beta-VAE - Epoch [10/10], Step [4400/4608], Loss: 15711.2715
# Beta-VAE - Epoch [10/10], Step [4500/4608], Loss: 15754.0098
# Beta-VAE - Epoch [10/10], Step [4600/4608], Loss: 15682.8164
# Beta-VAE - Epoch [10/10]
# Training complete!

# %%
# MRH: converting "collect_latent_factors_for_metrics" to "collect_latent_factors_for_metrics2"
# since HDVAE has model.encode but others have encoder
def collect_latent_factors_for_metrics2(model, data_loader, device, num_samples_to_collect=None):
    model.eval()
    all_mu1 = []
    all_latents_values = [] # This will store the continuous ground truth factors

    # dSprites factor names (excluding 'color')
    factor_names = ["color", "shape", "scale", "orientation", "posX", "posY"]
    active_factors_idx = [1, 2, 3, 4, 5] # Exclude color (index 0)

    print(f"Collecting latent representations and ground truth factors for metrics (up to {num_samples_to_collect if num_samples_to_collect else 'all'} samples)...")
    samples_collected = 0
    with torch.no_grad():
        # --- MODIFIED LINE HERE (same as before) ---
        # Assuming your DataLoader yields (image, latents_values, latents_classes)
        for batch_idx, (images, latents_values_batch, latents_classes_batch) in tqdm(enumerate(data_loader), desc="Collecting data for metrics"):
            images = images.to(device)

            # Extract ground truth factors (continuous values)
            # For dSprites, latents_values_batch tensor structure is usually:
            # latents_values_batch[:, 0] = color (constant)
            # latents_values_batch[:, 1] = shape
            # latents_values_batch[:, 2] = scale
            # latents_values_batch[:, 3] = orientation
            # latents_values_batch[:, 4] = posX
            # latents_values_batch[:, 5] = posY
            # --- CORRECTED LINE BELOW ---
            ground_truth_factors = latents_values_batch.cpu().numpy() # Use the correct variable name

            # Encode the image to get latent means (mu1)
            # (_, _, z1_mu), (_, _, z2_mu), (_, _, z3_mu) = model.encode(images)
            # h = model.encoder(x.view(-1, self.image_size))
            #print('mrh images shape= ',images.shape )
            image_size=64*64
            h = model.encoder(images.view(-1, image_size))
            z1_mu = model.fc_mu(h)

            # print('mrh= ',z1_mu.shape)

            all_mu1.append(z1_mu.cpu().numpy())
            all_latents_values.append(ground_truth_factors)

            samples_collected += images.size(0)
            if num_samples_to_collect is not None and samples_collected >= num_samples_to_collect:
                break # Stop collecting once enough samples are gathered

    mu1_for_metrics = np.concatenate(all_mu1, axis=0)
    latents_values_for_metrics = np.concatenate(all_latents_values, axis=0)

    # Ensure we only return up to num_samples_to_collect if specified
    if num_samples_to_collect is not None:
        mu1_for_metrics = mu1_for_metrics[:num_samples_to_collect]
        latents_values_for_metrics = latents_values_for_metrics[:num_samples_to_collect]
        print(f"Collected {mu1_for_metrics.shape[0]} samples for metrics.")

    return mu1_for_metrics, latents_values_for_metrics, factor_names, active_factors_idx

# %%
# beta_vae_model
model=beta_vae_model_
# --- Run Metrics After Training ---
print("\n" + "="*50)
print("Starting Quantitative Metrics Evaluation")
print("="*50 + "\n")

# Define the number of samples for metrics calculation to speed it up.
# For dSprites, 10,000 to 20,000 samples is usually sufficient.
# Set to None to use all available samples in the test_dataset.
NUM_SAMPLES_FOR_METRICS = 20000

# Collect data for metrics (using test_loader, but now limited by NUM_SAMPLES_FOR_METRICS)
# It's good to keep batch_size for the data_loader relatively high (e.g., 256)
# to make efficient use of the GPU during the forward pass.
metrics_data_loader = torch.utils.data.DataLoader(dataset=test_dataset, batch_size=256, shuffle=False)


######################################


mu1_for_metrics, latents_values_for_metrics, factor_names, active_factors_idx = \
    collect_latent_factors_for_metrics2(model, metrics_data_loader, device,
                                       num_samples_to_collect=NUM_SAMPLES_FOR_METRICS)

# Calculate and print MIG
mig_avg_score, mig_report = calculate_mig(mu1_for_metrics, latents_values_for_metrics, factor_names, active_factors_idx)

# Calculate and print Linear Regression Disentanglement Score
linear_disentanglement_avg_score, linear_r2_report, linear_disentanglement_summary = \
    calculate_linear_disentanglement_score(mu1_for_metrics, latents_values_for_metrics, factor_names, active_factors_idx)

# Calculate and print DCI
dci_informativeness, dci_disentanglement, dci_completeness, dci_report = \
    calculate_dci(mu1_for_metrics, latents_values_for_metrics, factor_names, active_factors_idx)

print("\n" + "="*50)
print("Quantitative Metrics Evaluation Complete")
print("="*50 + "\n")


#######################
model_name = "Beta-VAE"
model_results = {
    "Model": model_name,
    "MIG Score": mig_avg_score,
    "DCI Informativeness": dci_informativeness,
    "DCI Disentanglement": dci_disentanglement,
    "DCI Completeness": dci_completeness,
    "Average R2 Disentanglement": linear_disentanglement_avg_score,
}
all_model_results.append(model_results)
print(f"Finished evaluating {model_name}.")
# Out:
# ==================================================
# Starting Quantitative Metrics Evaluation
# ==================================================
#
# Collecting latent representations and ground truth factors for metrics (up to 20000 samples)...
# Collecting data for metrics: 0it [00:00, ?it/s]
# Collected 20000 samples for metrics.
#
# Calculating MIG (Mutual Information Gap) Score...
# Discretizing latent dimensions into 20 bins for MI calculation...
# Discretizing Latents:   0%|          | 0/64 [00:00<?, ?it/s]
# Discretizing ground truth factors into 20 bins for MI calculation...
# Discretizing Factors:   0%|          | 0/5 [00:00<?, ?it/s]
# Calculating MI matrix (this can take a while)...
#
# MIG Score:
# --------------------------------------------------
#   Average MIG Score: 0.2659
# --------------------------------------------------
# Mutual Information Heatmap saved to mig_mi_heatmap.png
#
# Calculating Linear Regression Disentanglement Score (R-squared)...
# Fitting linear regressors:   0%|          | 0/64 [00:00<?, ?it/s]
# Linear Regression R-squared Scores:
# --------------------------------------------------
# Latent Dim   | shape      scale      orientation posX       posY
# ----------------------------------------------------------------------
# Latent 0     | 0.0250     0.1989     0.0000     0.1240     0.0279
# Latent 1     | 0.0400     0.1910     0.0000     0.1607     0.0052
# Latent 2     | 0.0285     0.1275     0.0002     0.1839     0.1139
# Latent 3     | 0.0013     0.0021     0.0000     0.0754     0.0934
# Latent 4     | 0.0149     0.0799     0.0002     0.0083     0.1887
# Latent 5     | 0.0531     0.3239     0.0004     0.0035     0.0078
# Latent 6     | 0.0057     0.0116     0.0000     0.2254     0.0800
# Latent 7     | 0.0180     0.0662     0.0006     0.0477     0.0812
# Latent 8     | 0.0013     0.0019     0.0007     0.3104     0.0111
# Latent 9     | 0.0029     0.0085     0.0001     0.1423     0.4764
# Latent 10    | 0.0025     0.0339     0.0001     0.2020     0.0022
# Latent 11    | 0.0028     0.0046     0.0003     0.0323     0.4090
# Latent 12    | 0.1009     0.4454     0.0001     0.0036     0.0005
# Latent 13    | 0.0285     0.1435     0.0000     0.0742     0.0036
# Latent 14    | 0.0270     0.1073     0.0005     0.0002     0.0961
# Latent 15    | 0.0025     0.0131     0.0002     0.0821     0.1576
# Latent 16    | 0.0000     0.0003     0.0002     0.0758     0.1098
# Latent 17    | 0.1473     0.7289     0.0000     0.0010     0.0038
# Latent 18    | 0.0049     0.0202     0.0010     0.1859     0.1206
# Latent 19    | 0.0068     0.0504     0.0003     0.0597     0.1021
# Latent 20    | 0.0037     0.0270     0.0006     0.0000     0.0068
# Latent 21    | 0.0299     0.1292     0.0000     0.0565     0.1202
# Latent 22    | 0.0003     0.0003     0.0000     0.1795     0.0130
# Latent 23    | 0.0224     0.1086     0.0002     0.1641     0.0040
# Latent 24    | 0.0100     0.0682     0.0014     0.0322     0.0000
# Latent 25    | 0.0000     0.0003     0.0000     0.1021     0.3066
# Latent 26    | 0.0076     0.0351     0.0002     0.1793     0.0001
# Latent 27    | 0.0382     0.1738     0.0001     0.1449     0.0443
# Latent 28    | 0.0043     0.0524     0.0000     0.0964     0.0008
# Latent 29    | 0.0083     0.0539     0.0000     0.1407     0.0366
# Latent 30    | 0.0016     0.0118     0.0001     0.0512     0.0411
# Latent 31    | 0.0028     0.0081     0.0000     0.0402     0.2255
# Latent 32    | 0.0427     0.1786     0.0001     0.0030     0.2072
# Latent 33    | 0.0226     0.0997     0.0002     0.1290     0.1572
# Latent 34    | 0.0011     0.0045     0.0000     0.0042     0.4049
# Latent 35    | 0.0047     0.0180     0.0000     0.0183     0.0503
# Latent 36    | 0.0238     0.0897     0.0000     0.0200     0.1626
# Latent 37    | 0.0013     0.0006     0.0004     0.0193     0.1303
# Latent 38    | 0.0087     0.1027     0.0003     0.0920     0.0280
# Latent 39    | 0.0261     0.1173     0.0000     0.0101     0.0034
# Latent 40    | 0.0000     0.0011     0.0001     0.2722     0.1074
# Latent 41    | 0.0006     0.0094     0.0002     0.0357     0.0243
# Latent 42    | 0.0021     0.0029     0.0011     0.0342     0.0310
# Latent 43    | 0.0049     0.0091     0.0002     0.3775     0.0020
# Latent 44    | 0.0012     0.0054     0.0002     0.0451     0.0264
# Latent 45    | 0.0001     0.0034     0.0003     0.0615     0.1162
# Latent 46    | 0.0003     0.0009     0.0003     0.0853     0.2186
# Latent 47    | 0.0002     0.0007     0.0005     0.1327     0.0355
# Latent 48    | 0.0000     0.0003     0.0000     0.0982     0.0429
# Latent 49    | 0.0475     0.2028     0.0006     0.0001     0.0671
# Latent 50    | 0.0013     0.0062     0.0000     0.0136     0.0332
# Latent 51    | 0.0003     0.0016     0.0002     0.0264     0.0723
# Latent 52    | 0.0044     0.0260     0.0004     0.1645     0.0819
# Latent 53    | 0.0208     0.1101     0.0000     0.2530     0.0018
# Latent 54    | 0.0384     0.1967     0.0000     0.0040     0.0016
# Latent 55    | 0.0055     0.0325     0.0016     0.0395     0.0172
# Latent 56    | 0.0189     0.1000     0.0002     0.2708     0.0670
# Latent 57    | 0.0090     0.0445     0.0000     0.0657     0.3033
# Latent 58    | 0.0043     0.0232     0.0002     0.0607     0.0067
# Latent 59    | 0.0000     0.0000     0.0001     0.0829     0.0627
# Latent 60    | 0.0149     0.0447     0.0001     0.0258     0.0600
# Latent 61    | 0.0010     0.0034     0.0004     0.0142     0.1065
# Latent 62    | 0.0091     0.0396     0.0000     0.3672     0.0723
# Latent 63    | 0.0042     0.0047     0.0000     0.2195     0.2208
#
# Disentanglement Summary (Per Ground Truth Factor):
# --------------------------------------------------
#   shape: Best explained by Latent 17 (R2: 0.1473)
#   scale: Best explained by Latent 17 (R2: 0.7289)
#   orientation: Best explained by Latent 55 (R2: 0.0016)
#   posX: Best explained by Latent 43 (R2: 0.3775)
#   posY: Best explained by Latent 9 (R2: 0.4764)
# --------------------------------------------------
# Average Disentanglement Score (Max R2 per factor): 0.3463
# Saved R2 matrix to ./metrics_hdvae/linear_r2_matrix.npy
# Saved R2 heatmap to ./metrics_hdvae/linear_r2_heatmap.png
#
# Calculating DCI (Disentanglement, Completeness, Informativeness) Score...
# Discretizing ground truth factors into 10 bins for DCI...
# Training RandomForestClassifiers for each ground truth factor...
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_discretization.py:306: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 0 are removed. Consider decreasing the number of bins.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_discretization.py:306: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 0 are removed. Consider decreasing the number of bins.
#   warnings.warn(
# DCI per factor:   0%|          | 0/5 [00:00<?, ?it/s]
# DCI Scores:
# --------------------------------------------------
#   Informativeness: 0.7377
#   Disentanglement: 0.0501
#   Completeness:    0.0502
# --------------------------------------------------
#
# ==================================================
# Quantitative Metrics Evaluation Complete
# ==================================================
#
# Finished evaluating Beta-VAE.

# %%
model_name = "Beta-VAE"
model_results = {
    "Model": model_name,
    "MIG Score": 0.2659,
    "DCI Informativeness": 0.7377,
    "DCI Disentanglement": 0.0501,
    "DCI Completeness": 0.0502,
    "Average R2 Disentanglement": 0.3463,
}
all_model_results.append(model_results)
print(f"Finished evaluating {model_name}.")
# Out:
# Finished evaluating Beta-VAE.

# %%
# V4: FactorVAE for comparison

# --- FactorVAE Model ---
# FactorVAE aims for disentanglement by adding a Total Correlation (TC) penalty.

class FactorVAE(nn.Module):
    def __init__(self, image_size, z_dim):
        super(FactorVAE, self).__init__()
        self.image_size = image_size
        self.z_dim = z_dim

        # Encoder (identical to Vanilla/Beta VAE)
        self.encoder = nn.Sequential(
            nn.Linear(image_size, 512),
            nn.ReLU(),
            nn.Linear(512, 256),
            nn.ReLU(),
            nn.Linear(256, 128)
        )
        self.fc_mu = nn.Linear(128, z_dim)
        self.fc_logvar = nn.Linear(128, z_dim)

        # Decoder (identical to Vanilla/Beta VAE)
        self.decoder = nn.Sequential(
            nn.Linear(z_dim, 256),
            nn.ReLU(),
            nn.Linear(256, 512),
            nn.ReLU(),
            nn.Linear(512, image_size),
            nn.Sigmoid()
        )

    def reparameterize(self, mu, log_var):
        std = torch.exp(0.5 * log_var)
        eps = torch.randn_like(std)
        return mu + eps * std

    def forward(self, x):
        # Encode
        h = self.encoder(x.view(-1, self.image_size))
        mu = self.fc_mu(h)
        log_var = self.fc_logvar(h)
        z = self.reparameterize(mu, log_var)

        # Decode
        recon_x = self.decoder(z)
        return recon_x, mu, log_var, z # Return z for TC calculation

# --- Discriminator for FactorVAE ---
class Discriminator(nn.Module):
    def __init__(self, z_dim):
        super(Discriminator, self).__init__()
        self.z_dim = z_dim
        self.model = nn.Sequential(
            nn.Linear(z_dim, 1000),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Linear(1000, 1000),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Linear(1000, 1000),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Linear(1000, 1000),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Linear(1000, 1000),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Linear(1000, 1000),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Linear(1000, 2) # Output logits for binary classification (real vs. permuted)
        )

    def forward(self, z):
        return self.model(z)



# --- FactorVAE Loss Function Components ---
# The loss calculation is more complex and will be handled within the training loop.
# Here's the KL divergence part, standard for VAEs.
def kl_divergence(mu, log_var):
    return -0.5 * torch.sum(1 + log_var - mu.pow(2) - log_var.exp())




# --- Setup for FactorVAE Training ---
factor_vae_z_dim = z1_dim # Still 64 for consistency
# Hyperparameter gamma for Total Correlation loss
factor_vae_gamma = 10.0 # Common values range from 1 to 100
# Discriminator training iterations per VAE training iteration
num_discriminator_steps = 1 # Usually 1 or 2

factor_vae_model = FactorVAE(image_size, factor_vae_z_dim).to(device)
discriminator_model = Discriminator(factor_vae_z_dim).to(device)

factor_vae_optimizer = torch.optim.Adam(factor_vae_model.parameters(), lr=learning_rate)
discriminator_optimizer = torch.optim.Adam(discriminator_model.parameters(), lr=learning_rate)

# Binary Cross-Entropy Loss for the discriminator
bce_logits = nn.CrossEntropyLoss() # For D, 2 output logits

print("\n--- FactorVAE Model ---")
print(factor_vae_model)
print("\n--- FactorVAE Discriminator Model ---")
print(discriminator_model)

# --- Training Loop for FactorVAE ---
print(f"\nStarting FactorVAE training with gamma = {factor_vae_gamma}...")
for epoch in range(num_epochs):
    factor_vae_model.train()
    discriminator_model.train()
    total_vae_loss = 0
    total_disc_loss = 0

    for i, (images, _,_) in enumerate(train_loader):
        images = images.to(device)
        batch_size = images.size(0)

        # --- Train Discriminator ---
        for _ in range(num_discriminator_steps):
            discriminator_optimizer.zero_grad()

            recon_images, mu, log_var, z = factor_vae_model(images) # Get z for discriminator

            # Sample z from aggregate posterior q(z) - approximated by current batch z's
            # Create a permuted copy of z
            z_permuted = []
            for _z in z.transpose(0, 1): # Iterate over each latent dimension
                idx = torch.randperm(batch_size) # Random permutation for each dim
                z_permuted.append(_z[idx])
            z_permuted = torch.stack(z_permuted, 1) # Stack back to (batch_size, z_dim)

            # Pass through discriminator
            d_z = discriminator_model(z.detach()) # Detach z from VAE graph
            d_z_permuted = discriminator_model(z_permuted.detach()) # Detach z_permuted

            # Discriminator loss: try to classify real vs. permuted
            # Real samples should be classified as 0, permuted as 1 (or vice-versa depending on setup)
            real_labels = torch.zeros(batch_size).long().to(device) # Label 0 for original
            perm_labels = torch.ones(batch_size).long().to(device)  # Label 1 for permuted

            disc_loss = 0.5 * (bce_logits(d_z, real_labels) + bce_logits(d_z_permuted, perm_labels))

            disc_loss.backward()
            discriminator_optimizer.step()
            total_disc_loss += disc_loss.item()

        # --- Train VAE ---
        factor_vae_optimizer.zero_grad()

        recon_images, mu, log_var, z = factor_vae_model(images)

        # 1. Reconstruction Loss
        recon_loss = F.binary_cross_entropy(recon_images, images.view(-1, image_size), reduction='sum')

        # 2. KL Divergence (Standard VAE KLD)
        kld_loss = kl_divergence(mu, log_var)

        # 3. Total Correlation (TC) Loss
        # This term tries to fool the discriminator into thinking real samples are permuted.
        # It's log(D(z)) - log(1-D(z))
        d_z = discriminator_model(z) # No detach here, we want gradients to flow to VAE

        # Log-probabilities for TC calculation
        # The discriminator outputs 2 logits: [logit_real, logit_permuted]
        # P(z is real) = softmax(d_z)[0], P(z is permuted) = softmax(d_z)[1]
        # We want log(P(z is real) / P(z is permuted))

        # Safe way to compute log(P_real / P_permuted) or similar quantities
        # using log_softmax and then subtraction
        logits_real = d_z[:, 0]
        logits_perm = d_z[:, 1]

        # TC loss is derived from the discriminator's ability to distinguish real from permuted.
        # It's (log(D(z)_real) - log(D(z)_permuted)) for the VAE's loss,
        # encouraging D(z)_real to be small and D(z)_permuted to be large.
        # This is essentially making D(z) predict permuted for real samples.
        tc_loss = (logits_real - logits_perm).mean() # As per FactorVAE paper's interpretation

        # Full VAE Loss
        vae_loss = recon_loss + kld_loss + factor_vae_gamma * tc_loss

        vae_loss.backward()
        factor_vae_optimizer.step()
        total_vae_loss += vae_loss.item()

        if (i+1) % 100 == 0:
            print(f"FactorVAE - Epoch [{epoch+1}/{num_epochs}], Step [{i+1}/{len(train_loader)}], VAE Loss: {vae_loss.item():.4f}, Disc Loss: {disc_loss.item():.4f}")

    avg_vae_loss = total_vae_loss / len(train_loader.dataset)
    avg_disc_loss = total_disc_loss / (len(train_loader.dataset) * num_discriminator_steps)

    print(f"FactorVAE - Epoch [{epoch+1}/{num_epochs}] completed. Avg VAE Loss: {avg_vae_loss:.4f}")
print("Training complete!")
# Out:
# --- FactorVAE Model ---
# FactorVAE(
#   (encoder): Sequential(
#     (0): Linear(in_features=4096, out_features=512, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=512, out_features=256, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=256, out_features=128, bias=True)
#   )
#   (fc_mu): Linear(in_features=128, out_features=64, bias=True)
#   (fc_logvar): Linear(in_features=128, out_features=64, bias=True)
#   (decoder): Sequential(
#     (0): Linear(in_features=64, out_features=256, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=256, out_features=512, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=512, out_features=4096, bias=True)
#     (5): Sigmoid()
#   )
# )
#
# --- FactorVAE Discriminator Model ---
# Discriminator(
#   (model): Sequential(
#     (0): Linear(in_features=64, out_features=1000, bias=True)
#     (1): LeakyReLU(negative_slope=0.2, inplace=True)
#     (2): Linear(in_features=1000, out_features=1000, bias=True)
#     (3): LeakyReLU(negative_slope=0.2, inplace=True)
#     (4): Linear(in_features=1000, out_features=1000, bias=True)
#     (5): LeakyReLU(negative_slope=0.2, inplace=True)
#     (6): Linear(in_features=1000, out_features=1000, bias=True)
#     (7): LeakyReLU(negative_slope=0.2, inplace=True)
#     (8): Linear(in_features=1000, out_features=1000, bias=True)
#     (9): LeakyReLU(negative_slope=0.2, inplace=True)
#     (10): Linear(in_features=1000, out_features=1000, bias=True)
#     (11): LeakyReLU(negative_slope=0.2, inplace=True)
#     (12): Linear(in_features=1000, out_features=2, bias=True)
#   )
# )
#
# Starting FactorVAE training with gamma = 10.0...
# FactorVAE - Epoch [1/10], Step [100/4608], VAE Loss: 71280.8750, Disc Loss: 0.6953
# FactorVAE - Epoch [1/10], Step [200/4608], VAE Loss: 26951.4160, Disc Loss: 0.0478
# FactorVAE - Epoch [1/10], Step [300/4608], VAE Loss: 23126.5625, Disc Loss: 0.0379
# FactorVAE - Epoch [1/10], Step [400/4608], VAE Loss: 21894.5137, Disc Loss: 0.0305
# FactorVAE - Epoch [1/10], Step [500/4608], VAE Loss: 20980.9961, Disc Loss: 0.0291
# FactorVAE - Epoch [1/10], Step [600/4608], VAE Loss: 20100.1289, Disc Loss: 0.0459
# FactorVAE - Epoch [1/10], Step [700/4608], VAE Loss: 19425.6465, Disc Loss: 0.0372
# FactorVAE - Epoch [1/10], Step [800/4608], VAE Loss: 18432.2227, Disc Loss: 0.0150
# FactorVAE - Epoch [1/10], Step [900/4608], VAE Loss: 18450.6367, Disc Loss: 0.0708
# FactorVAE - Epoch [1/10], Step [1000/4608], VAE Loss: 17634.2344, Disc Loss: 0.0310
# FactorVAE - Epoch [1/10], Step [1100/4608], VAE Loss: 16730.7070, Disc Loss: 0.0700
# FactorVAE - Epoch [1/10], Step [1200/4608], VAE Loss: 17392.5664, Disc Loss: 0.0543
# FactorVAE - Epoch [1/10], Step [1300/4608], VAE Loss: 17372.9121, Disc Loss: 0.0568
# FactorVAE - Epoch [1/10], Step [1400/4608], VAE Loss: 15915.6221, Disc Loss: 0.0627
# FactorVAE - Epoch [1/10], Step [1500/4608], VAE Loss: 16324.3379, Disc Loss: 0.1023
# FactorVAE - Epoch [1/10], Step [1600/4608], VAE Loss: 15417.8975, Disc Loss: 0.0415
# FactorVAE - Epoch [1/10], Step [1700/4608], VAE Loss: 15730.8457, Disc Loss: 0.1062
# FactorVAE - Epoch [1/10], Step [1800/4608], VAE Loss: 15713.1475, Disc Loss: 0.1281
# FactorVAE - Epoch [1/10], Step [1900/4608], VAE Loss: 14834.4033, Disc Loss: 0.1446
# FactorVAE - Epoch [1/10], Step [2000/4608], VAE Loss: 15273.8604, Disc Loss: 0.2112
# FactorVAE - Epoch [1/10], Step [2100/4608], VAE Loss: 13968.9805, Disc Loss: 0.2903
# FactorVAE - Epoch [1/10], Step [2200/4608], VAE Loss: 15021.4521, Disc Loss: 0.2794
# FactorVAE - Epoch [1/10], Step [2300/4608], VAE Loss: 13981.1045, Disc Loss: 0.1935
# FactorVAE - Epoch [1/10], Step [2400/4608], VAE Loss: 13171.8115, Disc Loss: 0.2747
# FactorVAE - Epoch [1/10], Step [2500/4608], VAE Loss: 14846.1650, Disc Loss: 0.2826
# FactorVAE - Epoch [1/10], Step [2600/4608], VAE Loss: 13211.5859, Disc Loss: 0.2568
# FactorVAE - Epoch [1/10], Step [2700/4608], VAE Loss: 13799.3457, Disc Loss: 0.2739
# FactorVAE - Epoch [1/10], Step [2800/4608], VAE Loss: 13736.0801, Disc Loss: 0.3314
# FactorVAE - Epoch [1/10], Step [2900/4608], VAE Loss: 14153.3652, Disc Loss: 0.3446
# FactorVAE - Epoch [1/10], Step [3000/4608], VAE Loss: 12964.5576, Disc Loss: 0.3759
# FactorVAE - Epoch [1/10], Step [3100/4608], VAE Loss: 13995.5244, Disc Loss: 0.3362
# FactorVAE - Epoch [1/10], Step [3200/4608], VAE Loss: 13902.4463, Disc Loss: 0.4058
# FactorVAE - Epoch [1/10], Step [3300/4608], VAE Loss: 14049.4102, Disc Loss: 0.3454
# FactorVAE - Epoch [1/10], Step [3400/4608], VAE Loss: 13435.4492, Disc Loss: 0.3979
# FactorVAE - Epoch [1/10], Step [3500/4608], VAE Loss: 12933.0537, Disc Loss: 0.3804
# FactorVAE - Epoch [1/10], Step [3600/4608], VAE Loss: 13503.6377, Disc Loss: 0.4347
# FactorVAE - Epoch [1/10], Step [3700/4608], VAE Loss: 14376.7041, Disc Loss: 0.4081
# FactorVAE - Epoch [1/10], Step [3800/4608], VAE Loss: 12982.5654, Disc Loss: 0.3783
# FactorVAE - Epoch [1/10], Step [3900/4608], VAE Loss: 13390.7451, Disc Loss: 0.4064
# FactorVAE - Epoch [1/10], Step [4000/4608], VAE Loss: 13194.3857, Disc Loss: 0.3289
# FactorVAE - Epoch [1/10], Step [4100/4608], VAE Loss: 12323.5527, Disc Loss: 0.3702
# FactorVAE - Epoch [1/10], Step [4200/4608], VAE Loss: 13124.3809, Disc Loss: 0.3243
# FactorVAE - Epoch [1/10], Step [4300/4608], VAE Loss: 12512.7607, Disc Loss: 0.3758
# FactorVAE - Epoch [1/10], Step [4400/4608], VAE Loss: 12412.6484, Disc Loss: 0.4022
# FactorVAE - Epoch [1/10], Step [4500/4608], VAE Loss: 13234.2080, Disc Loss: 0.3725
# FactorVAE - Epoch [1/10], Step [4600/4608], VAE Loss: 12523.4209, Disc Loss: 0.3378
# FactorVAE - Epoch [1/10] completed. Avg VAE Loss: 138.7801
# FactorVAE - Epoch [2/10], Step [100/4608], VAE Loss: 12577.6982, Disc Loss: 0.3987
# FactorVAE - Epoch [2/10], Step [200/4608], VAE Loss: 12157.4609, Disc Loss: 0.4017
# FactorVAE - Epoch [2/10], Step [300/4608], VAE Loss: 12851.6084, Disc Loss: 0.3811
# FactorVAE - Epoch [2/10], Step [400/4608], VAE Loss: 11744.0908, Disc Loss: 0.3448
# FactorVAE - Epoch [2/10], Step [500/4608], VAE Loss: 11931.5664, Disc Loss: 0.3330
# FactorVAE - Epoch [2/10], Step [600/4608], VAE Loss: 12468.6191, Disc Loss: 0.2953
# FactorVAE - Epoch [2/10], Step [700/4608], VAE Loss: 11725.9443, Disc Loss: 0.3879
# FactorVAE - Epoch [2/10], Step [800/4608], VAE Loss: 12861.8652, Disc Loss: 0.3149
# FactorVAE - Epoch [2/10], Step [900/4608], VAE Loss: 11716.0596, Disc Loss: 0.3769
# FactorVAE - Epoch [2/10], Step [1000/4608], VAE Loss: 12337.2666, Disc Loss: 0.3137
# FactorVAE - Epoch [2/10], Step [1100/4608], VAE Loss: 12670.1123, Disc Loss: 0.3522
# FactorVAE - Epoch [2/10], Step [1200/4608], VAE Loss: 12361.9434, Disc Loss: 0.2599
# FactorVAE - Epoch [2/10], Step [1300/4608], VAE Loss: 11578.7959, Disc Loss: 0.3782
# FactorVAE - Epoch [2/10], Step [1400/4608], VAE Loss: 11969.7939, Disc Loss: 0.3309
# FactorVAE - Epoch [2/10], Step [1500/4608], VAE Loss: 12802.6455, Disc Loss: 0.2611
# FactorVAE - Epoch [2/10], Step [1600/4608], VAE Loss: 11657.5986, Disc Loss: 0.2999
# FactorVAE - Epoch [2/10], Step [1700/4608], VAE Loss: 12803.4385, Disc Loss: 0.3075
# FactorVAE - Epoch [2/10], Step [1800/4608], VAE Loss: 12280.5469, Disc Loss: 0.2940
# FactorVAE - Epoch [2/10], Step [1900/4608], VAE Loss: 11819.8398, Disc Loss: 0.3020
# FactorVAE - Epoch [2/10], Step [2000/4608], VAE Loss: 12442.3115, Disc Loss: 0.3429
# FactorVAE - Epoch [2/10], Step [2100/4608], VAE Loss: 11838.2275, Disc Loss: 0.3368
# FactorVAE - Epoch [2/10], Step [2200/4608], VAE Loss: 11934.5518, Disc Loss: 0.3165
# FactorVAE - Epoch [2/10], Step [2300/4608], VAE Loss: 11639.3564, Disc Loss: 0.3104
# FactorVAE - Epoch [2/10], Step [2400/4608], VAE Loss: 11999.5947, Disc Loss: 0.3578
# FactorVAE - Epoch [2/10], Step [2500/4608], VAE Loss: 11779.0703, Disc Loss: 0.3032
# FactorVAE - Epoch [2/10], Step [2600/4608], VAE Loss: 11506.2959, Disc Loss: 0.3060
# FactorVAE - Epoch [2/10], Step [2700/4608], VAE Loss: 11456.5771, Disc Loss: 0.3330
# FactorVAE - Epoch [2/10], Step [2800/4608], VAE Loss: 11971.5625, Disc Loss: 0.3596
# FactorVAE - Epoch [2/10], Step [2900/4608], VAE Loss: 11736.6240, Disc Loss: 0.3378
# FactorVAE - Epoch [2/10], Step [3000/4608], VAE Loss: 11606.1299, Disc Loss: 0.2647
# FactorVAE - Epoch [2/10], Step [3100/4608], VAE Loss: 11358.3223, Disc Loss: 0.3270
# FactorVAE - Epoch [2/10], Step [3200/4608], VAE Loss: 12913.6943, Disc Loss: 0.2538
# FactorVAE - Epoch [2/10], Step [3300/4608], VAE Loss: 11866.0479, Disc Loss: 0.2297
# FactorVAE - Epoch [2/10], Step [3400/4608], VAE Loss: 12138.2295, Disc Loss: 0.2910
# FactorVAE - Epoch [2/10], Step [3500/4608], VAE Loss: 11745.4756, Disc Loss: 0.3236
# FactorVAE - Epoch [2/10], Step [3600/4608], VAE Loss: 11917.8105, Disc Loss: 0.2781
# FactorVAE - Epoch [2/10], Step [3700/4608], VAE Loss: 11642.1670, Disc Loss: 0.3394
# FactorVAE - Epoch [2/10], Step [3800/4608], VAE Loss: 11406.7256, Disc Loss: 0.3222
# FactorVAE - Epoch [2/10], Step [3900/4608], VAE Loss: 11558.9551, Disc Loss: 0.3561
# FactorVAE - Epoch [2/10], Step [4000/4608], VAE Loss: 10910.6914, Disc Loss: 0.3425
# FactorVAE - Epoch [2/10], Step [4100/4608], VAE Loss: 11297.0293, Disc Loss: 0.3256
# FactorVAE - Epoch [2/10], Step [4200/4608], VAE Loss: 12256.9473, Disc Loss: 0.2714
# FactorVAE - Epoch [2/10], Step [4300/4608], VAE Loss: 11859.4170, Disc Loss: 0.3636
# FactorVAE - Epoch [2/10], Step [4400/4608], VAE Loss: 11521.9033, Disc Loss: 0.3510
# FactorVAE - Epoch [2/10], Step [4500/4608], VAE Loss: 11890.8379, Disc Loss: 0.3285
# FactorVAE - Epoch [2/10], Step [4600/4608], VAE Loss: 11781.9395, Disc Loss: 0.3087
# FactorVAE - Epoch [2/10] completed. Avg VAE Loss: 93.1325
# FactorVAE - Epoch [3/10], Step [100/4608], VAE Loss: 11603.4082, Disc Loss: 0.3331
# FactorVAE - Epoch [3/10], Step [200/4608], VAE Loss: 11600.7334, Disc Loss: 0.3405
# FactorVAE - Epoch [3/10], Step [300/4608], VAE Loss: 11490.0869, Disc Loss: 0.3849
# FactorVAE - Epoch [3/10], Step [400/4608], VAE Loss: 11955.2549, Disc Loss: 0.3141
# FactorVAE - Epoch [3/10], Step [500/4608], VAE Loss: 11166.1260, Disc Loss: 0.3367
# FactorVAE - Epoch [3/10], Step [600/4608], VAE Loss: 11444.7441, Disc Loss: 0.3074
# FactorVAE - Epoch [3/10], Step [700/4608], VAE Loss: 11098.4980, Disc Loss: 0.3221
# FactorVAE - Epoch [3/10], Step [800/4608], VAE Loss: 11644.7236, Disc Loss: 0.4008
# FactorVAE - Epoch [3/10], Step [900/4608], VAE Loss: 11666.5127, Disc Loss: 0.3136
# FactorVAE - Epoch [3/10], Step [1000/4608], VAE Loss: 12402.8857, Disc Loss: 0.3091
# FactorVAE - Epoch [3/10], Step [1100/4608], VAE Loss: 11166.7480, Disc Loss: 0.3562
# FactorVAE - Epoch [3/10], Step [1200/4608], VAE Loss: 11710.2559, Disc Loss: 0.3567
# FactorVAE - Epoch [3/10], Step [1300/4608], VAE Loss: 11454.7842, Disc Loss: 0.3504
# FactorVAE - Epoch [3/10], Step [1400/4608], VAE Loss: 11273.0908, Disc Loss: 0.3133
# FactorVAE - Epoch [3/10], Step [1500/4608], VAE Loss: 11185.0518, Disc Loss: 0.3327
# FactorVAE - Epoch [3/10], Step [1600/4608], VAE Loss: 11828.3096, Disc Loss: 0.4637
# FactorVAE - Epoch [3/10], Step [1700/4608], VAE Loss: 11156.0420, Disc Loss: 0.4120
# FactorVAE - Epoch [3/10], Step [1800/4608], VAE Loss: 10247.9971, Disc Loss: 0.3429
# FactorVAE - Epoch [3/10], Step [1900/4608], VAE Loss: 10291.6602, Disc Loss: 0.3366
# FactorVAE - Epoch [3/10], Step [2000/4608], VAE Loss: 11122.2646, Disc Loss: 0.3674
# FactorVAE - Epoch [3/10], Step [2100/4608], VAE Loss: 10630.5303, Disc Loss: 0.3072
# FactorVAE - Epoch [3/10], Step [2200/4608], VAE Loss: 11069.6064, Disc Loss: 0.3375
# FactorVAE - Epoch [3/10], Step [2300/4608], VAE Loss: 11154.8633, Disc Loss: 0.3192
# FactorVAE - Epoch [3/10], Step [2400/4608], VAE Loss: 11394.2490, Disc Loss: 0.3514
# FactorVAE - Epoch [3/10], Step [2500/4608], VAE Loss: 11475.6201, Disc Loss: 0.3179
# FactorVAE - Epoch [3/10], Step [2600/4608], VAE Loss: 10910.8447, Disc Loss: 0.3649
# FactorVAE - Epoch [3/10], Step [2700/4608], VAE Loss: 10660.4453, Disc Loss: 0.3809
# FactorVAE - Epoch [3/10], Step [2800/4608], VAE Loss: 10945.8965, Disc Loss: 0.3342
# FactorVAE - Epoch [3/10], Step [2900/4608], VAE Loss: 10740.5205, Disc Loss: 0.4074
# FactorVAE - Epoch [3/10], Step [3000/4608], VAE Loss: 10382.7568, Disc Loss: 0.4280
# FactorVAE - Epoch [3/10], Step [3100/4608], VAE Loss: 9962.7490, Disc Loss: 0.3531
# FactorVAE - Epoch [3/10], Step [3200/4608], VAE Loss: 11031.9365, Disc Loss: 0.3792
# FactorVAE - Epoch [3/10], Step [3300/4608], VAE Loss: 10616.4795, Disc Loss: 0.3445
# FactorVAE - Epoch [3/10], Step [3400/4608], VAE Loss: 10964.2686, Disc Loss: 0.3434
# FactorVAE - Epoch [3/10], Step [3500/4608], VAE Loss: 10619.2744, Disc Loss: 0.3301
# FactorVAE - Epoch [3/10], Step [3600/4608], VAE Loss: 10380.5371, Disc Loss: 0.3272
# FactorVAE - Epoch [3/10], Step [3700/4608], VAE Loss: 10186.1289, Disc Loss: 0.3651
# FactorVAE - Epoch [3/10], Step [3800/4608], VAE Loss: 11274.8848, Disc Loss: 0.3858
# FactorVAE - Epoch [3/10], Step [3900/4608], VAE Loss: 10235.4062, Disc Loss: 0.4043
# FactorVAE - Epoch [3/10], Step [4000/4608], VAE Loss: 10214.6455, Disc Loss: 0.3326
# FactorVAE - Epoch [3/10], Step [4100/4608], VAE Loss: 10185.5498, Disc Loss: 0.3485
# FactorVAE - Epoch [3/10], Step [4200/4608], VAE Loss: 10183.6846, Disc Loss: 0.3880
# FactorVAE - Epoch [3/10], Step [4300/4608], VAE Loss: 10530.8975, Disc Loss: 0.3844
# FactorVAE - Epoch [3/10], Step [4400/4608], VAE Loss: 10027.6895, Disc Loss: 0.4047
# FactorVAE - Epoch [3/10], Step [4500/4608], VAE Loss: 10527.6387, Disc Loss: 0.2977
# FactorVAE - Epoch [3/10], Step [4600/4608], VAE Loss: 9980.6143, Disc Loss: 0.3660
# FactorVAE - Epoch [3/10] completed. Avg VAE Loss: 85.4323
# FactorVAE - Epoch [4/10], Step [100/4608], VAE Loss: 10440.6064, Disc Loss: 0.3086
# FactorVAE - Epoch [4/10], Step [200/4608], VAE Loss: 9966.8633, Disc Loss: 0.3222
# FactorVAE - Epoch [4/10], Step [300/4608], VAE Loss: 10554.7451, Disc Loss: 0.3205
# FactorVAE - Epoch [4/10], Step [400/4608], VAE Loss: 10688.4756, Disc Loss: 0.3787
# FactorVAE - Epoch [4/10], Step [500/4608], VAE Loss: 10685.1270, Disc Loss: 0.3458
# FactorVAE - Epoch [4/10], Step [600/4608], VAE Loss: 9969.9111, Disc Loss: 0.3449
# FactorVAE - Epoch [4/10], Step [700/4608], VAE Loss: 11135.4053, Disc Loss: 0.3373
# FactorVAE - Epoch [4/10], Step [800/4608], VAE Loss: 10046.3809, Disc Loss: 0.3737
# FactorVAE - Epoch [4/10], Step [900/4608], VAE Loss: 11131.1436, Disc Loss: 0.3529
# FactorVAE - Epoch [4/10], Step [1000/4608], VAE Loss: 10319.2529, Disc Loss: 0.4321
# FactorVAE - Epoch [4/10], Step [1100/4608], VAE Loss: 10042.2285, Disc Loss: 0.3762
# FactorVAE - Epoch [4/10], Step [1200/4608], VAE Loss: 11158.5742, Disc Loss: 0.3382
# FactorVAE - Epoch [4/10], Step [1300/4608], VAE Loss: 9904.4160, Disc Loss: 0.3492
# FactorVAE - Epoch [4/10], Step [1400/4608], VAE Loss: 10500.8652, Disc Loss: 0.3442
# FactorVAE - Epoch [4/10], Step [1500/4608], VAE Loss: 10093.7939, Disc Loss: 0.3749
# FactorVAE - Epoch [4/10], Step [1600/4608], VAE Loss: 9942.1094, Disc Loss: 0.4011
# FactorVAE - Epoch [4/10], Step [1700/4608], VAE Loss: 10299.6924, Disc Loss: 0.3051
# FactorVAE - Epoch [4/10], Step [1800/4608], VAE Loss: 10034.2861, Disc Loss: 0.3341
# FactorVAE - Epoch [4/10], Step [1900/4608], VAE Loss: 10587.9385, Disc Loss: 0.3969
# FactorVAE - Epoch [4/10], Step [2000/4608], VAE Loss: 10233.2354, Disc Loss: 0.3727
# FactorVAE - Epoch [4/10], Step [2100/4608], VAE Loss: 10513.6709, Disc Loss: 0.3736
# FactorVAE - Epoch [4/10], Step [2200/4608], VAE Loss: 10677.3438, Disc Loss: 0.3812
# FactorVAE - Epoch [4/10], Step [2300/4608], VAE Loss: 10062.4385, Disc Loss: 0.3593
# FactorVAE - Epoch [4/10], Step [2400/4608], VAE Loss: 10265.9980, Disc Loss: 0.3582
# FactorVAE - Epoch [4/10], Step [2500/4608], VAE Loss: 10151.6045, Disc Loss: 0.3097
# FactorVAE - Epoch [4/10], Step [2600/4608], VAE Loss: 9335.6465, Disc Loss: 0.3901
# FactorVAE - Epoch [4/10], Step [2700/4608], VAE Loss: 10640.6348, Disc Loss: 0.3993
# FactorVAE - Epoch [4/10], Step [2800/4608], VAE Loss: 10426.3887, Disc Loss: 0.3429
# FactorVAE - Epoch [4/10], Step [2900/4608], VAE Loss: 10022.1592, Disc Loss: 0.3725
# FactorVAE - Epoch [4/10], Step [3000/4608], VAE Loss: 10002.5947, Disc Loss: 0.3449
# FactorVAE - Epoch [4/10], Step [3100/4608], VAE Loss: 9851.8838, Disc Loss: 0.4052
# FactorVAE - Epoch [4/10], Step [3200/4608], VAE Loss: 9614.7119, Disc Loss: 0.3451
# FactorVAE - Epoch [4/10], Step [3300/4608], VAE Loss: 10311.4102, Disc Loss: 0.4356
# FactorVAE - Epoch [4/10], Step [3400/4608], VAE Loss: 9951.8057, Disc Loss: 0.4047
# FactorVAE - Epoch [4/10], Step [3500/4608], VAE Loss: 9677.4102, Disc Loss: 0.4282
# FactorVAE - Epoch [4/10], Step [3600/4608], VAE Loss: 10108.5068, Disc Loss: 0.3775
# FactorVAE - Epoch [4/10], Step [3700/4608], VAE Loss: 9441.7051, Disc Loss: 0.3488
# FactorVAE - Epoch [4/10], Step [3800/4608], VAE Loss: 10079.9746, Disc Loss: 0.3497
# FactorVAE - Epoch [4/10], Step [3900/4608], VAE Loss: 10244.8340, Disc Loss: 0.3857
# FactorVAE - Epoch [4/10], Step [4000/4608], VAE Loss: 9863.8711, Disc Loss: 0.3637
# FactorVAE - Epoch [4/10], Step [4100/4608], VAE Loss: 10139.9434, Disc Loss: 0.3332
# FactorVAE - Epoch [4/10], Step [4200/4608], VAE Loss: 9738.0869, Disc Loss: 0.3706
# FactorVAE - Epoch [4/10], Step [4300/4608], VAE Loss: 10264.8125, Disc Loss: 0.3543
# FactorVAE - Epoch [4/10], Step [4400/4608], VAE Loss: 10127.3086, Disc Loss: 0.3053
# FactorVAE - Epoch [4/10], Step [4500/4608], VAE Loss: 9880.8662, Disc Loss: 0.3593
# FactorVAE - Epoch [4/10], Step [4600/4608], VAE Loss: 9867.3193, Disc Loss: 0.3094
# FactorVAE - Epoch [4/10] completed. Avg VAE Loss: 79.3868
# FactorVAE - Epoch [5/10], Step [100/4608], VAE Loss: 10149.3789, Disc Loss: 0.3592
# FactorVAE - Epoch [5/10], Step [200/4608], VAE Loss: 9200.0010, Disc Loss: 0.3396
# FactorVAE - Epoch [5/10], Step [300/4608], VAE Loss: 9959.4854, Disc Loss: 0.3324
# FactorVAE - Epoch [5/10], Step [400/4608], VAE Loss: 10302.7559, Disc Loss: 0.3459
# FactorVAE - Epoch [5/10], Step [500/4608], VAE Loss: 9612.5088, Disc Loss: 0.3636
# FactorVAE - Epoch [5/10], Step [600/4608], VAE Loss: 9812.4102, Disc Loss: 0.3504
# FactorVAE - Epoch [5/10], Step [700/4608], VAE Loss: 9857.9971, Disc Loss: 0.4274
# FactorVAE - Epoch [5/10], Step [800/4608], VAE Loss: 9369.1348, Disc Loss: 0.3898
# FactorVAE - Epoch [5/10], Step [900/4608], VAE Loss: 9738.1553, Disc Loss: 0.3555
# FactorVAE - Epoch [5/10], Step [1000/4608], VAE Loss: 9432.1104, Disc Loss: 0.3429
# FactorVAE - Epoch [5/10], Step [1100/4608], VAE Loss: 10126.4951, Disc Loss: 0.3762
# FactorVAE - Epoch [5/10], Step [1200/4608], VAE Loss: 9720.2432, Disc Loss: 0.3664
# FactorVAE - Epoch [5/10], Step [1300/4608], VAE Loss: 10111.3135, Disc Loss: 0.4625
# FactorVAE - Epoch [5/10], Step [1400/4608], VAE Loss: 9240.1436, Disc Loss: 0.3487
# FactorVAE - Epoch [5/10], Step [1500/4608], VAE Loss: 9979.6094, Disc Loss: 0.3810
# FactorVAE - Epoch [5/10], Step [1600/4608], VAE Loss: 9728.1328, Disc Loss: 0.4021
# FactorVAE - Epoch [5/10], Step [1700/4608], VAE Loss: 9976.3740, Disc Loss: 0.3695
# FactorVAE - Epoch [5/10], Step [1800/4608], VAE Loss: 9485.3047, Disc Loss: 0.3840
# FactorVAE - Epoch [5/10], Step [1900/4608], VAE Loss: 9251.6846, Disc Loss: 0.3783
# FactorVAE - Epoch [5/10], Step [2000/4608], VAE Loss: 10370.6895, Disc Loss: 0.3282
# FactorVAE - Epoch [5/10], Step [2100/4608], VAE Loss: 9839.3926, Disc Loss: 0.3886
# FactorVAE - Epoch [5/10], Step [2200/4608], VAE Loss: 9563.0439, Disc Loss: 0.3598
# FactorVAE - Epoch [5/10], Step [2300/4608], VAE Loss: 9768.1973, Disc Loss: 0.4210
# FactorVAE - Epoch [5/10], Step [2400/4608], VAE Loss: 9495.0107, Disc Loss: 0.4116
# FactorVAE - Epoch [5/10], Step [2500/4608], VAE Loss: 9484.9199, Disc Loss: 0.3209
# FactorVAE - Epoch [5/10], Step [2600/4608], VAE Loss: 10014.3096, Disc Loss: 0.3370
# FactorVAE - Epoch [5/10], Step [2700/4608], VAE Loss: 9730.2754, Disc Loss: 0.3681
# FactorVAE - Epoch [5/10], Step [2800/4608], VAE Loss: 9687.3320, Disc Loss: 0.3339
# FactorVAE - Epoch [5/10], Step [2900/4608], VAE Loss: 9712.5293, Disc Loss: 0.3401
# FactorVAE - Epoch [5/10], Step [3000/4608], VAE Loss: 9433.2412, Disc Loss: 0.3918
# FactorVAE - Epoch [5/10], Step [3100/4608], VAE Loss: 9839.1689, Disc Loss: 0.3640
# FactorVAE - Epoch [5/10], Step [3200/4608], VAE Loss: 9295.7432, Disc Loss: 0.3667
# FactorVAE - Epoch [5/10], Step [3300/4608], VAE Loss: 9268.6758, Disc Loss: 0.3108
# FactorVAE - Epoch [5/10], Step [3400/4608], VAE Loss: 9823.2031, Disc Loss: 0.3385
# FactorVAE - Epoch [5/10], Step [3500/4608], VAE Loss: 9687.1133, Disc Loss: 0.3649
# FactorVAE - Epoch [5/10], Step [3600/4608], VAE Loss: 9152.6270, Disc Loss: 0.3578
# FactorVAE - Epoch [5/10], Step [3700/4608], VAE Loss: 9531.0664, Disc Loss: 0.4180
# FactorVAE - Epoch [5/10], Step [3800/4608], VAE Loss: 10202.9619, Disc Loss: 0.4790
# FactorVAE - Epoch [5/10], Step [3900/4608], VAE Loss: 9755.3789, Disc Loss: 0.3679
# FactorVAE - Epoch [5/10], Step [4000/4608], VAE Loss: 9264.0742, Disc Loss: 0.3324
# FactorVAE - Epoch [5/10], Step [4100/4608], VAE Loss: 9627.3242, Disc Loss: 0.4427
# FactorVAE - Epoch [5/10], Step [4200/4608], VAE Loss: 8893.7178, Disc Loss: 0.3513
# FactorVAE - Epoch [5/10], Step [4300/4608], VAE Loss: 9265.6816, Disc Loss: 0.3625
# FactorVAE - Epoch [5/10], Step [4400/4608], VAE Loss: 8804.0186, Disc Loss: 0.4104
# FactorVAE - Epoch [5/10], Step [4500/4608], VAE Loss: 9098.6348, Disc Loss: 0.3271
# FactorVAE - Epoch [5/10], Step [4600/4608], VAE Loss: 9303.7070, Disc Loss: 0.3620
# FactorVAE - Epoch [5/10] completed. Avg VAE Loss: 75.2070
# FactorVAE - Epoch [6/10], Step [100/4608], VAE Loss: 9285.6582, Disc Loss: 0.3615
# FactorVAE - Epoch [6/10], Step [200/4608], VAE Loss: 9210.4521, Disc Loss: 0.3513
# FactorVAE - Epoch [6/10], Step [300/4608], VAE Loss: 8961.4971, Disc Loss: 0.3157
# FactorVAE - Epoch [6/10], Step [400/4608], VAE Loss: 10085.0176, Disc Loss: 0.4261
# FactorVAE - Epoch [6/10], Step [500/4608], VAE Loss: 9189.7930, Disc Loss: 0.3376
# FactorVAE - Epoch [6/10], Step [600/4608], VAE Loss: 9040.1084, Disc Loss: 0.3912
# FactorVAE - Epoch [6/10], Step [700/4608], VAE Loss: 9908.9854, Disc Loss: 0.3539
# FactorVAE - Epoch [6/10], Step [800/4608], VAE Loss: 8586.6094, Disc Loss: 0.3521
# FactorVAE - Epoch [6/10], Step [900/4608], VAE Loss: 10116.9492, Disc Loss: 0.4051
# FactorVAE - Epoch [6/10], Step [1000/4608], VAE Loss: 9334.3027, Disc Loss: 0.3994
# FactorVAE - Epoch [6/10], Step [1100/4608], VAE Loss: 9570.3525, Disc Loss: 0.3676
# FactorVAE - Epoch [6/10], Step [1200/4608], VAE Loss: 9061.2822, Disc Loss: 0.4149
# FactorVAE - Epoch [6/10], Step [1300/4608], VAE Loss: 9773.7490, Disc Loss: 0.3962
# FactorVAE - Epoch [6/10], Step [1400/4608], VAE Loss: 8857.1846, Disc Loss: 0.2994
# FactorVAE - Epoch [6/10], Step [1500/4608], VAE Loss: 9554.8711, Disc Loss: 0.4558
# FactorVAE - Epoch [6/10], Step [1600/4608], VAE Loss: 9443.0537, Disc Loss: 0.4017
# FactorVAE - Epoch [6/10], Step [1700/4608], VAE Loss: 9863.5068, Disc Loss: 0.3680
# FactorVAE - Epoch [6/10], Step [1800/4608], VAE Loss: 9476.2490, Disc Loss: 0.4025
# FactorVAE - Epoch [6/10], Step [1900/4608], VAE Loss: 9454.9248, Disc Loss: 0.3659
# FactorVAE - Epoch [6/10], Step [2000/4608], VAE Loss: 8755.8447, Disc Loss: 0.3437
# FactorVAE - Epoch [6/10], Step [2100/4608], VAE Loss: 10022.4688, Disc Loss: 0.3866
# FactorVAE - Epoch [6/10], Step [2200/4608], VAE Loss: 9437.5127, Disc Loss: 0.3627
# FactorVAE - Epoch [6/10], Step [2300/4608], VAE Loss: 9221.1836, Disc Loss: 0.3559
# FactorVAE - Epoch [6/10], Step [2400/4608], VAE Loss: 8906.7393, Disc Loss: 0.3162
# FactorVAE - Epoch [6/10], Step [2500/4608], VAE Loss: 9015.0967, Disc Loss: 0.3031
# FactorVAE - Epoch [6/10], Step [2600/4608], VAE Loss: 8963.2500, Disc Loss: 0.3262
# FactorVAE - Epoch [6/10], Step [2700/4608], VAE Loss: 9332.0605, Disc Loss: 0.3541
# FactorVAE - Epoch [6/10], Step [2800/4608], VAE Loss: 8628.7422, Disc Loss: 0.3494
# FactorVAE - Epoch [6/10], Step [2900/4608], VAE Loss: 9601.1426, Disc Loss: 0.3269
# FactorVAE - Epoch [6/10], Step [3000/4608], VAE Loss: 9499.6465, Disc Loss: 0.2822
# FactorVAE - Epoch [6/10], Step [3100/4608], VAE Loss: 8987.9219, Disc Loss: 0.3818
# FactorVAE - Epoch [6/10], Step [3200/4608], VAE Loss: 9085.4131, Disc Loss: 0.3054
# FactorVAE - Epoch [6/10], Step [3300/4608], VAE Loss: 9176.7471, Disc Loss: 0.3188
# FactorVAE - Epoch [6/10], Step [3400/4608], VAE Loss: 9165.1260, Disc Loss: 0.3486
# FactorVAE - Epoch [6/10], Step [3500/4608], VAE Loss: 9382.6436, Disc Loss: 0.3928
# FactorVAE - Epoch [6/10], Step [3600/4608], VAE Loss: 9410.3906, Disc Loss: 0.3215
# FactorVAE - Epoch [6/10], Step [3700/4608], VAE Loss: 8771.7256, Disc Loss: 0.3403
# FactorVAE - Epoch [6/10], Step [3800/4608], VAE Loss: 9243.6172, Disc Loss: 0.3825
# FactorVAE - Epoch [6/10], Step [3900/4608], VAE Loss: 9325.1738, Disc Loss: 0.3483
# FactorVAE - Epoch [6/10], Step [4000/4608], VAE Loss: 8734.3232, Disc Loss: 0.3619
# FactorVAE - Epoch [6/10], Step [4100/4608], VAE Loss: 8615.6299, Disc Loss: 0.3761
# FactorVAE - Epoch [6/10], Step [4200/4608], VAE Loss: 9523.4014, Disc Loss: 0.3806
# FactorVAE - Epoch [6/10], Step [4300/4608], VAE Loss: 8832.7764, Disc Loss: 0.4220
# FactorVAE - Epoch [6/10], Step [4400/4608], VAE Loss: 9545.0869, Disc Loss: 0.3041
# FactorVAE - Epoch [6/10], Step [4500/4608], VAE Loss: 9292.3242, Disc Loss: 0.3732
# FactorVAE - Epoch [6/10], Step [4600/4608], VAE Loss: 8740.7188, Disc Loss: 0.3810
# FactorVAE - Epoch [6/10] completed. Avg VAE Loss: 72.3057
# FactorVAE - Epoch [7/10], Step [100/4608], VAE Loss: 8851.0264, Disc Loss: 0.2898
# FactorVAE - Epoch [7/10], Step [200/4608], VAE Loss: 9200.7637, Disc Loss: 0.3474
# FactorVAE - Epoch [7/10], Step [300/4608], VAE Loss: 8928.5332, Disc Loss: 0.3926
# FactorVAE - Epoch [7/10], Step [400/4608], VAE Loss: 9305.8740, Disc Loss: 0.3719
# FactorVAE - Epoch [7/10], Step [500/4608], VAE Loss: 8998.3408, Disc Loss: 0.3628
# FactorVAE - Epoch [7/10], Step [600/4608], VAE Loss: 8907.0430, Disc Loss: 0.3435
# FactorVAE - Epoch [7/10], Step [700/4608], VAE Loss: 8731.3311, Disc Loss: 0.4483
# FactorVAE - Epoch [7/10], Step [800/4608], VAE Loss: 9355.9434, Disc Loss: 0.3464
# FactorVAE - Epoch [7/10], Step [900/4608], VAE Loss: 8743.3760, Disc Loss: 0.3745
# FactorVAE - Epoch [7/10], Step [1000/4608], VAE Loss: 9093.0527, Disc Loss: 0.3606
# FactorVAE - Epoch [7/10], Step [1100/4608], VAE Loss: 8967.7695, Disc Loss: 0.3366
# FactorVAE - Epoch [7/10], Step [1200/4608], VAE Loss: 9033.7217, Disc Loss: 0.3973
# FactorVAE - Epoch [7/10], Step [1300/4608], VAE Loss: 8942.6221, Disc Loss: 0.3709
# FactorVAE - Epoch [7/10], Step [1400/4608], VAE Loss: 8789.2773, Disc Loss: 0.4302
# FactorVAE - Epoch [7/10], Step [1500/4608], VAE Loss: 8693.8799, Disc Loss: 0.3726
# FactorVAE - Epoch [7/10], Step [1600/4608], VAE Loss: 9017.9961, Disc Loss: 0.2871
# FactorVAE - Epoch [7/10], Step [1700/4608], VAE Loss: 9148.6250, Disc Loss: 0.3119
# FactorVAE - Epoch [7/10], Step [1800/4608], VAE Loss: 8522.5166, Disc Loss: 0.3027
# FactorVAE - Epoch [7/10], Step [1900/4608], VAE Loss: 8961.8838, Disc Loss: 0.3389
# FactorVAE - Epoch [7/10], Step [2000/4608], VAE Loss: 9293.7920, Disc Loss: 0.4126
# FactorVAE - Epoch [7/10], Step [2100/4608], VAE Loss: 9030.8213, Disc Loss: 0.2985
# FactorVAE - Epoch [7/10], Step [2200/4608], VAE Loss: 8473.3076, Disc Loss: 0.3327
# FactorVAE - Epoch [7/10], Step [2300/4608], VAE Loss: 8914.7383, Disc Loss: 0.4362
# FactorVAE - Epoch [7/10], Step [2400/4608], VAE Loss: 9169.0000, Disc Loss: 0.4307
# FactorVAE - Epoch [7/10], Step [2500/4608], VAE Loss: 8989.8906, Disc Loss: 0.3976
# FactorVAE - Epoch [7/10], Step [2600/4608], VAE Loss: 8890.2988, Disc Loss: 0.3465
# FactorVAE - Epoch [7/10], Step [2700/4608], VAE Loss: 8965.6494, Disc Loss: 0.3719
# FactorVAE - Epoch [7/10], Step [2800/4608], VAE Loss: 9122.8877, Disc Loss: 0.3869
# FactorVAE - Epoch [7/10], Step [2900/4608], VAE Loss: 9201.1523, Disc Loss: 0.4173
# FactorVAE - Epoch [7/10], Step [3000/4608], VAE Loss: 9846.8623, Disc Loss: 0.3621
# FactorVAE - Epoch [7/10], Step [3100/4608], VAE Loss: 8735.9170, Disc Loss: 0.4293
# FactorVAE - Epoch [7/10], Step [3200/4608], VAE Loss: 9279.0332, Disc Loss: 0.3601
# FactorVAE - Epoch [7/10], Step [3300/4608], VAE Loss: 9377.5137, Disc Loss: 0.3354
# FactorVAE - Epoch [7/10], Step [3400/4608], VAE Loss: 8857.2676, Disc Loss: 0.3851
# FactorVAE - Epoch [7/10], Step [3500/4608], VAE Loss: 8657.0820, Disc Loss: 0.3052
# FactorVAE - Epoch [7/10], Step [3600/4608], VAE Loss: 8831.0508, Disc Loss: 0.3803
# FactorVAE - Epoch [7/10], Step [3700/4608], VAE Loss: 8727.4053, Disc Loss: 0.3638
# FactorVAE - Epoch [7/10], Step [3800/4608], VAE Loss: 9332.9004, Disc Loss: 0.3621
# FactorVAE - Epoch [7/10], Step [3900/4608], VAE Loss: 8753.9854, Disc Loss: 0.3059
# FactorVAE - Epoch [7/10], Step [4000/4608], VAE Loss: 8604.1787, Disc Loss: 0.3878
# FactorVAE - Epoch [7/10], Step [4100/4608], VAE Loss: 9152.3828, Disc Loss: 0.3298
# FactorVAE - Epoch [7/10], Step [4200/4608], VAE Loss: 8722.7383, Disc Loss: 0.3583
# FactorVAE - Epoch [7/10], Step [4300/4608], VAE Loss: 9386.2383, Disc Loss: 0.3862
# FactorVAE - Epoch [7/10], Step [4400/4608], VAE Loss: 9110.8047, Disc Loss: 0.3876
# FactorVAE - Epoch [7/10], Step [4500/4608], VAE Loss: 9331.6084, Disc Loss: 0.4162
# FactorVAE - Epoch [7/10], Step [4600/4608], VAE Loss: 9175.2070, Disc Loss: 0.3595
# FactorVAE - Epoch [7/10] completed. Avg VAE Loss: 70.2913
# FactorVAE - Epoch [8/10], Step [100/4608], VAE Loss: 8938.7158, Disc Loss: 0.4000
# FactorVAE - Epoch [8/10], Step [200/4608], VAE Loss: 8662.8496, Disc Loss: 0.3697
# FactorVAE - Epoch [8/10], Step [300/4608], VAE Loss: 8476.7227, Disc Loss: 0.3822
# FactorVAE - Epoch [8/10], Step [400/4608], VAE Loss: 8782.4141, Disc Loss: 0.3430
# FactorVAE - Epoch [8/10], Step [500/4608], VAE Loss: 9140.6250, Disc Loss: 0.3288
# FactorVAE - Epoch [8/10], Step [600/4608], VAE Loss: 8722.9971, Disc Loss: 0.3697
# FactorVAE - Epoch [8/10], Step [700/4608], VAE Loss: 8483.1562, Disc Loss: 0.3202
# FactorVAE - Epoch [8/10], Step [800/4608], VAE Loss: 9000.2188, Disc Loss: 0.3756
# FactorVAE - Epoch [8/10], Step [900/4608], VAE Loss: 9268.0850, Disc Loss: 0.3060
# FactorVAE - Epoch [8/10], Step [1000/4608], VAE Loss: 8894.1582, Disc Loss: 0.3177
# FactorVAE - Epoch [8/10], Step [1100/4608], VAE Loss: 8918.5547, Disc Loss: 0.2752
# FactorVAE - Epoch [8/10], Step [1200/4608], VAE Loss: 8995.3545, Disc Loss: 0.3347
# FactorVAE - Epoch [8/10], Step [1300/4608], VAE Loss: 8794.8320, Disc Loss: 0.3542
# FactorVAE - Epoch [8/10], Step [1400/4608], VAE Loss: 8796.4893, Disc Loss: 0.2884
# FactorVAE - Epoch [8/10], Step [1500/4608], VAE Loss: 9053.1973, Disc Loss: 0.3462
# FactorVAE - Epoch [8/10], Step [1600/4608], VAE Loss: 8718.1758, Disc Loss: 0.3424
# FactorVAE - Epoch [8/10], Step [1700/4608], VAE Loss: 9724.0527, Disc Loss: 0.3554
# FactorVAE - Epoch [8/10], Step [1800/4608], VAE Loss: 8567.0137, Disc Loss: 0.3636
# FactorVAE - Epoch [8/10], Step [1900/4608], VAE Loss: 8797.6533, Disc Loss: 0.3745
# FactorVAE - Epoch [8/10], Step [2000/4608], VAE Loss: 9578.5361, Disc Loss: 0.3435
# FactorVAE - Epoch [8/10], Step [2100/4608], VAE Loss: 9029.0596, Disc Loss: 0.3069
# FactorVAE - Epoch [8/10], Step [2200/4608], VAE Loss: 8574.8203, Disc Loss: 0.3853
# FactorVAE - Epoch [8/10], Step [2300/4608], VAE Loss: 8966.6279, Disc Loss: 0.3343
# FactorVAE - Epoch [8/10], Step [2400/4608], VAE Loss: 8908.4648, Disc Loss: 0.3622
# FactorVAE - Epoch [8/10], Step [2500/4608], VAE Loss: 8540.8184, Disc Loss: 0.3529
# FactorVAE - Epoch [8/10], Step [2600/4608], VAE Loss: 8699.3594, Disc Loss: 0.3647
# FactorVAE - Epoch [8/10], Step [2700/4608], VAE Loss: 8855.9092, Disc Loss: 0.3485
# FactorVAE - Epoch [8/10], Step [2800/4608], VAE Loss: 9464.1963, Disc Loss: 0.3223
# FactorVAE - Epoch [8/10], Step [2900/4608], VAE Loss: 8583.6396, Disc Loss: 0.3083
# FactorVAE - Epoch [8/10], Step [3000/4608], VAE Loss: 8592.4873, Disc Loss: 0.3602
# FactorVAE - Epoch [8/10], Step [3100/4608], VAE Loss: 8365.1035, Disc Loss: 0.3160
# FactorVAE - Epoch [8/10], Step [3200/4608], VAE Loss: 9124.0146, Disc Loss: 0.3877
# FactorVAE - Epoch [8/10], Step [3300/4608], VAE Loss: 8450.9219, Disc Loss: 0.3737
# FactorVAE - Epoch [8/10], Step [3400/4608], VAE Loss: 8955.0322, Disc Loss: 0.3164
# FactorVAE - Epoch [8/10], Step [3500/4608], VAE Loss: 8514.6641, Disc Loss: 0.4404
# FactorVAE - Epoch [8/10], Step [3600/4608], VAE Loss: 8739.7959, Disc Loss: 0.3404
# FactorVAE - Epoch [8/10], Step [3700/4608], VAE Loss: 8745.7539, Disc Loss: 0.3545
# FactorVAE - Epoch [8/10], Step [3800/4608], VAE Loss: 8835.6982, Disc Loss: 0.3985
# FactorVAE - Epoch [8/10], Step [3900/4608], VAE Loss: 8645.5020, Disc Loss: 0.3150
# FactorVAE - Epoch [8/10], Step [4000/4608], VAE Loss: 8939.3633, Disc Loss: 0.3394
# FactorVAE - Epoch [8/10], Step [4100/4608], VAE Loss: 9000.2324, Disc Loss: 0.3376
# FactorVAE - Epoch [8/10], Step [4200/4608], VAE Loss: 8582.9473, Disc Loss: 0.3285
# FactorVAE - Epoch [8/10], Step [4300/4608], VAE Loss: 9025.2627, Disc Loss: 0.4140
# FactorVAE - Epoch [8/10], Step [4400/4608], VAE Loss: 8566.3164, Disc Loss: 0.3639
# FactorVAE - Epoch [8/10], Step [4500/4608], VAE Loss: 8858.1846, Disc Loss: 0.3464
# FactorVAE - Epoch [8/10], Step [4600/4608], VAE Loss: 8746.1533, Disc Loss: 0.3352
# FactorVAE - Epoch [8/10] completed. Avg VAE Loss: 68.7960
# FactorVAE - Epoch [9/10], Step [100/4608], VAE Loss: 8395.0547, Disc Loss: 0.3333
# FactorVAE - Epoch [9/10], Step [200/4608], VAE Loss: 8394.5225, Disc Loss: 0.3685
# FactorVAE - Epoch [9/10], Step [300/4608], VAE Loss: 8541.0762, Disc Loss: 0.3720
# FactorVAE - Epoch [9/10], Step [400/4608], VAE Loss: 8584.2100, Disc Loss: 0.3690
# FactorVAE - Epoch [9/10], Step [500/4608], VAE Loss: 8682.5889, Disc Loss: 0.3745
# FactorVAE - Epoch [9/10], Step [600/4608], VAE Loss: 8695.6201, Disc Loss: 0.3062
# FactorVAE - Epoch [9/10], Step [700/4608], VAE Loss: 8936.7422, Disc Loss: 0.3611
# FactorVAE - Epoch [9/10], Step [800/4608], VAE Loss: 8874.2324, Disc Loss: 0.3450
# FactorVAE - Epoch [9/10], Step [900/4608], VAE Loss: 8340.2383, Disc Loss: 0.3356
# FactorVAE - Epoch [9/10], Step [1000/4608], VAE Loss: 8921.3525, Disc Loss: 0.3476
# FactorVAE - Epoch [9/10], Step [1100/4608], VAE Loss: 8880.8281, Disc Loss: 0.4073
# FactorVAE - Epoch [9/10], Step [1200/4608], VAE Loss: 8566.4287, Disc Loss: 0.3300
# FactorVAE - Epoch [9/10], Step [1300/4608], VAE Loss: 8917.9932, Disc Loss: 0.3426
# FactorVAE - Epoch [9/10], Step [1400/4608], VAE Loss: 8952.0752, Disc Loss: 0.3240
# FactorVAE - Epoch [9/10], Step [1500/4608], VAE Loss: 9314.9590, Disc Loss: 0.3432
# FactorVAE - Epoch [9/10], Step [1600/4608], VAE Loss: 9121.6328, Disc Loss: 0.2950
# FactorVAE - Epoch [9/10], Step [1700/4608], VAE Loss: 8054.8750, Disc Loss: 0.3391
# FactorVAE - Epoch [9/10], Step [1800/4608], VAE Loss: 9147.4746, Disc Loss: 0.3905
# FactorVAE - Epoch [9/10], Step [1900/4608], VAE Loss: 8858.6328, Disc Loss: 0.2903
# FactorVAE - Epoch [9/10], Step [2000/4608], VAE Loss: 8813.2803, Disc Loss: 0.3530
# FactorVAE - Epoch [9/10], Step [2100/4608], VAE Loss: 8954.3535, Disc Loss: 0.3911
# FactorVAE - Epoch [9/10], Step [2200/4608], VAE Loss: 8585.6289, Disc Loss: 0.3616
# FactorVAE - Epoch [9/10], Step [2300/4608], VAE Loss: 8770.6123, Disc Loss: 0.3753
# FactorVAE - Epoch [9/10], Step [2400/4608], VAE Loss: 8743.1143, Disc Loss: 0.4193
# FactorVAE - Epoch [9/10], Step [2500/4608], VAE Loss: 8625.1543, Disc Loss: 0.3398
# FactorVAE - Epoch [9/10], Step [2600/4608], VAE Loss: 8878.2842, Disc Loss: 0.3422
# FactorVAE - Epoch [9/10], Step [2700/4608], VAE Loss: 8195.0918, Disc Loss: 0.4010
# FactorVAE - Epoch [9/10], Step [2800/4608], VAE Loss: 8228.8906, Disc Loss: 0.4395
# FactorVAE - Epoch [9/10], Step [2900/4608], VAE Loss: 8868.2520, Disc Loss: 0.3267
# FactorVAE - Epoch [9/10], Step [3000/4608], VAE Loss: 8378.5625, Disc Loss: 0.2983
# FactorVAE - Epoch [9/10], Step [3100/4608], VAE Loss: 8650.4883, Disc Loss: 0.3840
# FactorVAE - Epoch [9/10], Step [3200/4608], VAE Loss: 8900.7256, Disc Loss: 0.3780
# FactorVAE - Epoch [9/10], Step [3300/4608], VAE Loss: 8388.3369, Disc Loss: 0.2940
# FactorVAE - Epoch [9/10], Step [3400/4608], VAE Loss: 8597.2832, Disc Loss: 0.3134
# FactorVAE - Epoch [9/10], Step [3500/4608], VAE Loss: 8000.7896, Disc Loss: 0.3380
# FactorVAE - Epoch [9/10], Step [3600/4608], VAE Loss: 9357.2188, Disc Loss: 0.3519
# FactorVAE - Epoch [9/10], Step [3700/4608], VAE Loss: 8055.9829, Disc Loss: 0.3035
# FactorVAE - Epoch [9/10], Step [3800/4608], VAE Loss: 8934.7744, Disc Loss: 0.2736
# FactorVAE - Epoch [9/10], Step [3900/4608], VAE Loss: 8683.8096, Disc Loss: 0.3790
# FactorVAE - Epoch [9/10], Step [4000/4608], VAE Loss: 8604.1631, Disc Loss: 0.2997
# FactorVAE - Epoch [9/10], Step [4100/4608], VAE Loss: 8853.1074, Disc Loss: 0.3769
# FactorVAE - Epoch [9/10], Step [4200/4608], VAE Loss: 8588.8770, Disc Loss: 0.3259
# FactorVAE - Epoch [9/10], Step [4300/4608], VAE Loss: 8346.6738, Disc Loss: 0.3447
# FactorVAE - Epoch [9/10], Step [4400/4608], VAE Loss: 8509.0889, Disc Loss: 0.3687
# FactorVAE - Epoch [9/10], Step [4500/4608], VAE Loss: 8592.3281, Disc Loss: 0.2990
# FactorVAE - Epoch [9/10], Step [4600/4608], VAE Loss: 8805.4561, Disc Loss: 0.4047
# FactorVAE - Epoch [9/10] completed. Avg VAE Loss: 67.6261
# FactorVAE - Epoch [10/10], Step [100/4608], VAE Loss: 8407.1611, Disc Loss: 0.3429
# FactorVAE - Epoch [10/10], Step [200/4608], VAE Loss: 7981.6265, Disc Loss: 0.3158
# FactorVAE - Epoch [10/10], Step [300/4608], VAE Loss: 8854.9082, Disc Loss: 0.4188
# FactorVAE - Epoch [10/10], Step [400/4608], VAE Loss: 8326.1074, Disc Loss: 0.3904
# FactorVAE - Epoch [10/10], Step [500/4608], VAE Loss: 8510.5078, Disc Loss: 0.3817
# FactorVAE - Epoch [10/10], Step [600/4608], VAE Loss: 9109.9121, Disc Loss: 0.3641
# FactorVAE - Epoch [10/10], Step [700/4608], VAE Loss: 8712.9619, Disc Loss: 0.3656
# FactorVAE - Epoch [10/10], Step [800/4608], VAE Loss: 8673.3457, Disc Loss: 0.3246
# FactorVAE - Epoch [10/10], Step [900/4608], VAE Loss: 7951.6753, Disc Loss: 0.2804
# FactorVAE - Epoch [10/10], Step [1000/4608], VAE Loss: 8489.0039, Disc Loss: 0.4418
# FactorVAE - Epoch [10/10], Step [1100/4608], VAE Loss: 8914.4150, Disc Loss: 0.3642
# FactorVAE - Epoch [10/10], Step [1200/4608], VAE Loss: 9009.4453, Disc Loss: 0.4181
# FactorVAE - Epoch [10/10], Step [1300/4608], VAE Loss: 8697.6826, Disc Loss: 0.3348
# FactorVAE - Epoch [10/10], Step [1400/4608], VAE Loss: 8085.0425, Disc Loss: 0.3720
# FactorVAE - Epoch [10/10], Step [1500/4608], VAE Loss: 8528.3623, Disc Loss: 0.3198
# FactorVAE - Epoch [10/10], Step [1600/4608], VAE Loss: 8678.6963, Disc Loss: 0.3189
# FactorVAE - Epoch [10/10], Step [1700/4608], VAE Loss: 8491.2773, Disc Loss: 0.3316
# FactorVAE - Epoch [10/10], Step [1800/4608], VAE Loss: 8733.4941, Disc Loss: 0.3232
# FactorVAE - Epoch [10/10], Step [1900/4608], VAE Loss: 8709.4893, Disc Loss: 0.3653
# FactorVAE - Epoch [10/10], Step [2000/4608], VAE Loss: 8289.5010, Disc Loss: 0.3212
# FactorVAE - Epoch [10/10], Step [2100/4608], VAE Loss: 8571.2314, Disc Loss: 0.3744
# FactorVAE - Epoch [10/10], Step [2200/4608], VAE Loss: 8971.9766, Disc Loss: 0.3560
# FactorVAE - Epoch [10/10], Step [2300/4608], VAE Loss: 8573.3828, Disc Loss: 0.3976
# FactorVAE - Epoch [10/10], Step [2400/4608], VAE Loss: 8378.7754, Disc Loss: 0.3965
# FactorVAE - Epoch [10/10], Step [2500/4608], VAE Loss: 8592.7920, Disc Loss: 0.3383
# FactorVAE - Epoch [10/10], Step [2600/4608], VAE Loss: 8195.2783, Disc Loss: 0.3734
# FactorVAE - Epoch [10/10], Step [2700/4608], VAE Loss: 8464.0908, Disc Loss: 0.3472
# FactorVAE - Epoch [10/10], Step [2800/4608], VAE Loss: 8779.1416, Disc Loss: 0.4362
# FactorVAE - Epoch [10/10], Step [2900/4608], VAE Loss: 8377.3740, Disc Loss: 0.3997
# FactorVAE - Epoch [10/10], Step [3000/4608], VAE Loss: 8625.5566, Disc Loss: 0.3291
# FactorVAE - Epoch [10/10], Step [3100/4608], VAE Loss: 8927.4121, Disc Loss: 0.3438
# FactorVAE - Epoch [10/10], Step [3200/4608], VAE Loss: 8956.0742, Disc Loss: 0.3542
# FactorVAE - Epoch [10/10], Step [3300/4608], VAE Loss: 8616.4160, Disc Loss: 0.3482
# FactorVAE - Epoch [10/10], Step [3400/4608], VAE Loss: 8656.9033, Disc Loss: 0.3522
# FactorVAE - Epoch [10/10], Step [3500/4608], VAE Loss: 8190.7686, Disc Loss: 0.3225
# FactorVAE - Epoch [10/10], Step [3600/4608], VAE Loss: 8490.6777, Disc Loss: 0.3282
# FactorVAE - Epoch [10/10], Step [3700/4608], VAE Loss: 8151.8188, Disc Loss: 0.3392
# FactorVAE - Epoch [10/10], Step [3800/4608], VAE Loss: 8974.4990, Disc Loss: 0.3343
# FactorVAE - Epoch [10/10], Step [3900/4608], VAE Loss: 8744.5449, Disc Loss: 0.3404
# FactorVAE - Epoch [10/10], Step [4000/4608], VAE Loss: 8079.3218, Disc Loss: 0.3333
# FactorVAE - Epoch [10/10], Step [4100/4608], VAE Loss: 8133.3696, Disc Loss: 0.3393
# FactorVAE - Epoch [10/10], Step [4200/4608], VAE Loss: 8224.5908, Disc Loss: 0.2848
# FactorVAE - Epoch [10/10], Step [4300/4608], VAE Loss: 8339.4775, Disc Loss: 0.3027
# FactorVAE - Epoch [10/10], Step [4400/4608], VAE Loss: 8111.3750, Disc Loss: 0.3917
# FactorVAE - Epoch [10/10], Step [4500/4608], VAE Loss: 8625.3916, Disc Loss: 0.3619
# FactorVAE - Epoch [10/10], Step [4600/4608], VAE Loss: 8273.2988, Disc Loss: 0.3337
# FactorVAE - Epoch [10/10] completed. Avg VAE Loss: 66.6911
# Training complete!

# %%
# factor_vae_model
model=factor_vae_model
# --- Run Metrics After Training ---
print("\n" + "="*50)
print("Starting Quantitative Metrics Evaluation")
print("="*50 + "\n")

# Define the number of samples for metrics calculation to speed it up.
# For dSprites, 10,000 to 20,000 samples is usually sufficient.
# Set to None to use all available samples in the test_dataset.
NUM_SAMPLES_FOR_METRICS = 20000

# Collect data for metrics (using test_loader, but now limited by NUM_SAMPLES_FOR_METRICS)
# It's good to keep batch_size for the data_loader relatively high (e.g., 256)
# to make efficient use of the GPU during the forward pass.
metrics_data_loader = torch.utils.data.DataLoader(dataset=test_dataset, batch_size=256, shuffle=False)


######################################


mu1_for_metrics, latents_values_for_metrics, factor_names, active_factors_idx = \
    collect_latent_factors_for_metrics2(model, metrics_data_loader, device,
                                       num_samples_to_collect=NUM_SAMPLES_FOR_METRICS)

# Calculate and print MIG
mig_avg_score, mig_report = calculate_mig(mu1_for_metrics, latents_values_for_metrics, factor_names, active_factors_idx)

# Calculate and print Linear Regression Disentanglement Score
linear_disentanglement_avg_score, linear_r2_report, linear_disentanglement_summary = \
    calculate_linear_disentanglement_score(mu1_for_metrics, latents_values_for_metrics, factor_names, active_factors_idx)

# Calculate and print DCI
dci_informativeness, dci_disentanglement, dci_completeness, dci_report = \
    calculate_dci(mu1_for_metrics, latents_values_for_metrics, factor_names, active_factors_idx)

print("\n" + "="*50)
print("Quantitative Metrics Evaluation Complete")
print("="*50 + "\n")


#######################
model_name = "factor_vae_model"
model_results = {
    "Model": model_name,
    "MIG Score": mig_avg_score,
    "DCI Informativeness": dci_informativeness,
    "DCI Disentanglement": dci_disentanglement,
    "DCI Completeness": dci_completeness,
    "Average R2 Disentanglement": linear_disentanglement_avg_score,
}
all_model_results.append(model_results)
print(f"Finished evaluating {model_name}.")
# Out:
# ==================================================
# Starting Quantitative Metrics Evaluation
# ==================================================
#
# Collecting latent representations and ground truth factors for metrics (up to 20000 samples)...
# Collecting data for metrics: 0it [00:00, ?it/s]
# Collected 20000 samples for metrics.
#
# Calculating MIG (Mutual Information Gap) Score...
# Discretizing latent dimensions into 20 bins for MI calculation...
# Discretizing Latents:   0%|          | 0/64 [00:00<?, ?it/s]
# Discretizing ground truth factors into 20 bins for MI calculation...
# Discretizing Factors:   0%|          | 0/5 [00:00<?, ?it/s]
# Calculating MI matrix (this can take a while)...
#
# MIG Score:
# --------------------------------------------------
#   Average MIG Score: 0.2856
# --------------------------------------------------
# Mutual Information Heatmap saved to mig_mi_heatmap.png
#
# Calculating Linear Regression Disentanglement Score (R-squared)...
# Fitting linear regressors:   0%|          | 0/64 [00:00<?, ?it/s]
# Linear Regression R-squared Scores:
# --------------------------------------------------
# Latent Dim   | shape      scale      orientation posX       posY
# ----------------------------------------------------------------------
# Latent 0     | 0.0151     0.0938     0.0000     0.1365     0.1407
# Latent 1     | 0.0361     0.1282     0.0000     0.0011     0.0027
# Latent 2     | 0.0122     0.0795     0.0006     0.0277     0.3339
# Latent 3     | 0.0026     0.0061     0.0013     0.0036     0.0049
# Latent 4     | 0.0026     0.0096     0.0039     0.0239     0.0047
# Latent 5     | 0.0066     0.0353     0.0027     0.2859     0.0349
# Latent 6     | 0.0011     0.0029     0.0009     0.1279     0.0073
# Latent 7     | 0.0044     0.0235     0.0012     0.1442     0.1909
# Latent 8     | 0.0257     0.1063     0.0010     0.0349     0.0993
# Latent 9     | 0.0382     0.1803     0.0009     0.0589     0.0190
# Latent 10    | 0.0007     0.0011     0.0003     0.2273     0.0220
# Latent 11    | 0.0138     0.0705     0.0000     0.3036     0.0582
# Latent 12    | 0.0407     0.1642     0.0003     0.0693     0.0566
# Latent 13    | 0.0017     0.0040     0.0003     0.2455     0.0036
# Latent 14    | 0.0533     0.2554     0.0000     0.0582     0.1179
# Latent 15    | 0.0123     0.0659     0.0018     0.0054     0.0005
# Latent 16    | 0.0030     0.0278     0.0014     0.0239     0.0317
# Latent 17    | 0.0097     0.0445     0.0003     0.3081     0.0038
# Latent 18    | 0.0128     0.0807     0.0010     0.1793     0.0756
# Latent 19    | 0.0075     0.0275     0.0014     0.0588     0.1576
# Latent 20    | 0.0069     0.0327     0.0000     0.1814     0.0507
# Latent 21    | 0.0016     0.0185     0.0000     0.0389     0.0228
# Latent 22    | 0.0101     0.0311     0.0008     0.0005     0.0748
# Latent 23    | 0.0009     0.0089     0.0014     0.0046     0.1732
# Latent 24    | 0.0369     0.1876     0.0002     0.0924     0.0046
# Latent 25    | 0.0152     0.0799     0.0002     0.3072     0.0007
# Latent 26    | 0.0060     0.0296     0.0000     0.0840     0.1007
# Latent 27    | 0.0002     0.0000     0.0003     0.0589     0.0438
# Latent 28    | 0.0040     0.0177     0.0002     0.0059     0.0504
# Latent 29    | 0.0376     0.1842     0.0005     0.1503     0.0805
# Latent 30    | 0.0001     0.0036     0.0004     0.1739     0.1041
# Latent 31    | 0.0053     0.0210     0.0001     0.3968     0.2806
# Latent 32    | 0.0001     0.0001     0.0011     0.1167     0.1659
# Latent 33    | 0.0215     0.1187     0.0000     0.1590     0.0023
# Latent 34    | 0.0218     0.0740     0.0003     0.0341     0.0224
# Latent 35    | 0.0071     0.0384     0.0007     0.0029     0.0069
# Latent 36    | 0.0090     0.0264     0.0002     0.0481     0.2007
# Latent 37    | 0.0158     0.0943     0.0002     0.0129     0.0149
# Latent 38    | 0.0553     0.2339     0.0004     0.0026     0.0036
# Latent 39    | 0.0020     0.0110     0.0001     0.1727     0.1317
# Latent 40    | 0.0002     0.0001     0.0009     0.0291     0.1758
# Latent 41    | 0.0029     0.0126     0.0014     0.0232     0.0097
# Latent 42    | 0.0093     0.0202     0.0002     0.0222     0.0680
# Latent 43    | 0.0000     0.0009     0.0020     0.0828     0.0032
# Latent 44    | 0.0001     0.0012     0.0025     0.0518     0.0749
# Latent 45    | 0.0215     0.1123     0.0023     0.0007     0.0002
# Latent 46    | 0.0872     0.3708     0.0001     0.0696     0.1044
# Latent 47    | 0.0306     0.1247     0.0001     0.0166     0.0590
# Latent 48    | 0.0006     0.0002     0.0010     0.0335     0.0288
# Latent 49    | 0.0187     0.1052     0.0003     0.0486     0.3203
# Latent 50    | 0.0045     0.0162     0.0001     0.0323     0.0171
# Latent 51    | 0.0238     0.0763     0.0002     0.2912     0.0078
# Latent 52    | 0.0135     0.0561     0.0001     0.0009     0.1964
# Latent 53    | 0.0009     0.0022     0.0003     0.0078     0.0543
# Latent 54    | 0.0000     0.0000     0.0031     0.0023     0.0103
# Latent 55    | 0.0245     0.1083     0.0023     0.0445     0.0655
# Latent 56    | 0.0027     0.0098     0.0000     0.0457     0.1718
# Latent 57    | 0.0005     0.0008     0.0006     0.0034     0.1924
# Latent 58    | 0.0539     0.2276     0.0010     0.0928     0.0017
# Latent 59    | 0.0635     0.3130     0.0000     0.0014     0.0031
# Latent 60    | 0.0750     0.3390     0.0001     0.0256     0.0121
# Latent 61    | 0.0005     0.0020     0.0009     0.4340     0.0509
# Latent 62    | 0.0040     0.0156     0.0003     0.0019     0.0483
# Latent 63    | 0.0009     0.0031     0.0001     0.2861     0.0187
#
# Disentanglement Summary (Per Ground Truth Factor):
# --------------------------------------------------
#   shape: Best explained by Latent 46 (R2: 0.0872)
#   scale: Best explained by Latent 46 (R2: 0.3708)
#   orientation: Best explained by Latent 4 (R2: 0.0039)
#   posX: Best explained by Latent 61 (R2: 0.4340)
#   posY: Best explained by Latent 2 (R2: 0.3339)
# --------------------------------------------------
# Average Disentanglement Score (Max R2 per factor): 0.2460
# Saved R2 matrix to ./metrics_hdvae/linear_r2_matrix.npy
# Saved R2 heatmap to ./metrics_hdvae/linear_r2_heatmap.png
#
# Calculating DCI (Disentanglement, Completeness, Informativeness) Score...
# Discretizing ground truth factors into 10 bins for DCI...
# Training RandomForestClassifiers for each ground truth factor...
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_discretization.py:306: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 0 are removed. Consider decreasing the number of bins.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_discretization.py:306: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 0 are removed. Consider decreasing the number of bins.
#   warnings.warn(
# DCI per factor:   0%|          | 0/5 [00:00<?, ?it/s]
# DCI Scores:
# --------------------------------------------------
#   Informativeness: 0.7440
#   Disentanglement: 0.0377
#   Completeness:    0.0543
# --------------------------------------------------
#
# ==================================================
# Quantitative Metrics Evaluation Complete
# ==================================================
#
# Finished evaluating factor_vae_model.

# %%
model_name = "factor_vae_model"
model_results = {
    "Model": model_name,
    "MIG Score": 0.2856,
    "DCI Informativeness": 0.7440,
    "DCI Disentanglement": 0.0377,
    "DCI Completeness": 0.0543,
    "Average R2 Disentanglement": 0.2460,
}
all_model_results.append(model_results)
print(f"Finished evaluating {model_name}.")
# Out:
# Finished evaluating factor_vae_model.

# %%
# V4: DIP-VAE-I (Disentangled Inferred Prior VAE, Type I) for comparison

# --- DIP-VAE-I Model ---
# This model is structurally identical to the Vanilla VAE,
# but its loss function includes a regularization term on the covariance of the latent space.

class DIPVAE(nn.Module):
    def __init__(self, image_size, z_dim):
        super(DIPVAE, self).__init__()
        self.image_size = image_size
        self.z_dim = z_dim

        # Encoder (identical to previous VAEs)
        self.encoder = nn.Sequential(
            nn.Linear(image_size, 512),
            nn.ReLU(),
            nn.Linear(512, 256),
            nn.ReLU(),
            nn.Linear(256, 128)
        )
        self.fc_mu = nn.Linear(128, z_dim)
        self.fc_logvar = nn.Linear(128, z_dim)

        # Decoder (identical to previous VAEs)
        self.decoder = nn.Sequential(
            nn.Linear(z_dim, 256),
            nn.ReLU(),
            nn.Linear(256, 512),
            nn.ReLU(),
            nn.Linear(512, image_size),
            nn.Sigmoid()
        )

    def reparameterize(self, mu, log_var):
        std = torch.exp(0.5 * log_var)
        eps = torch.randn_like(std)
        return mu + eps * std

    def forward(self, x):
        # Encode
        h = self.encoder(x.view(-1, self.image_size))
        mu = self.fc_mu(h)
        log_var = self.fc_logvar(h)
        z = self.reparameterize(mu, log_var)

        # Decode
        recon_x = self.decoder(z)
        return recon_x, mu, log_var, z # Return z for DIP-VAE regularization




# --- DIP-VAE-I Loss Function (adapted to calculate covariance within the loop) ---
# The total loss will be calculated in the training loop.

# Function to calculate empirical covariance for a batch of latent vectors
def batch_covariance(z):
    batch_size = z.size(0)
    z_centered = z - z.mean(dim=0, keepdim=True)
    covariance = torch.matmul(z_centered.transpose(0, 1), z_centered) / (batch_size - 1)
    return covariance

# --- Setup for DIP-VAE-I Training ---
dip_vae_z_dim = z1_dim # Still 64 for consistency
# Hyperparameter lambda for DIP-VAE regularization
dip_vae_lambda = 100.0 # Common values range from 1 to 200 for MNIST
# Hyperparameter beta for standard KLD (we'll keep it 1.0 for simplicity, like vanilla)
dip_vae_beta = 1.0

dip_vae_model = DIPVAE(image_size, dip_vae_z_dim).to(device)
dip_vae_optimizer = torch.optim.Adam(dip_vae_model.parameters(), lr=learning_rate)

print("\n--- DIP-VAE-I Model ---")
print(dip_vae_model)

# --- Training Loop for DIP-VAE-I ---
print(f"\nStarting DIP-VAE-I training with lambda = {dip_vae_lambda}...")
for epoch in range(num_epochs):
    dip_vae_model.train()
    total_loss = 0

    for i, (images, _,_) in enumerate(train_loader):
        images = images.to(device)
        batch_size = images.size(0)

        recon_images, mu, log_var, z = dip_vae_model(images) # Get z for regularization

        # 1. Reconstruction Loss
        bce_loss = F.binary_cross_entropy(recon_images, images.view(-1, image_size), reduction='sum')

        # 2. KL Divergence
        kld_loss = -0.5 * torch.sum(1 + log_var - mu.pow(2) - log_var.exp())

        # 3. DIP-VAE-I Regularization Term
        # Calculate empirical covariance of z for the current batch
        z_cov = batch_covariance(z)

        # Create an identity matrix of size z_dim x z_dim
        identity_matrix = torch.eye(dip_vae_z_dim).to(device)

        # Calculate Frobenius norm squared of (Cov(z) - I)
        dip_loss = torch.norm(z_cov - identity_matrix, p='fro')**2

        # Total Loss
        loss = bce_loss + dip_vae_beta * kld_loss + dip_vae_lambda * dip_loss

        dip_vae_optimizer.zero_grad()
        loss.backward()
        dip_vae_optimizer.step()

        total_loss += loss.item()

        if (i+1) % 100 == 0:
            print(f"DIP-VAE-I - Epoch [{epoch+1}/{num_epochs}], Step [{i+1}/{len(train_loader)}], Loss: {loss.item():.4f}")

    avg_loss = total_loss / len(train_loader.dataset)
    print(f"DIP-VAE-I - Epoch [{epoch+1}/{num_epochs}] completed. Avg Loss: {avg_loss:.4f}")

print("Training complete!")
# Out:
# --- DIP-VAE-I Model ---
# DIPVAE(
#   (encoder): Sequential(
#     (0): Linear(in_features=4096, out_features=512, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=512, out_features=256, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=256, out_features=128, bias=True)
#   )
#   (fc_mu): Linear(in_features=128, out_features=64, bias=True)
#   (fc_logvar): Linear(in_features=128, out_features=64, bias=True)
#   (decoder): Sequential(
#     (0): Linear(in_features=64, out_features=256, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=256, out_features=512, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=512, out_features=4096, bias=True)
#     (5): Sigmoid()
#   )
# )
#
# Starting DIP-VAE-I training with lambda = 100.0...
# DIP-VAE-I - Epoch [1/10], Step [100/4608], Loss: 71389.0625
# DIP-VAE-I - Epoch [1/10], Step [200/4608], Loss: 34049.7578
# DIP-VAE-I - Epoch [1/10], Step [300/4608], Loss: 26996.0820
# DIP-VAE-I - Epoch [1/10], Step [400/4608], Loss: 25414.8281
# DIP-VAE-I - Epoch [1/10], Step [500/4608], Loss: 21602.6758
# DIP-VAE-I - Epoch [1/10], Step [600/4608], Loss: 21899.5059
# DIP-VAE-I - Epoch [1/10], Step [700/4608], Loss: 20930.4336
# DIP-VAE-I - Epoch [1/10], Step [800/4608], Loss: 20331.1602
# DIP-VAE-I - Epoch [1/10], Step [900/4608], Loss: 19942.1133
# DIP-VAE-I - Epoch [1/10], Step [1000/4608], Loss: 19180.1055
# DIP-VAE-I - Epoch [1/10], Step [1100/4608], Loss: 18971.7070
# DIP-VAE-I - Epoch [1/10], Step [1200/4608], Loss: 17983.4727
# DIP-VAE-I - Epoch [1/10], Step [1300/4608], Loss: 18653.5840
# DIP-VAE-I - Epoch [1/10], Step [1400/4608], Loss: 17417.7168
# DIP-VAE-I - Epoch [1/10], Step [1500/4608], Loss: 18203.3789
# DIP-VAE-I - Epoch [1/10], Step [1600/4608], Loss: 16733.4961
# DIP-VAE-I - Epoch [1/10], Step [1700/4608], Loss: 17284.2012
# DIP-VAE-I - Epoch [1/10], Step [1800/4608], Loss: 17319.3555
# DIP-VAE-I - Epoch [1/10], Step [1900/4608], Loss: 16604.0898
# DIP-VAE-I - Epoch [1/10], Step [2000/4608], Loss: 15617.5254
# DIP-VAE-I - Epoch [1/10], Step [2100/4608], Loss: 16044.2344
# DIP-VAE-I - Epoch [1/10], Step [2200/4608], Loss: 15399.2373
# DIP-VAE-I - Epoch [1/10], Step [2300/4608], Loss: 16622.6543
# DIP-VAE-I - Epoch [1/10], Step [2400/4608], Loss: 15376.6348
# DIP-VAE-I - Epoch [1/10], Step [2500/4608], Loss: 15927.5215
# DIP-VAE-I - Epoch [1/10], Step [2600/4608], Loss: 15159.2705
# DIP-VAE-I - Epoch [1/10], Step [2700/4608], Loss: 15271.6875
# DIP-VAE-I - Epoch [1/10], Step [2800/4608], Loss: 15147.3838
# DIP-VAE-I - Epoch [1/10], Step [2900/4608], Loss: 15242.7305
# DIP-VAE-I - Epoch [1/10], Step [3000/4608], Loss: 14979.0967
# DIP-VAE-I - Epoch [1/10], Step [3100/4608], Loss: 15864.7939
# DIP-VAE-I - Epoch [1/10], Step [3200/4608], Loss: 14885.2910
# DIP-VAE-I - Epoch [1/10], Step [3300/4608], Loss: 15080.5098
# DIP-VAE-I - Epoch [1/10], Step [3400/4608], Loss: 14528.3281
# DIP-VAE-I - Epoch [1/10], Step [3500/4608], Loss: 14006.2246
# DIP-VAE-I - Epoch [1/10], Step [3600/4608], Loss: 15189.9980
# DIP-VAE-I - Epoch [1/10], Step [3700/4608], Loss: 14337.4756
# DIP-VAE-I - Epoch [1/10], Step [3800/4608], Loss: 14737.0527
# DIP-VAE-I - Epoch [1/10], Step [3900/4608], Loss: 13862.8623
# DIP-VAE-I - Epoch [1/10], Step [4000/4608], Loss: 14430.3789
# DIP-VAE-I - Epoch [1/10], Step [4100/4608], Loss: 13809.9531
# DIP-VAE-I - Epoch [1/10], Step [4200/4608], Loss: 13791.1719
# DIP-VAE-I - Epoch [1/10], Step [4300/4608], Loss: 14399.5859
# DIP-VAE-I - Epoch [1/10], Step [4400/4608], Loss: 13966.0391
# DIP-VAE-I - Epoch [1/10], Step [4500/4608], Loss: 14130.5234
# DIP-VAE-I - Epoch [1/10], Step [4600/4608], Loss: 13766.8691
# DIP-VAE-I - Epoch [1/10] completed. Avg Loss: 150.2170
# DIP-VAE-I - Epoch [2/10], Step [100/4608], Loss: 13913.0566
# DIP-VAE-I - Epoch [2/10], Step [200/4608], Loss: 14104.2373
# DIP-VAE-I - Epoch [2/10], Step [300/4608], Loss: 14200.9785
# DIP-VAE-I - Epoch [2/10], Step [400/4608], Loss: 13236.2568
# DIP-VAE-I - Epoch [2/10], Step [500/4608], Loss: 13986.0156
# DIP-VAE-I - Epoch [2/10], Step [600/4608], Loss: 14404.3135
# DIP-VAE-I - Epoch [2/10], Step [700/4608], Loss: 13918.0781
# DIP-VAE-I - Epoch [2/10], Step [800/4608], Loss: 14010.3867
# DIP-VAE-I - Epoch [2/10], Step [900/4608], Loss: 13761.7061
# DIP-VAE-I - Epoch [2/10], Step [1000/4608], Loss: 13462.3213
# DIP-VAE-I - Epoch [2/10], Step [1100/4608], Loss: 14088.9443
# DIP-VAE-I - Epoch [2/10], Step [1200/4608], Loss: 13389.8965
# DIP-VAE-I - Epoch [2/10], Step [1300/4608], Loss: 14561.3545
# DIP-VAE-I - Epoch [2/10], Step [1400/4608], Loss: 13141.3867
# DIP-VAE-I - Epoch [2/10], Step [1500/4608], Loss: 13585.3672
# DIP-VAE-I - Epoch [2/10], Step [1600/4608], Loss: 13251.6445
# DIP-VAE-I - Epoch [2/10], Step [1700/4608], Loss: 13958.8281
# DIP-VAE-I - Epoch [2/10], Step [1800/4608], Loss: 13634.7793
# DIP-VAE-I - Epoch [2/10], Step [1900/4608], Loss: 13226.4756
# DIP-VAE-I - Epoch [2/10], Step [2000/4608], Loss: 13429.0703
# DIP-VAE-I - Epoch [2/10], Step [2100/4608], Loss: 14087.2646
# DIP-VAE-I - Epoch [2/10], Step [2200/4608], Loss: 13640.3535
# DIP-VAE-I - Epoch [2/10], Step [2300/4608], Loss: 13403.8242
# DIP-VAE-I - Epoch [2/10], Step [2400/4608], Loss: 12920.7139
# DIP-VAE-I - Epoch [2/10], Step [2500/4608], Loss: 13615.9951
# DIP-VAE-I - Epoch [2/10], Step [2600/4608], Loss: 14430.9814
# DIP-VAE-I - Epoch [2/10], Step [2700/4608], Loss: 13306.3301
# DIP-VAE-I - Epoch [2/10], Step [2800/4608], Loss: 13299.7402
# DIP-VAE-I - Epoch [2/10], Step [2900/4608], Loss: 13128.7734
# DIP-VAE-I - Epoch [2/10], Step [3000/4608], Loss: 14510.1641
# DIP-VAE-I - Epoch [2/10], Step [3100/4608], Loss: 13996.5908
# DIP-VAE-I - Epoch [2/10], Step [3200/4608], Loss: 12999.5713
# DIP-VAE-I - Epoch [2/10], Step [3300/4608], Loss: 13572.9453
# DIP-VAE-I - Epoch [2/10], Step [3400/4608], Loss: 14061.4619
# DIP-VAE-I - Epoch [2/10], Step [3500/4608], Loss: 13388.8984
# DIP-VAE-I - Epoch [2/10], Step [3600/4608], Loss: 13357.0234
# DIP-VAE-I - Epoch [2/10], Step [3700/4608], Loss: 13234.5576
# DIP-VAE-I - Epoch [2/10], Step [3800/4608], Loss: 13204.6260
# DIP-VAE-I - Epoch [2/10], Step [3900/4608], Loss: 13826.8340
# DIP-VAE-I - Epoch [2/10], Step [4000/4608], Loss: 12592.5684
# DIP-VAE-I - Epoch [2/10], Step [4100/4608], Loss: 13993.4453
# DIP-VAE-I - Epoch [2/10], Step [4200/4608], Loss: 13801.9707
# DIP-VAE-I - Epoch [2/10], Step [4300/4608], Loss: 13157.5244
# DIP-VAE-I - Epoch [2/10], Step [4400/4608], Loss: 12724.9785
# DIP-VAE-I - Epoch [2/10], Step [4500/4608], Loss: 13098.1562
# DIP-VAE-I - Epoch [2/10], Step [4600/4608], Loss: 13072.2109
# DIP-VAE-I - Epoch [2/10] completed. Avg Loss: 106.2934
# DIP-VAE-I - Epoch [3/10], Step [100/4608], Loss: 13298.5293
# DIP-VAE-I - Epoch [3/10], Step [200/4608], Loss: 12955.5312
# DIP-VAE-I - Epoch [3/10], Step [300/4608], Loss: 13075.9414
# DIP-VAE-I - Epoch [3/10], Step [400/4608], Loss: 13549.5898
# DIP-VAE-I - Epoch [3/10], Step [500/4608], Loss: 12992.4766
# DIP-VAE-I - Epoch [3/10], Step [600/4608], Loss: 12910.5117
# DIP-VAE-I - Epoch [3/10], Step [700/4608], Loss: 12874.9141
# DIP-VAE-I - Epoch [3/10], Step [800/4608], Loss: 13274.3545
# DIP-VAE-I - Epoch [3/10], Step [900/4608], Loss: 12538.1230
# DIP-VAE-I - Epoch [3/10], Step [1000/4608], Loss: 13302.3555
# DIP-VAE-I - Epoch [3/10], Step [1100/4608], Loss: 13744.9785
# DIP-VAE-I - Epoch [3/10], Step [1200/4608], Loss: 12655.9287
# DIP-VAE-I - Epoch [3/10], Step [1300/4608], Loss: 13240.0020
# DIP-VAE-I - Epoch [3/10], Step [1400/4608], Loss: 12546.1797
# DIP-VAE-I - Epoch [3/10], Step [1500/4608], Loss: 13518.9609
# DIP-VAE-I - Epoch [3/10], Step [1600/4608], Loss: 13244.3359
# DIP-VAE-I - Epoch [3/10], Step [1700/4608], Loss: 13335.8242
# DIP-VAE-I - Epoch [3/10], Step [1800/4608], Loss: 12873.8535
# DIP-VAE-I - Epoch [3/10], Step [1900/4608], Loss: 12535.7988
# DIP-VAE-I - Epoch [3/10], Step [2000/4608], Loss: 12778.8145
# DIP-VAE-I - Epoch [3/10], Step [2100/4608], Loss: 13030.1758
# DIP-VAE-I - Epoch [3/10], Step [2200/4608], Loss: 13003.6172
# DIP-VAE-I - Epoch [3/10], Step [2300/4608], Loss: 13109.2646
# DIP-VAE-I - Epoch [3/10], Step [2400/4608], Loss: 13635.8613
# DIP-VAE-I - Epoch [3/10], Step [2500/4608], Loss: 13347.4043
# DIP-VAE-I - Epoch [3/10], Step [2600/4608], Loss: 13604.1416
# DIP-VAE-I - Epoch [3/10], Step [2700/4608], Loss: 12281.7080
# DIP-VAE-I - Epoch [3/10], Step [2800/4608], Loss: 12430.4160
# DIP-VAE-I - Epoch [3/10], Step [2900/4608], Loss: 12824.7578
# DIP-VAE-I - Epoch [3/10], Step [3000/4608], Loss: 13269.1230
# DIP-VAE-I - Epoch [3/10], Step [3100/4608], Loss: 12588.5205
# DIP-VAE-I - Epoch [3/10], Step [3200/4608], Loss: 12511.1699
# DIP-VAE-I - Epoch [3/10], Step [3300/4608], Loss: 13313.3154
# DIP-VAE-I - Epoch [3/10], Step [3400/4608], Loss: 12224.8457
# DIP-VAE-I - Epoch [3/10], Step [3500/4608], Loss: 12267.2285
# DIP-VAE-I - Epoch [3/10], Step [3600/4608], Loss: 12646.4443
# DIP-VAE-I - Epoch [3/10], Step [3700/4608], Loss: 12570.4199
# DIP-VAE-I - Epoch [3/10], Step [3800/4608], Loss: 13164.4893
# DIP-VAE-I - Epoch [3/10], Step [3900/4608], Loss: 12863.4258
# DIP-VAE-I - Epoch [3/10], Step [4000/4608], Loss: 12863.3262
# DIP-VAE-I - Epoch [3/10], Step [4100/4608], Loss: 11819.0947
# DIP-VAE-I - Epoch [3/10], Step [4200/4608], Loss: 12489.7080
# DIP-VAE-I - Epoch [3/10], Step [4300/4608], Loss: 12933.9131
# DIP-VAE-I - Epoch [3/10], Step [4400/4608], Loss: 12785.3193
# DIP-VAE-I - Epoch [3/10], Step [4500/4608], Loss: 13041.4688
# DIP-VAE-I - Epoch [3/10], Step [4600/4608], Loss: 13118.8623
# DIP-VAE-I - Epoch [3/10] completed. Avg Loss: 101.3012
# DIP-VAE-I - Epoch [4/10], Step [100/4608], Loss: 13301.0488
# DIP-VAE-I - Epoch [4/10], Step [200/4608], Loss: 12567.3789
# DIP-VAE-I - Epoch [4/10], Step [300/4608], Loss: 12417.0430
# DIP-VAE-I - Epoch [4/10], Step [400/4608], Loss: 12460.2188
# DIP-VAE-I - Epoch [4/10], Step [500/4608], Loss: 12023.8770
# DIP-VAE-I - Epoch [4/10], Step [600/4608], Loss: 12021.4893
# DIP-VAE-I - Epoch [4/10], Step [700/4608], Loss: 12732.3535
# DIP-VAE-I - Epoch [4/10], Step [800/4608], Loss: 12442.5020
# DIP-VAE-I - Epoch [4/10], Step [900/4608], Loss: 12083.7793
# DIP-VAE-I - Epoch [4/10], Step [1000/4608], Loss: 12402.3945
# DIP-VAE-I - Epoch [4/10], Step [1100/4608], Loss: 11800.6865
# DIP-VAE-I - Epoch [4/10], Step [1200/4608], Loss: 12274.5879
# DIP-VAE-I - Epoch [4/10], Step [1300/4608], Loss: 12882.8301
# DIP-VAE-I - Epoch [4/10], Step [1400/4608], Loss: 13102.5566
# DIP-VAE-I - Epoch [4/10], Step [1500/4608], Loss: 12402.2012
# DIP-VAE-I - Epoch [4/10], Step [1600/4608], Loss: 12557.9121
# DIP-VAE-I - Epoch [4/10], Step [1700/4608], Loss: 13119.2500
# DIP-VAE-I - Epoch [4/10], Step [1800/4608], Loss: 12291.1758
# DIP-VAE-I - Epoch [4/10], Step [1900/4608], Loss: 12833.1719
# DIP-VAE-I - Epoch [4/10], Step [2000/4608], Loss: 12229.6133
# DIP-VAE-I - Epoch [4/10], Step [2100/4608], Loss: 12017.1309
# DIP-VAE-I - Epoch [4/10], Step [2200/4608], Loss: 12393.1699
# DIP-VAE-I - Epoch [4/10], Step [2300/4608], Loss: 12515.1982
# DIP-VAE-I - Epoch [4/10], Step [2400/4608], Loss: 11780.5146
# DIP-VAE-I - Epoch [4/10], Step [2500/4608], Loss: 12415.1748
# DIP-VAE-I - Epoch [4/10], Step [2600/4608], Loss: 12361.3213
# DIP-VAE-I - Epoch [4/10], Step [2700/4608], Loss: 12220.3906
# DIP-VAE-I - Epoch [4/10], Step [2800/4608], Loss: 12400.0840
# DIP-VAE-I - Epoch [4/10], Step [2900/4608], Loss: 12055.0518
# DIP-VAE-I - Epoch [4/10], Step [3000/4608], Loss: 11520.6172
# DIP-VAE-I - Epoch [4/10], Step [3100/4608], Loss: 12267.5674
# DIP-VAE-I - Epoch [4/10], Step [3200/4608], Loss: 12084.7188
# DIP-VAE-I - Epoch [4/10], Step [3300/4608], Loss: 12190.6875
# DIP-VAE-I - Epoch [4/10], Step [3400/4608], Loss: 11970.0859
# DIP-VAE-I - Epoch [4/10], Step [3500/4608], Loss: 12521.4023
# DIP-VAE-I - Epoch [4/10], Step [3600/4608], Loss: 12194.8555
# DIP-VAE-I - Epoch [4/10], Step [3700/4608], Loss: 12171.0859
# DIP-VAE-I - Epoch [4/10], Step [3800/4608], Loss: 11978.2998
# DIP-VAE-I - Epoch [4/10], Step [3900/4608], Loss: 12050.1543
# DIP-VAE-I - Epoch [4/10], Step [4000/4608], Loss: 11757.4785
# DIP-VAE-I - Epoch [4/10], Step [4100/4608], Loss: 11990.3408
# DIP-VAE-I - Epoch [4/10], Step [4200/4608], Loss: 12306.8398
# DIP-VAE-I - Epoch [4/10], Step [4300/4608], Loss: 12019.0830
# DIP-VAE-I - Epoch [4/10], Step [4400/4608], Loss: 11863.6562
# DIP-VAE-I - Epoch [4/10], Step [4500/4608], Loss: 12269.6299
# DIP-VAE-I - Epoch [4/10], Step [4600/4608], Loss: 11653.9863
# DIP-VAE-I - Epoch [4/10] completed. Avg Loss: 96.0802
# DIP-VAE-I - Epoch [5/10], Step [100/4608], Loss: 11139.0322
# DIP-VAE-I - Epoch [5/10], Step [200/4608], Loss: 12259.6641
# DIP-VAE-I - Epoch [5/10], Step [300/4608], Loss: 12096.9922
# DIP-VAE-I - Epoch [5/10], Step [400/4608], Loss: 12110.9932
# DIP-VAE-I - Epoch [5/10], Step [500/4608], Loss: 11728.8135
# DIP-VAE-I - Epoch [5/10], Step [600/4608], Loss: 11999.2578
# DIP-VAE-I - Epoch [5/10], Step [700/4608], Loss: 11774.6465
# DIP-VAE-I - Epoch [5/10], Step [800/4608], Loss: 12095.2676
# DIP-VAE-I - Epoch [5/10], Step [900/4608], Loss: 12532.6875
# DIP-VAE-I - Epoch [5/10], Step [1000/4608], Loss: 11664.5410
# DIP-VAE-I - Epoch [5/10], Step [1100/4608], Loss: 12274.2598
# DIP-VAE-I - Epoch [5/10], Step [1200/4608], Loss: 11789.6348
# DIP-VAE-I - Epoch [5/10], Step [1300/4608], Loss: 11887.5010
# DIP-VAE-I - Epoch [5/10], Step [1400/4608], Loss: 11230.9941
# DIP-VAE-I - Epoch [5/10], Step [1500/4608], Loss: 11593.7061
# DIP-VAE-I - Epoch [5/10], Step [1600/4608], Loss: 11273.0723
# DIP-VAE-I - Epoch [5/10], Step [1700/4608], Loss: 11595.1240
# DIP-VAE-I - Epoch [5/10], Step [1800/4608], Loss: 12065.8281
# DIP-VAE-I - Epoch [5/10], Step [1900/4608], Loss: 11970.6035
# DIP-VAE-I - Epoch [5/10], Step [2000/4608], Loss: 11790.0195
# DIP-VAE-I - Epoch [5/10], Step [2100/4608], Loss: 12103.6055
# DIP-VAE-I - Epoch [5/10], Step [2200/4608], Loss: 11524.1543
# DIP-VAE-I - Epoch [5/10], Step [2300/4608], Loss: 11927.0361
# DIP-VAE-I - Epoch [5/10], Step [2400/4608], Loss: 11958.0225
# DIP-VAE-I - Epoch [5/10], Step [2500/4608], Loss: 11561.6416
# DIP-VAE-I - Epoch [5/10], Step [2600/4608], Loss: 11275.0703
# DIP-VAE-I - Epoch [5/10], Step [2700/4608], Loss: 11229.7617
# DIP-VAE-I - Epoch [5/10], Step [2800/4608], Loss: 11903.4268
# DIP-VAE-I - Epoch [5/10], Step [2900/4608], Loss: 11983.4521
# DIP-VAE-I - Epoch [5/10], Step [3000/4608], Loss: 11548.9844
# DIP-VAE-I - Epoch [5/10], Step [3100/4608], Loss: 11647.6738
# DIP-VAE-I - Epoch [5/10], Step [3200/4608], Loss: 11315.8174
# DIP-VAE-I - Epoch [5/10], Step [3300/4608], Loss: 11463.0605
# DIP-VAE-I - Epoch [5/10], Step [3400/4608], Loss: 11713.6289
# DIP-VAE-I - Epoch [5/10], Step [3500/4608], Loss: 11723.7920
# DIP-VAE-I - Epoch [5/10], Step [3600/4608], Loss: 11366.9258
# DIP-VAE-I - Epoch [5/10], Step [3700/4608], Loss: 11521.4941
# DIP-VAE-I - Epoch [5/10], Step [3800/4608], Loss: 11490.9932
# DIP-VAE-I - Epoch [5/10], Step [3900/4608], Loss: 11751.9717
# DIP-VAE-I - Epoch [5/10], Step [4000/4608], Loss: 10996.5391
# DIP-VAE-I - Epoch [5/10], Step [4100/4608], Loss: 11849.2832
# DIP-VAE-I - Epoch [5/10], Step [4200/4608], Loss: 11525.7793
# DIP-VAE-I - Epoch [5/10], Step [4300/4608], Loss: 11529.5869
# DIP-VAE-I - Epoch [5/10], Step [4400/4608], Loss: 11911.7529
# DIP-VAE-I - Epoch [5/10], Step [4500/4608], Loss: 11587.6846
# DIP-VAE-I - Epoch [5/10], Step [4600/4608], Loss: 11634.5713
# DIP-VAE-I - Epoch [5/10] completed. Avg Loss: 91.4908
# DIP-VAE-I - Epoch [6/10], Step [100/4608], Loss: 11485.5859
# DIP-VAE-I - Epoch [6/10], Step [200/4608], Loss: 11617.4229
# DIP-VAE-I - Epoch [6/10], Step [300/4608], Loss: 11908.2041
# DIP-VAE-I - Epoch [6/10], Step [400/4608], Loss: 11759.7637
# DIP-VAE-I - Epoch [6/10], Step [500/4608], Loss: 11197.3750
# DIP-VAE-I - Epoch [6/10], Step [600/4608], Loss: 12008.5342
# DIP-VAE-I - Epoch [6/10], Step [700/4608], Loss: 11518.4336
# DIP-VAE-I - Epoch [6/10], Step [800/4608], Loss: 11538.9082
# DIP-VAE-I - Epoch [6/10], Step [900/4608], Loss: 11273.0117
# DIP-VAE-I - Epoch [6/10], Step [1000/4608], Loss: 11809.8984
# DIP-VAE-I - Epoch [6/10], Step [1100/4608], Loss: 11354.9346
# DIP-VAE-I - Epoch [6/10], Step [1200/4608], Loss: 11657.1035
# DIP-VAE-I - Epoch [6/10], Step [1300/4608], Loss: 11497.2598
# DIP-VAE-I - Epoch [6/10], Step [1400/4608], Loss: 11089.5703
# DIP-VAE-I - Epoch [6/10], Step [1500/4608], Loss: 11028.3047
# DIP-VAE-I - Epoch [6/10], Step [1600/4608], Loss: 11843.0439
# DIP-VAE-I - Epoch [6/10], Step [1700/4608], Loss: 10874.4111
# DIP-VAE-I - Epoch [6/10], Step [1800/4608], Loss: 11391.5938
# DIP-VAE-I - Epoch [6/10], Step [1900/4608], Loss: 11474.3535
# DIP-VAE-I - Epoch [6/10], Step [2000/4608], Loss: 11228.7588
# DIP-VAE-I - Epoch [6/10], Step [2100/4608], Loss: 10815.2881
# DIP-VAE-I - Epoch [6/10], Step [2200/4608], Loss: 10899.1201
# DIP-VAE-I - Epoch [6/10], Step [2300/4608], Loss: 11397.6699
# DIP-VAE-I - Epoch [6/10], Step [2400/4608], Loss: 11006.0723
# DIP-VAE-I - Epoch [6/10], Step [2500/4608], Loss: 11781.2744
# DIP-VAE-I - Epoch [6/10], Step [2600/4608], Loss: 10916.2881
# DIP-VAE-I - Epoch [6/10], Step [2700/4608], Loss: 11193.6982
# DIP-VAE-I - Epoch [6/10], Step [2800/4608], Loss: 10817.8594
# DIP-VAE-I - Epoch [6/10], Step [2900/4608], Loss: 11171.1250
# DIP-VAE-I - Epoch [6/10], Step [3000/4608], Loss: 11014.0791
# DIP-VAE-I - Epoch [6/10], Step [3100/4608], Loss: 11376.8008
# DIP-VAE-I - Epoch [6/10], Step [3200/4608], Loss: 10886.4648
# DIP-VAE-I - Epoch [6/10], Step [3300/4608], Loss: 11140.5205
# DIP-VAE-I - Epoch [6/10], Step [3400/4608], Loss: 11076.8447
# DIP-VAE-I - Epoch [6/10], Step [3500/4608], Loss: 11248.0908
# DIP-VAE-I - Epoch [6/10], Step [3600/4608], Loss: 11435.4209
# DIP-VAE-I - Epoch [6/10], Step [3700/4608], Loss: 11132.5117
# DIP-VAE-I - Epoch [6/10], Step [3800/4608], Loss: 10954.1318
# DIP-VAE-I - Epoch [6/10], Step [3900/4608], Loss: 11667.2441
# DIP-VAE-I - Epoch [6/10], Step [4000/4608], Loss: 10792.1514
# DIP-VAE-I - Epoch [6/10], Step [4100/4608], Loss: 11118.7705
# DIP-VAE-I - Epoch [6/10], Step [4200/4608], Loss: 11098.4209
# DIP-VAE-I - Epoch [6/10], Step [4300/4608], Loss: 10894.8525
# DIP-VAE-I - Epoch [6/10], Step [4400/4608], Loss: 11514.9316
# DIP-VAE-I - Epoch [6/10], Step [4500/4608], Loss: 11639.6992
# DIP-VAE-I - Epoch [6/10], Step [4600/4608], Loss: 11402.3896
# DIP-VAE-I - Epoch [6/10] completed. Avg Loss: 88.4986
# DIP-VAE-I - Epoch [7/10], Step [100/4608], Loss: 11435.8926
# DIP-VAE-I - Epoch [7/10], Step [200/4608], Loss: 11189.8330
# DIP-VAE-I - Epoch [7/10], Step [300/4608], Loss: 11075.9531
# DIP-VAE-I - Epoch [7/10], Step [400/4608], Loss: 11119.4355
# DIP-VAE-I - Epoch [7/10], Step [500/4608], Loss: 11216.6191
# DIP-VAE-I - Epoch [7/10], Step [600/4608], Loss: 10872.2402
# DIP-VAE-I - Epoch [7/10], Step [700/4608], Loss: 11182.0361
# DIP-VAE-I - Epoch [7/10], Step [800/4608], Loss: 11090.4365
# DIP-VAE-I - Epoch [7/10], Step [900/4608], Loss: 10998.6240
# DIP-VAE-I - Epoch [7/10], Step [1000/4608], Loss: 11010.9229
# DIP-VAE-I - Epoch [7/10], Step [1100/4608], Loss: 11345.5625
# DIP-VAE-I - Epoch [7/10], Step [1200/4608], Loss: 11085.3574
# DIP-VAE-I - Epoch [7/10], Step [1300/4608], Loss: 11210.8105
# DIP-VAE-I - Epoch [7/10], Step [1400/4608], Loss: 11249.8340
# DIP-VAE-I - Epoch [7/10], Step [1500/4608], Loss: 11205.1680
# DIP-VAE-I - Epoch [7/10], Step [1600/4608], Loss: 11616.1592
# DIP-VAE-I - Epoch [7/10], Step [1700/4608], Loss: 10909.9209
# DIP-VAE-I - Epoch [7/10], Step [1800/4608], Loss: 11468.8584
# DIP-VAE-I - Epoch [7/10], Step [1900/4608], Loss: 11146.4775
# DIP-VAE-I - Epoch [7/10], Step [2000/4608], Loss: 10961.2021
# DIP-VAE-I - Epoch [7/10], Step [2100/4608], Loss: 11258.6865
# DIP-VAE-I - Epoch [7/10], Step [2200/4608], Loss: 11190.7363
# DIP-VAE-I - Epoch [7/10], Step [2300/4608], Loss: 11012.1611
# DIP-VAE-I - Epoch [7/10], Step [2400/4608], Loss: 11040.8496
# DIP-VAE-I - Epoch [7/10], Step [2500/4608], Loss: 11082.7275
# DIP-VAE-I - Epoch [7/10], Step [2600/4608], Loss: 10605.2002
# DIP-VAE-I - Epoch [7/10], Step [2700/4608], Loss: 11245.6025
# DIP-VAE-I - Epoch [7/10], Step [2800/4608], Loss: 11405.4551
# DIP-VAE-I - Epoch [7/10], Step [2900/4608], Loss: 11001.2422
# DIP-VAE-I - Epoch [7/10], Step [3000/4608], Loss: 11152.1680
# DIP-VAE-I - Epoch [7/10], Step [3100/4608], Loss: 11237.7520
# DIP-VAE-I - Epoch [7/10], Step [3200/4608], Loss: 11091.8574
# DIP-VAE-I - Epoch [7/10], Step [3300/4608], Loss: 10945.5234
# DIP-VAE-I - Epoch [7/10], Step [3400/4608], Loss: 10779.0996
# DIP-VAE-I - Epoch [7/10], Step [3500/4608], Loss: 10850.3926
# DIP-VAE-I - Epoch [7/10], Step [3600/4608], Loss: 11074.7383
# DIP-VAE-I - Epoch [7/10], Step [3700/4608], Loss: 11103.0186
# DIP-VAE-I - Epoch [7/10], Step [3800/4608], Loss: 11134.3018
# DIP-VAE-I - Epoch [7/10], Step [3900/4608], Loss: 10864.7090
# DIP-VAE-I - Epoch [7/10], Step [4000/4608], Loss: 10964.6934
# DIP-VAE-I - Epoch [7/10], Step [4100/4608], Loss: 11035.0479
# DIP-VAE-I - Epoch [7/10], Step [4200/4608], Loss: 10763.5312
# DIP-VAE-I - Epoch [7/10], Step [4300/4608], Loss: 10837.3613
# DIP-VAE-I - Epoch [7/10], Step [4400/4608], Loss: 10899.9961
# DIP-VAE-I - Epoch [7/10], Step [4500/4608], Loss: 11130.9336
# DIP-VAE-I - Epoch [7/10], Step [4600/4608], Loss: 11303.6475
# DIP-VAE-I - Epoch [7/10] completed. Avg Loss: 86.3962
# DIP-VAE-I - Epoch [8/10], Step [100/4608], Loss: 10960.0508
# DIP-VAE-I - Epoch [8/10], Step [200/4608], Loss: 10341.5488
# DIP-VAE-I - Epoch [8/10], Step [300/4608], Loss: 10976.0098
# DIP-VAE-I - Epoch [8/10], Step [400/4608], Loss: 10927.8955
# DIP-VAE-I - Epoch [8/10], Step [500/4608], Loss: 10916.0840
# DIP-VAE-I - Epoch [8/10], Step [600/4608], Loss: 10658.5010
# DIP-VAE-I - Epoch [8/10], Step [700/4608], Loss: 10699.9395
# DIP-VAE-I - Epoch [8/10], Step [800/4608], Loss: 10815.6318
# DIP-VAE-I - Epoch [8/10], Step [900/4608], Loss: 10377.0781
# DIP-VAE-I - Epoch [8/10], Step [1000/4608], Loss: 10447.9961
# DIP-VAE-I - Epoch [8/10], Step [1100/4608], Loss: 11242.4941
# DIP-VAE-I - Epoch [8/10], Step [1200/4608], Loss: 10758.8428
# DIP-VAE-I - Epoch [8/10], Step [1300/4608], Loss: 10427.3125
# DIP-VAE-I - Epoch [8/10], Step [1400/4608], Loss: 10958.7822
# DIP-VAE-I - Epoch [8/10], Step [1500/4608], Loss: 10754.7773
# DIP-VAE-I - Epoch [8/10], Step [1600/4608], Loss: 10783.6797
# DIP-VAE-I - Epoch [8/10], Step [1700/4608], Loss: 11136.2451
# DIP-VAE-I - Epoch [8/10], Step [1800/4608], Loss: 10737.1406
# DIP-VAE-I - Epoch [8/10], Step [1900/4608], Loss: 10578.9854
# DIP-VAE-I - Epoch [8/10], Step [2000/4608], Loss: 10922.8682
# DIP-VAE-I - Epoch [8/10], Step [2100/4608], Loss: 11188.5420
# DIP-VAE-I - Epoch [8/10], Step [2200/4608], Loss: 10782.4355
# DIP-VAE-I - Epoch [8/10], Step [2300/4608], Loss: 10947.7402
# DIP-VAE-I - Epoch [8/10], Step [2400/4608], Loss: 10821.1572
# DIP-VAE-I - Epoch [8/10], Step [2500/4608], Loss: 10808.4551
# DIP-VAE-I - Epoch [8/10], Step [2600/4608], Loss: 10728.4756
# DIP-VAE-I - Epoch [8/10], Step [2700/4608], Loss: 10786.1602
# DIP-VAE-I - Epoch [8/10], Step [2800/4608], Loss: 10862.7178
# DIP-VAE-I - Epoch [8/10], Step [2900/4608], Loss: 10615.0352
# DIP-VAE-I - Epoch [8/10], Step [3000/4608], Loss: 11110.6094
# DIP-VAE-I - Epoch [8/10], Step [3100/4608], Loss: 10858.5977
# DIP-VAE-I - Epoch [8/10], Step [3200/4608], Loss: 10667.5723
# DIP-VAE-I - Epoch [8/10], Step [3300/4608], Loss: 11033.6787
# DIP-VAE-I - Epoch [8/10], Step [3400/4608], Loss: 10875.8203
# DIP-VAE-I - Epoch [8/10], Step [3500/4608], Loss: 10658.5488
# DIP-VAE-I - Epoch [8/10], Step [3600/4608], Loss: 10456.5371
# DIP-VAE-I - Epoch [8/10], Step [3700/4608], Loss: 10830.6582
# DIP-VAE-I - Epoch [8/10], Step [3800/4608], Loss: 10864.4648
# DIP-VAE-I - Epoch [8/10], Step [3900/4608], Loss: 10307.6211
# DIP-VAE-I - Epoch [8/10], Step [4000/4608], Loss: 11037.5195
# DIP-VAE-I - Epoch [8/10], Step [4100/4608], Loss: 10509.2822
# DIP-VAE-I - Epoch [8/10], Step [4200/4608], Loss: 11147.2402
# DIP-VAE-I - Epoch [8/10], Step [4300/4608], Loss: 10237.9316
# DIP-VAE-I - Epoch [8/10], Step [4400/4608], Loss: 10796.5117
# DIP-VAE-I - Epoch [8/10], Step [4500/4608], Loss: 10843.6133
# DIP-VAE-I - Epoch [8/10], Step [4600/4608], Loss: 10912.0840
# DIP-VAE-I - Epoch [8/10] completed. Avg Loss: 84.8789
# DIP-VAE-I - Epoch [9/10], Step [100/4608], Loss: 10558.8555
# DIP-VAE-I - Epoch [9/10], Step [200/4608], Loss: 10958.8604
# DIP-VAE-I - Epoch [9/10], Step [300/4608], Loss: 10656.5195
# DIP-VAE-I - Epoch [9/10], Step [400/4608], Loss: 10635.5254
# DIP-VAE-I - Epoch [9/10], Step [500/4608], Loss: 11040.0820
# DIP-VAE-I - Epoch [9/10], Step [600/4608], Loss: 10456.0156
# DIP-VAE-I - Epoch [9/10], Step [700/4608], Loss: 10794.3711
# DIP-VAE-I - Epoch [9/10], Step [800/4608], Loss: 10268.9854
# DIP-VAE-I - Epoch [9/10], Step [900/4608], Loss: 10436.2734
# DIP-VAE-I - Epoch [9/10], Step [1000/4608], Loss: 10654.7832
# DIP-VAE-I - Epoch [9/10], Step [1100/4608], Loss: 10341.3838
# DIP-VAE-I - Epoch [9/10], Step [1200/4608], Loss: 10357.4287
# DIP-VAE-I - Epoch [9/10], Step [1300/4608], Loss: 10459.7051
# DIP-VAE-I - Epoch [9/10], Step [1400/4608], Loss: 10897.5723
# DIP-VAE-I - Epoch [9/10], Step [1500/4608], Loss: 10694.7891
# DIP-VAE-I - Epoch [9/10], Step [1600/4608], Loss: 10876.5088
# DIP-VAE-I - Epoch [9/10], Step [1700/4608], Loss: 10860.5566
# DIP-VAE-I - Epoch [9/10], Step [1800/4608], Loss: 10739.2158
# DIP-VAE-I - Epoch [9/10], Step [1900/4608], Loss: 10633.1084
# DIP-VAE-I - Epoch [9/10], Step [2000/4608], Loss: 10637.6572
# DIP-VAE-I - Epoch [9/10], Step [2100/4608], Loss: 10584.5566
# DIP-VAE-I - Epoch [9/10], Step [2200/4608], Loss: 11009.2520
# DIP-VAE-I - Epoch [9/10], Step [2300/4608], Loss: 10353.3711
# DIP-VAE-I - Epoch [9/10], Step [2400/4608], Loss: 10846.7695
# DIP-VAE-I - Epoch [9/10], Step [2500/4608], Loss: 11211.9336
# DIP-VAE-I - Epoch [9/10], Step [2600/4608], Loss: 10485.8496
# DIP-VAE-I - Epoch [9/10], Step [2700/4608], Loss: 11092.2959
# DIP-VAE-I - Epoch [9/10], Step [2800/4608], Loss: 10643.5596
# DIP-VAE-I - Epoch [9/10], Step [2900/4608], Loss: 10773.4258
# DIP-VAE-I - Epoch [9/10], Step [3000/4608], Loss: 11552.4473
# DIP-VAE-I - Epoch [9/10], Step [3100/4608], Loss: 10572.1885
# DIP-VAE-I - Epoch [9/10], Step [3200/4608], Loss: 10604.6357
# DIP-VAE-I - Epoch [9/10], Step [3300/4608], Loss: 10537.6494
# DIP-VAE-I - Epoch [9/10], Step [3400/4608], Loss: 10680.3125
# DIP-VAE-I - Epoch [9/10], Step [3500/4608], Loss: 10591.6025
# DIP-VAE-I - Epoch [9/10], Step [3600/4608], Loss: 10443.1172
# DIP-VAE-I - Epoch [9/10], Step [3700/4608], Loss: 10151.6758
# DIP-VAE-I - Epoch [9/10], Step [3800/4608], Loss: 10560.6084
# DIP-VAE-I - Epoch [9/10], Step [3900/4608], Loss: 10410.4365
# DIP-VAE-I - Epoch [9/10], Step [4000/4608], Loss: 10621.1611
# DIP-VAE-I - Epoch [9/10], Step [4100/4608], Loss: 10975.1641
# DIP-VAE-I - Epoch [9/10], Step [4200/4608], Loss: 10299.0801
# DIP-VAE-I - Epoch [9/10], Step [4300/4608], Loss: 10937.0576
# DIP-VAE-I - Epoch [9/10], Step [4400/4608], Loss: 10209.3398
# DIP-VAE-I - Epoch [9/10], Step [4500/4608], Loss: 11127.0156
# DIP-VAE-I - Epoch [9/10], Step [4600/4608], Loss: 10272.4355
# DIP-VAE-I - Epoch [9/10] completed. Avg Loss: 83.6920
# DIP-VAE-I - Epoch [10/10], Step [100/4608], Loss: 10426.7246
# DIP-VAE-I - Epoch [10/10], Step [200/4608], Loss: 10740.1729
# DIP-VAE-I - Epoch [10/10], Step [300/4608], Loss: 10289.1270
# DIP-VAE-I - Epoch [10/10], Step [400/4608], Loss: 10179.3125
# DIP-VAE-I - Epoch [10/10], Step [500/4608], Loss: 10299.7188
# DIP-VAE-I - Epoch [10/10], Step [600/4608], Loss: 10262.7695
# DIP-VAE-I - Epoch [10/10], Step [700/4608], Loss: 10518.6484
# DIP-VAE-I - Epoch [10/10], Step [800/4608], Loss: 10230.6377
# DIP-VAE-I - Epoch [10/10], Step [900/4608], Loss: 10694.1006
# DIP-VAE-I - Epoch [10/10], Step [1000/4608], Loss: 10352.4990
# DIP-VAE-I - Epoch [10/10], Step [1100/4608], Loss: 10826.2275
# DIP-VAE-I - Epoch [10/10], Step [1200/4608], Loss: 10678.9199
# DIP-VAE-I - Epoch [10/10], Step [1300/4608], Loss: 10228.5791
# DIP-VAE-I - Epoch [10/10], Step [1400/4608], Loss: 10594.8887
# DIP-VAE-I - Epoch [10/10], Step [1500/4608], Loss: 10466.7568
# DIP-VAE-I - Epoch [10/10], Step [1600/4608], Loss: 10513.9219
# DIP-VAE-I - Epoch [10/10], Step [1700/4608], Loss: 10538.3301
# DIP-VAE-I - Epoch [10/10], Step [1800/4608], Loss: 10760.8086
# DIP-VAE-I - Epoch [10/10], Step [1900/4608], Loss: 10271.6699
# DIP-VAE-I - Epoch [10/10], Step [2000/4608], Loss: 10238.5801
# DIP-VAE-I - Epoch [10/10], Step [2100/4608], Loss: 10460.1445
# DIP-VAE-I - Epoch [10/10], Step [2200/4608], Loss: 11089.8535
# DIP-VAE-I - Epoch [10/10], Step [2300/4608], Loss: 10332.5898
# DIP-VAE-I - Epoch [10/10], Step [2400/4608], Loss: 10604.0430
# DIP-VAE-I - Epoch [10/10], Step [2500/4608], Loss: 10374.8506
# DIP-VAE-I - Epoch [10/10], Step [2600/4608], Loss: 10207.5869
# DIP-VAE-I - Epoch [10/10], Step [2700/4608], Loss: 10489.5234
# DIP-VAE-I - Epoch [10/10], Step [2800/4608], Loss: 10603.1670
# DIP-VAE-I - Epoch [10/10], Step [2900/4608], Loss: 10458.8867
# DIP-VAE-I - Epoch [10/10], Step [3000/4608], Loss: 10627.6025
# DIP-VAE-I - Epoch [10/10], Step [3100/4608], Loss: 10219.5586
# DIP-VAE-I - Epoch [10/10], Step [3200/4608], Loss: 10825.3623
# DIP-VAE-I - Epoch [10/10], Step [3300/4608], Loss: 10435.8633
# DIP-VAE-I - Epoch [10/10], Step [3400/4608], Loss: 10851.7393
# DIP-VAE-I - Epoch [10/10], Step [3500/4608], Loss: 11069.7910
# DIP-VAE-I - Epoch [10/10], Step [3600/4608], Loss: 10590.2334
# DIP-VAE-I - Epoch [10/10], Step [3700/4608], Loss: 10518.6621
# DIP-VAE-I - Epoch [10/10], Step [3800/4608], Loss: 10458.6318
# DIP-VAE-I - Epoch [10/10], Step [3900/4608], Loss: 10810.5664
# DIP-VAE-I - Epoch [10/10], Step [4000/4608], Loss: 10857.6807
# DIP-VAE-I - Epoch [10/10], Step [4100/4608], Loss: 10293.1279
# DIP-VAE-I - Epoch [10/10], Step [4200/4608], Loss: 10503.6748
# DIP-VAE-I - Epoch [10/10], Step [4300/4608], Loss: 10307.1631
# DIP-VAE-I - Epoch [10/10], Step [4400/4608], Loss: 10545.3896
# DIP-VAE-I - Epoch [10/10], Step [4500/4608], Loss: 10377.1309
# DIP-VAE-I - Epoch [10/10], Step [4600/4608], Loss: 10578.9346
# DIP-VAE-I - Epoch [10/10] completed. Avg Loss: 82.6680
# Training complete!

# %%
# dip_vae_model
model=dip_vae_model
# --- Run Metrics After Training ---
print("\n" + "="*50)
print("Starting Quantitative Metrics Evaluation")
print("="*50 + "\n")

# Define the number of samples for metrics calculation to speed it up.
# For dSprites, 10,000 to 20,000 samples is usually sufficient.
# Set to None to use all available samples in the test_dataset.
NUM_SAMPLES_FOR_METRICS = 20000

# Collect data for metrics (using test_loader, but now limited by NUM_SAMPLES_FOR_METRICS)
# It's good to keep batch_size for the data_loader relatively high (e.g., 256)
# to make efficient use of the GPU during the forward pass.
metrics_data_loader = torch.utils.data.DataLoader(dataset=test_dataset, batch_size=256, shuffle=False)


######################################


mu1_for_metrics, latents_values_for_metrics, factor_names, active_factors_idx = \
    collect_latent_factors_for_metrics2(model, metrics_data_loader, device,
                                       num_samples_to_collect=NUM_SAMPLES_FOR_METRICS)

# Calculate and print MIG
mig_avg_score, mig_report = calculate_mig(mu1_for_metrics, latents_values_for_metrics, factor_names, active_factors_idx)

# Calculate and print Linear Regression Disentanglement Score
linear_disentanglement_avg_score, linear_r2_report, linear_disentanglement_summary = \
    calculate_linear_disentanglement_score(mu1_for_metrics, latents_values_for_metrics, factor_names, active_factors_idx)

# Calculate and print DCI
dci_informativeness, dci_disentanglement, dci_completeness, dci_report = \
    calculate_dci(mu1_for_metrics, latents_values_for_metrics, factor_names, active_factors_idx)

print("\n" + "="*50)
print("Quantitative Metrics Evaluation Complete")
print("="*50 + "\n")


#######################
model_name = "dip_vae_model"
model_results = {
    "Model": model_name,
    "MIG Score": mig_avg_score,
    "DCI Informativeness": dci_informativeness,
    "DCI Disentanglement": dci_disentanglement,
    "DCI Completeness": dci_completeness,
    "Average R2 Disentanglement": linear_disentanglement_avg_score,
}
all_model_results.append(model_results)
print(f"Finished evaluating {model_name}.")
# Out:
# ==================================================
# Starting Quantitative Metrics Evaluation
# ==================================================
#
# Collecting latent representations and ground truth factors for metrics (up to 20000 samples)...
# Collecting data for metrics: 0it [00:00, ?it/s]
# Collected 20000 samples for metrics.
#
# Calculating MIG (Mutual Information Gap) Score...
# Discretizing latent dimensions into 20 bins for MI calculation...
# Discretizing Latents:   0%|          | 0/64 [00:00<?, ?it/s]
# Discretizing ground truth factors into 20 bins for MI calculation...
# Discretizing Factors:   0%|          | 0/5 [00:00<?, ?it/s]
# Calculating MI matrix (this can take a while)...
#
# MIG Score:
# --------------------------------------------------
#   Average MIG Score: 0.1816
# --------------------------------------------------
# Mutual Information Heatmap saved to mig_mi_heatmap.png
#
# Calculating Linear Regression Disentanglement Score (R-squared)...
# Fitting linear regressors:   0%|          | 0/64 [00:00<?, ?it/s]
# Linear Regression R-squared Scores:
# --------------------------------------------------
# Latent Dim   | shape      scale      orientation posX       posY
# ----------------------------------------------------------------------
# Latent 0     | 0.0071     0.0397     0.0000     0.0067     0.1803
# Latent 1     | 0.1175     0.5427     0.0000     0.0012     0.0137
# Latent 2     | 0.0333     0.1386     0.0001     0.0303     0.1065
# Latent 3     | 0.0021     0.0062     0.0001     0.1349     0.0125
# Latent 4     | 0.0571     0.2062     0.0000     0.0020     0.0396
# Latent 5     | 0.0056     0.0322     0.0001     0.0001     0.0498
# Latent 6     | 0.0003     0.0036     0.0001     0.0579     0.0030
# Latent 7     | 0.0025     0.0043     0.0001     0.2549     0.0015
# Latent 8     | 0.0557     0.2326     0.0008     0.2041     0.0238
# Latent 9     | 0.0481     0.1746     0.0001     0.1232     0.0114
# Latent 10    | 0.0254     0.1181     0.0013     0.0802     0.0112
# Latent 11    | 0.0231     0.1054     0.0002     0.0417     0.0116
# Latent 12    | 0.0002     0.0016     0.0006     0.0001     0.0229
# Latent 13    | 0.0251     0.1475     0.0013     0.2677     0.0275
# Latent 14    | 0.0130     0.0787     0.0001     0.0751     0.0135
# Latent 15    | 0.0044     0.0272     0.0024     0.0001     0.1007
# Latent 16    | 0.0005     0.0048     0.0001     0.0912     0.0024
# Latent 17    | 0.0413     0.1952     0.0003     0.0001     0.0063
# Latent 18    | 0.0141     0.0674     0.0012     0.0027     0.0473
# Latent 19    | 0.0017     0.0024     0.0000     0.1196     0.1128
# Latent 20    | 0.0005     0.0006     0.0000     0.1362     0.0146
# Latent 21    | 0.0106     0.0460     0.0011     0.0045     0.0016
# Latent 22    | 0.0748     0.3138     0.0000     0.0629     0.0082
# Latent 23    | 0.0146     0.0863     0.0000     0.0533     0.1029
# Latent 24    | 0.0108     0.0559     0.0002     0.0412     0.0414
# Latent 25    | 0.0251     0.0877     0.0006     0.0048     0.0013
# Latent 26    | 0.0099     0.0428     0.0001     0.0022     0.0001
# Latent 27    | 0.0605     0.2568     0.0004     0.0000     0.0305
# Latent 28    | 0.0035     0.0191     0.0002     0.0012     0.0000
# Latent 29    | 0.0357     0.1582     0.0000     0.0461     0.0235
# Latent 30    | 0.0040     0.0095     0.0000     0.2811     0.0329
# Latent 31    | 0.0047     0.0314     0.0008     0.0065     0.0186
# Latent 32    | 0.0208     0.1381     0.0001     0.0563     0.0044
# Latent 33    | 0.0056     0.0217     0.0000     0.2273     0.0139
# Latent 34    | 0.0000     0.0196     0.0005     0.0366     0.2094
# Latent 35    | 0.0380     0.1656     0.0001     0.0174     0.0963
# Latent 36    | 0.0048     0.0387     0.0000     0.0065     0.2215
# Latent 37    | 0.0146     0.0919     0.0000     0.2073     0.0007
# Latent 38    | 0.0119     0.0551     0.0000     0.0065     0.1237
# Latent 39    | 0.0030     0.0106     0.0001     0.0252     0.1373
# Latent 40    | 0.0004     0.0005     0.0001     0.0314     0.0686
# Latent 41    | 0.0000     0.0003     0.0000     0.0958     0.2890
# Latent 42    | 0.0009     0.0020     0.0000     0.0859     0.0312
# Latent 43    | 0.0002     0.0032     0.0004     0.0177     0.0402
# Latent 44    | 0.0471     0.1960     0.0005     0.1098     0.2087
# Latent 45    | 0.0006     0.0015     0.0000     0.0877     0.0003
# Latent 46    | 0.0081     0.0202     0.0006     0.0015     0.0151
# Latent 47    | 0.0413     0.1615     0.0004     0.0087     0.0000
# Latent 48    | 0.0001     0.0016     0.0000     0.0070     0.1213
# Latent 49    | 0.0006     0.0018     0.0001     0.4283     0.0093
# Latent 50    | 0.0172     0.0367     0.0002     0.0244     0.0013
# Latent 51    | 0.0403     0.1455     0.0000     0.0243     0.1734
# Latent 52    | 0.0005     0.0038     0.0002     0.0043     0.0117
# Latent 53    | 0.0343     0.1559     0.0000     0.2145     0.0461
# Latent 54    | 0.0008     0.0006     0.0002     0.0760     0.0057
# Latent 55    | 0.0052     0.0050     0.0003     0.0376     0.0106
# Latent 56    | 0.0421     0.1055     0.0005     0.0000     0.0466
# Latent 57    | 0.0101     0.0509     0.0000     0.2292     0.1042
# Latent 58    | 0.0155     0.0988     0.0018     0.2013     0.0424
# Latent 59    | 0.0232     0.0487     0.0003     0.0037     0.1213
# Latent 60    | 0.0019     0.0056     0.0000     0.1648     0.0000
# Latent 61    | 0.0072     0.0144     0.0004     0.0061     0.0792
# Latent 62    | 0.0036     0.0165     0.0001     0.0010     0.0088
# Latent 63    | 0.0033     0.0083     0.0001     0.3467     0.1828
#
# Disentanglement Summary (Per Ground Truth Factor):
# --------------------------------------------------
#   shape: Best explained by Latent 1 (R2: 0.1175)
#   scale: Best explained by Latent 1 (R2: 0.5427)
#   orientation: Best explained by Latent 15 (R2: 0.0024)
#   posX: Best explained by Latent 49 (R2: 0.4283)
#   posY: Best explained by Latent 41 (R2: 0.2890)
# --------------------------------------------------
# Average Disentanglement Score (Max R2 per factor): 0.2760
# Saved R2 matrix to ./metrics_hdvae/linear_r2_matrix.npy
# Saved R2 heatmap to ./metrics_hdvae/linear_r2_heatmap.png
#
# Calculating DCI (Disentanglement, Completeness, Informativeness) Score...
# Discretizing ground truth factors into 10 bins for DCI...
# Training RandomForestClassifiers for each ground truth factor...
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_discretization.py:306: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 0 are removed. Consider decreasing the number of bins.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_discretization.py:306: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 0 are removed. Consider decreasing the number of bins.
#   warnings.warn(
# DCI per factor:   0%|          | 0/5 [00:00<?, ?it/s]
# DCI Scores:
# --------------------------------------------------
#   Informativeness: 0.7625
#   Disentanglement: 0.0354
#   Completeness:    0.0583
# --------------------------------------------------
#
# ==================================================
# Quantitative Metrics Evaluation Complete
# ==================================================
#
# Finished evaluating dip_vae_model.

# %%
model_name = "dip_vae_model"
model_results = {
    "Model": model_name,
    "MIG Score": 0.1816,
    "DCI Informativeness": 0.7625,
    "DCI Disentanglement": 0.0354,
    "DCI Completeness": 0.0583,
    "Average R2 Disentanglement": 0.2760,
}
all_model_results.append(model_results)
print(f"Finished evaluating {model_name}.")
# Out:
# Finished evaluating dip_vae_model.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Set a style for the plots (optional, but makes them look nicer)
sns.set_theme(style="whitegrid")


# Convert to a Pandas DataFrame for easy plotting
df_results = pd.DataFrame(all_model_results)

print("DataFrame of Results:")
print(df_results)
# Out:
# DataFrame of Results:
#               Model  MIG Score  DCI Informativeness  DCI Disentanglement  \
# 0             HDVAE   0.396399               0.6248             0.110593
# 1          Beta-VAE   0.265900               0.7377             0.050100
# 2  factor_vae_model   0.285600               0.7440             0.037700
# 3     dip_vae_model   0.181600               0.7625             0.035400
#
#    DCI Completeness  Average R2 Disentanglement
# 0          0.032068                    0.317329
# 1          0.050200                    0.346300
# 2          0.054300                    0.246000
# 3          0.058300                    0.276000

# %%
# MIG Score Comparison
plt.figure(figsize=(8, 6))
sns.barplot(x="Model", y="MIG Score", data=df_results, palette="viridis")
plt.title("MIG Score Comparison Across Models")
plt.xlabel("Model Architecture")
plt.ylabel("MIG Score")
plt.ylim(0, 1) # MIG scores are typically between 0 and 1
plt.show()

# Average R2 Disentanglement Score Comparison
plt.figure(figsize=(8, 6))
sns.barplot(x="Model", y="Average R2 Disentanglement", data=df_results, palette="magma")
plt.title("Average R2 Disentanglement Score Comparison Across Models")
plt.xlabel("Model Architecture")
plt.ylabel("Average R2 Score")
plt.ylim(0, 1) # R2 scores are typically between 0 and 1
plt.show()

# Plot 3: DCI Scores Comparison (Grouped Bar Chart)
# Melt the DataFrame to long format for DCI plotting
df_dci = df_results[['Model', 'DCI Informativeness', 'DCI Disentanglement', 'DCI Completeness']]
df_dci_melted = df_dci.melt(id_vars='Model', var_name='DCI Metric', value_name='Score')
plt.figure(figsize=(10, 7))
sns.barplot(x="Model", y="Score", hue="DCI Metric", data=df_dci_melted, palette="deep")
plt.title("DCI Scores Comparison Across Models")
plt.xlabel("Model Architecture")
plt.ylabel("Score")
plt.ylim(0, 1) # DCI scores are typically between 0 and 1
plt.legend(title="DCI Metric", bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout() # Adjust layout to prevent labels from overlapping
plt.show()
# Out:
# <ipython-input-29-0e5ebe9a288f>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="Model", y="MIG Score", data=df_results, palette="viridis")
# <ipython-input-29-0e5ebe9a288f>:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="Model", y="Average R2 Disentanglement", data=df_results, palette="magma")
